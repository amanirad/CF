# %% [markdown]
# # Composite Face: RPPC

# %%
library(tidyverse)
library(ggpubr)
library(rstatix)
library(readxl)
library(dplyr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.1     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘rstatix’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
#install.packages('WRS2')
library(WRS2)
#conda install -c conda-forge r-wrs2

# %%
setwd("/Users/j.amanirad/Desktop/CompositeFace") 
CF_RPPCC <- read_excel("CF_RPPC.xlsx")
CF_RPPCC
# Out:
#      subject sex    Face_1    Face_2    Face_Gender Congruency Block Trial
# 1    1       male   A_06_08_F R_06_08_F Female      1.0        1     1
# 2    1       male   A_01_05_F R_06_05_F Female      0          1     2
# 3    1       male   A_05_01_F A_05_06_F Female      0          1     3
# 4    1       male   A_12_10_M R_09_11_M Male        1          1     4
# 5    1       male   A_11_09_M A_14_12_M Male        1          1     5
# 6    1       male   A_03_02_F R_03_02_F Female      1          1     6
# 7    1       male   A_03_08_F A_06_08_F Female      0          1     7
# 8    1       male   A_01_04_F R_02_01_F Female      1          1     8
# 9    1       male   A_14_09_M R_14_11_M Male        0          1     9
# 10   1       male   A_09_14_M R_09_14_M Male        1          1     10
# 11   1       male   A_02_03_F A_06_03_F Female      0          1     11
# 12   1       male   A_12_15_M A_14_15_M Male        0          1     12
# 13   1       male   A_11_13_M R_11_14_M Male        0          1     13
# 14   1       male   A_01_03_F A_02_01_F Female      1          1     14
# 15   1       male   A_05_08_F A_02_01_F Female      1          1     15
# 16   1       male   A_14_12_M R_14_12_M Male        1          1     16
# 17   1       male   A_10_12_M A_10_12_M Male        1          1     17
# 18   1       male   A_02_01_F A_02_01_F Female      1          1     18
# 19   1       male   A_05_07_F R_01_03_F Female      1          1     19
# 20   1       male   A_11_14_M R_14_09_M Male        1          1     20
# 21   1       male   A_10_13_M A_09_11_M Male        1          1     21
# 22   1       male   A_05_07_F A_05_07_F Female      1          1     22
# 23   1       male   A_09_11_M A_14_11_M Male        0          1     23
# 24   1       male   A_05_08_F R_05_01_F Female      0          1     24
# 25   1       male   A_12_10_M A_12_10_M Male        1          1     25
# 26   1       male   A_14_09_M R_12_09_M Male        0          1     26
# 27   1       male   A_09_11_M A_09_11_M Male        1          1     27
# 28   1       male   A_03_04_F A_03_08_F Female      0          1     28
# 29   1       male   A_01_05_F A_02_03_F Female      1          1     29
# 30   1       male   A_06_03_F R_02_03_F Female      0          1     30
# ⋮    ⋮       ⋮      ⋮         ⋮         ⋮           ⋮          ⋮     ⋮
# 5731 36      female A_10_13_M R_14_15_M Male        1          4     131
# 5732 36      female A_09_12_M A_09_10_M Male        0          4     132
# 5733 36      female A_03_01_F A_03_01_F Female      1          4     133
# 5734 36      female A_01_03_F R_01_02_F Female      0          4     134
# 5735 36      female A_03_01_F A_02_04_F Female      1          4     135
# 5736 36      female A_03_04_F R_05_07_F Female      1          4     136
# 5737 36      female A_11_10_M R_11_13_M Male        0          4     137
# 5738 36      female A_14_15_M R_12_15_M Male        0          4     138
# 5739 36      female A_03_04_F R_02_01_F Female      1          4     139
# 5740 36      female A_09_14_M R_10_13_M Male        1          4     140
# 5741 36      female A_02_06_F A_02_06_F Female      1          4     141
# 5742 36      female A_10_12_M A_10_09_M Male        0          4     142
# 5743 36      female A_12_09_M R_12_10_M Male        0          4     143
# 5744 36      female A_03_04_F R_03_04_F Female      1          4     144
# 5745 36      female A_11_14_M A_11_14_M Male        1          4     145
# 5746 36      female A_02_03_F A_06_03_F Female      0          4     146
# 5747 36      female A_01_03_F R_02_03_F Female      0          4     147
# 5748 36      female A_10_13_M A_11_13_M Male        0          4     148
# 5749 36      female A_09_12_M R_09_12_M Male        1          4     149
# 5750 36      female A_10_12_M A_12_09_M Male        1          4     150
# 5751 36      female A_10_11_M R_10_12_M Male        0          4     151
# 5752 36      female A_02_04_F A_06_03_F Female      1          4     152
# 5753 36      female A_03_02_F R_01_02_F Female      0          4     153
# 5754 36      female A_12_15_M R_14_15_M Male        0          4     154
# 5755 36      female A_11_09_M R_11_09_M Male        1          4     155
# 5756 36      female A_14_15_M R_14_15_M Male        1          4     156
# 5757 36      female A_14_09_M A_14_09_M Male        1          4     157
# 5758 36      female A_14_12_M A_12_10_M Male        1          4     158
# 5759 36      female A_01_05_F A_03_04_F Female      1          4     159
# 5760 36      female A_10_13_M A_10_13_M Male        1          4     160
#      Alignment Condition Type                   Key_Resp Cor_Ans Accuracy
# 1    0         1         Misaligned Congruent   L        L       1
# 2    0         3         Misaligned Incongruent A        A       1
# 3    1         2         Aligned Incongruent    L        L       1
# 4    0         4         Misaligned Congruent   A        A       1
# 5    1         4         Aligned Congruent      L        A       0
# 6    0         1         Misaligned Congruent   L        L       1
# 7    1         3         Aligned Incongruent    A        A       1
# 8    0         4         Misaligned Congruent   A        A       1
# 9    0         2         Misaligned Incongruent L        L       1
# 10   0         1         Misaligned Congruent   L        L       1
# 11   1         3         Aligned Incongruent    L        A       0
# 12   1         3         Aligned Incongruent    L        A       0
# 13   0         2         Misaligned Incongruent L        L       1
# 14   1         4         Aligned Congruent      A        A       1
# 15   1         4         Aligned Congruent      A        A       1
# 16   0         1         Misaligned Congruent   L        L       1
# 17   1         1         Aligned Congruent      L        L       1
# 18   1         1         Aligned Congruent      L        L       1
# 19   0         4         Misaligned Congruent   A        A       1
# 20   0         4         Misaligned Congruent   A        A       1
# 21   1         4         Aligned Congruent      A        A       1
# 22   1         1         Aligned Congruent      L        L       1
# 23   1         3         Aligned Incongruent    A        A       1
# 24   0         2         Misaligned Incongruent L        L       1
# 25   1         1         Aligned Congruent      L        L       1
# 26   0         3         Misaligned Incongruent A        A       1
# 27   1         1         Aligned Congruent      L        L       1
# 28   1         2         Aligned Incongruent    L        L       1
# 29   1         4         Aligned Congruent      A        A       1
# 30   0         3         Misaligned Incongruent A        A       1
# ⋮    ⋮         ⋮         ⋮                      ⋮        ⋮       ⋮
# 5731 0         4         Misaligned Congruent   A        A       1
# 5732 1         2         Aligned Incongruent    A        L       0
# 5733 1         1         Aligned Congruent      L        L       1
# 5734 0         2         Misaligned Incongruent L        L       1
# 5735 1         4         Aligned Congruent      A        A       1
# 5736 0         4         Misaligned Congruent   A        A       1
# 5737 0         2         Misaligned Incongruent A        L       0
# 5738 0         3         Misaligned Incongruent A        A       1
# 5739 0         4         Misaligned Congruent   A        A       1
# 5740 0         4         Misaligned Congruent   A        A       1
# 5741 1         1         Aligned Congruent      L        L       1
# 5742 1         2         Aligned Incongruent    L        L       1
# 5743 0         2         Misaligned Incongruent L        L       1
# 5744 0         1         Misaligned Congruent   L        L       1
# 5745 1         1         Aligned Congruent      L        L       1
# 5746 1         3         Aligned Incongruent    A        A       1
# 5747 0         3         Misaligned Incongruent A        A       1
# 5748 1         3         Aligned Incongruent    A        A       1
# 5749 0         1         Misaligned Congruent   L        L       1
# 5750 1         4         Aligned Congruent      A        A       1
# 5751 0         2         Misaligned Incongruent L        L       1
# 5752 1         4         Aligned Congruent      A        A       1
# 5753 0         3         Misaligned Incongruent L        A       0
# 5754 0         3         Misaligned Incongruent A        A       1
# 5755 0         1         Misaligned Congruent   L        L       1
# 5756 0         1         Misaligned Congruent   L        L       1
# 5757 1         1         Aligned Congruent      L        L       1
# 5758 1         4         Aligned Congruent      A        A       1
# 5759 1         4         Aligned Congruent      A        A       1
# 5760 1         1         Aligned Congruent      L        L       1
#      R_time              Trial-Start        Key-Resp-Start
# 1    0.6071001000011165  187.24440519999916 189.10150530000027
# 2    0.6535372999998799  190.10150530000027 192.00504260000014
# 3    0.6341856999999436  193.00504260000014 194.88922830000007
# 4    0.7268544999998994  195.88922830000007 197.86608279999996
# 5    0.6975531000000046  198.86608279999996 200.81363589999995
# 6    0.6856608000009146  201.81363589999995 203.74929670000085
# 7    0.6889084999995247  204.74929670000085 206.68820520000037
# 8    1.2445335999993403  207.68820520000037 210.1827387999997
# 9    0.6734250999990763  211.1827387999997  213.10616389999876
# 10   0.6538386000003811  214.10616389999876 216.01000249999913
# 11   0.6262396000012813  217.01000249999913 218.8862421000004
# 12   1.0082399999984772  219.8862421000004  222.14448209999887
# 13   0.8625689999982569  223.14448209999887 225.2570510999971
# 14   0.9862165000005916  226.2570510999971  228.4932675999977
# 15   0.970097300000998   229.4932675999977  231.71336489999868
# 16   0.8671304999999847  232.71336489999868 234.83049539999865
# 17   0.9194430999988981  235.83049539999865 237.99993849999754
# 18   0.9216330999999627  238.99993849999754 241.1715715999975
# 19   0.6830399000002216  242.1715715999975  244.1046114999977
# 20   0.6632765999995172  245.1046114999977  247.0178880999972
# 21   0.8916094999996858  248.0178880999972  250.15949759999688
# 22   0.8238713000002462  251.15949759999688 253.23336889999712
# 23   0.6858244999995804  254.23336889999712 256.1691933999967
# 24   0.824812899999597   257.1691933999967  259.2440062999963
# 25   0.590899599999102   260.2440062999963  262.08490589999536
# 26   0.6865096000012272  263.08490589999536 265.0214154999966
# 27   0.8821359000005031  266.0214154999966  268.15355139999707
# 28   0.6613253999996231  269.15355139999707 271.0648767999967
# 29   0.6335351000008813  272.0648767999967  273.94841189999755
# 30   0.7356728999995539  274.94841189999755 276.9340847999971
# ⋮    ⋮                   ⋮                  ⋮
# 5731 0.7629079000009369  454.62107169998916 456.6339795999901
# 5732 0.9008504000004904  457.6339795999901  459.78482999999056
# 5733 0.7279816999991453  460.78482999999056 462.7628116999897
# 5734 0.6890395999991596  463.7628116999897  465.70185129998885
# 5735 0.5317805999995471  466.70185129998885 468.4836318999884
# 5736 0.6696927000004507  469.4836318999884  471.4033245999888
# 5737 0.6425399000010656  472.4033245999888  474.2958644999899
# 5738 0.7277804999986983  475.2958644999899  477.27364499998856
# 5739 0.777839399998993   478.27364499998856 480.30148439998754
# 5740 0.49740279999896303 481.30148439998754 483.0488871999865
# 5741 0.4618160000001808  484.0488871999865  485.76070319998666
# 5742 0.4497687999984919  486.76070319998666 488.46047199998515
# 5743 0.5344961000002513  489.46047199998515 491.2449680999854
# 5744 0.42470229999998993 492.2449680999854  493.91967039998536
# 5745 0.4555387000011251  494.91967039998536 496.6252090999865
# 5746 0.4600862999988749  497.6252090999865  499.33529539998534
# 5747 0.5206470000004628  500.33529539998534 502.1059423999858
# 5748 0.7622850999989168  503.1059423999858  505.1182274999847
# 5749 0.6359229000001505  506.1182274999847  508.00415039998484
# 5750 0.6475606999985757  509.00415039998484 510.9017110999834
# 5751 0.7417422000009537  511.9017110999834  513.8934532999843
# 5752 0.49481209999903514 514.8934532999843  516.6382653999834
# 5753 0.7139526000002661  517.6382653999834  519.6022179999837
# 5754 0.48440910000063014 520.6022179999837  522.3366270999844
# 5755 0.5926133999993908  523.3366270999844  525.1792404999838
# 5756 0.6479823000001488  526.1792404999838  528.077222799984
# 5757 0.573720300000059   529.077222799984   530.9009430999841
# 5758 0.44552200000107406 531.9009430999841  533.5964650999853
# 5759 0.6825627999998687  534.5964650999853  536.5290278999852
# 5760 0.5595559000004868  537.5290278999852  539.3385837999857

# %%
CF_RPPC <- data.frame(subj = as.numeric(CF_RPPCC$subject),
                 #sex = CF_CZZ$'sex',
                 Trial = as.numeric(CF_RPPCC$Trial),
                 #Cond = as.numeric(CF_CZZ$Condition),
                 #Type = CF_CZZ$'Type',
                 Cong = as.numeric(CF_RPPCC$Congruency),
                 Alig = as.numeric(CF_RPPCC$Alignment),
                 Key_Resp = CF_RPPCC$'Key_Resp',
                 Cor_Ans = CF_RPPCC$'Cor_Ans',
                 Acc = as.numeric(CF_RPPCC$Accuracy),
                 RT = as.numeric(CF_RPPCC$R_time)
)
CF_RPPC <- CF_RPPC %>% mutate(Cong = ifelse(Cong == "1", "Congruent", ifelse(Cong == "0", "InCongruent", 
                                                                             "NaN")))
CF_RPPC <- CF_RPPC %>% mutate(Alig = ifelse(Alig == "1", "Alignment", ifelse(Alig == "0", "MissAlignment", 
                                                                             "NaN")))
#CF_CZ<- CF_CZ[which(CF_CZ$sex == "female"),]

CF_RPPC
# Out:
#      subj Trial Cong        Alig          Key_Resp Cor_Ans Acc RT
# 1    1     1    Congruent   MissAlignment L        L       1   0.6071001
# 2    1     2    InCongruent MissAlignment A        A       1   0.6535373
# 3    1     3    InCongruent Alignment     L        L       1   0.6341857
# 4    1     4    Congruent   MissAlignment A        A       1   0.7268545
# 5    1     5    Congruent   Alignment     L        A       0   0.6975531
# 6    1     6    Congruent   MissAlignment L        L       1   0.6856608
# 7    1     7    InCongruent Alignment     A        A       1   0.6889085
# 8    1     8    Congruent   MissAlignment A        A       1   1.2445336
# 9    1     9    InCongruent MissAlignment L        L       1   0.6734251
# 10   1    10    Congruent   MissAlignment L        L       1   0.6538386
# 11   1    11    InCongruent Alignment     L        A       0   0.6262396
# 12   1    12    InCongruent Alignment     L        A       0   1.0082400
# 13   1    13    InCongruent MissAlignment L        L       1   0.8625690
# 14   1    14    Congruent   Alignment     A        A       1   0.9862165
# 15   1    15    Congruent   Alignment     A        A       1   0.9700973
# 16   1    16    Congruent   MissAlignment L        L       1   0.8671305
# 17   1    17    Congruent   Alignment     L        L       1   0.9194431
# 18   1    18    Congruent   Alignment     L        L       1   0.9216331
# 19   1    19    Congruent   MissAlignment A        A       1   0.6830399
# 20   1    20    Congruent   MissAlignment A        A       1   0.6632766
# 21   1    21    Congruent   Alignment     A        A       1   0.8916095
# 22   1    22    Congruent   Alignment     L        L       1   0.8238713
# 23   1    23    InCongruent Alignment     A        A       1   0.6858245
# 24   1    24    InCongruent MissAlignment L        L       1   0.8248129
# 25   1    25    Congruent   Alignment     L        L       1   0.5908996
# 26   1    26    InCongruent MissAlignment A        A       1   0.6865096
# 27   1    27    Congruent   Alignment     L        L       1   0.8821359
# 28   1    28    InCongruent Alignment     L        L       1   0.6613254
# 29   1    29    Congruent   Alignment     A        A       1   0.6335351
# 30   1    30    InCongruent MissAlignment A        A       1   0.7356729
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮        ⋮       ⋮   ⋮
# 5731 36   131   Congruent   MissAlignment A        A       1   0.7629079
# 5732 36   132   InCongruent Alignment     A        L       0   0.9008504
# 5733 36   133   Congruent   Alignment     L        L       1   0.7279817
# 5734 36   134   InCongruent MissAlignment L        L       1   0.6890396
# 5735 36   135   Congruent   Alignment     A        A       1   0.5317806
# 5736 36   136   Congruent   MissAlignment A        A       1   0.6696927
# 5737 36   137   InCongruent MissAlignment A        L       0   0.6425399
# 5738 36   138   InCongruent MissAlignment A        A       1   0.7277805
# 5739 36   139   Congruent   MissAlignment A        A       1   0.7778394
# 5740 36   140   Congruent   MissAlignment A        A       1   0.4974028
# 5741 36   141   Congruent   Alignment     L        L       1   0.4618160
# 5742 36   142   InCongruent Alignment     L        L       1   0.4497688
# 5743 36   143   InCongruent MissAlignment L        L       1   0.5344961
# 5744 36   144   Congruent   MissAlignment L        L       1   0.4247023
# 5745 36   145   Congruent   Alignment     L        L       1   0.4555387
# 5746 36   146   InCongruent Alignment     A        A       1   0.4600863
# 5747 36   147   InCongruent MissAlignment A        A       1   0.5206470
# 5748 36   148   InCongruent Alignment     A        A       1   0.7622851
# 5749 36   149   Congruent   MissAlignment L        L       1   0.6359229
# 5750 36   150   Congruent   Alignment     A        A       1   0.6475607
# 5751 36   151   InCongruent MissAlignment L        L       1   0.7417422
# 5752 36   152   Congruent   Alignment     A        A       1   0.4948121
# 5753 36   153   InCongruent MissAlignment L        A       0   0.7139526
# 5754 36   154   InCongruent MissAlignment A        A       1   0.4844091
# 5755 36   155   Congruent   MissAlignment L        L       1   0.5926134
# 5756 36   156   Congruent   MissAlignment L        L       1   0.6479823
# 5757 36   157   Congruent   Alignment     L        L       1   0.5737203
# 5758 36   158   Congruent   Alignment     A        A       1   0.4455220
# 5759 36   159   Congruent   Alignment     A        A       1   0.6825628
# 5760 36   160   Congruent   Alignment     L        L       1   0.5595559

# %%
for(it in 1:length(CF_RPPC$subj)){
  if(CF_RPPC$subj[it] >= 10 & CF_RPPC$subj[it]<= 27){
    if(CF_RPPC$Key_Resp[it] == "A" & CF_RPPC$Cor_Ans[it] == "A")
      CF_RPPC$SDT[it] <- "Hit"
    else if(CF_RPPC$Key_Resp[it] == "A" & CF_RPPC$Cor_Ans[it] == "L")
      CF_RPPC$SDT[it] <- "FalseAlarm"
    else if(CF_RPPC$Key_Resp[it] == "L" & CF_RPPC$Cor_Ans[it] == "A")
      CF_RPPC$SDT[it] <- "Miss"
    else
      CF_RPPC$SDT[it] <- "CorrReject"
  }
  else{
    if(CF_RPPC$Key_Resp[it] == "L" & CF_RPPC$Cor_Ans[it] == "L")
      CF_RPPC$SDT[it] <- "Hit"
    else if(CF_RPPC$Key_Resp[it] == "L" & CF_RPPC$Cor_Ans[it] == "A")
      CF_RPPC$SDT[it] <- "FalseAlarm"
    else if(CF_RPPC$Key_Resp[it] == "A" & CF_RPPC$Cor_Ans[it] == "L")
      CF_RPPC$SDT[it] <- "Miss"
    else
      CF_RPPC$SDT[it] <- "CorrReject"
  }
}
CF_RPPC
# Out:
#      subj Trial Cong        Alig          Key_Resp Cor_Ans Acc RT
# 1    1     1    Congruent   MissAlignment L        L       1   0.6071001
# 2    1     2    InCongruent MissAlignment A        A       1   0.6535373
# 3    1     3    InCongruent Alignment     L        L       1   0.6341857
# 4    1     4    Congruent   MissAlignment A        A       1   0.7268545
# 5    1     5    Congruent   Alignment     L        A       0   0.6975531
# 6    1     6    Congruent   MissAlignment L        L       1   0.6856608
# 7    1     7    InCongruent Alignment     A        A       1   0.6889085
# 8    1     8    Congruent   MissAlignment A        A       1   1.2445336
# 9    1     9    InCongruent MissAlignment L        L       1   0.6734251
# 10   1    10    Congruent   MissAlignment L        L       1   0.6538386
# 11   1    11    InCongruent Alignment     L        A       0   0.6262396
# 12   1    12    InCongruent Alignment     L        A       0   1.0082400
# 13   1    13    InCongruent MissAlignment L        L       1   0.8625690
# 14   1    14    Congruent   Alignment     A        A       1   0.9862165
# 15   1    15    Congruent   Alignment     A        A       1   0.9700973
# 16   1    16    Congruent   MissAlignment L        L       1   0.8671305
# 17   1    17    Congruent   Alignment     L        L       1   0.9194431
# 18   1    18    Congruent   Alignment     L        L       1   0.9216331
# 19   1    19    Congruent   MissAlignment A        A       1   0.6830399
# 20   1    20    Congruent   MissAlignment A        A       1   0.6632766
# 21   1    21    Congruent   Alignment     A        A       1   0.8916095
# 22   1    22    Congruent   Alignment     L        L       1   0.8238713
# 23   1    23    InCongruent Alignment     A        A       1   0.6858245
# 24   1    24    InCongruent MissAlignment L        L       1   0.8248129
# 25   1    25    Congruent   Alignment     L        L       1   0.5908996
# 26   1    26    InCongruent MissAlignment A        A       1   0.6865096
# 27   1    27    Congruent   Alignment     L        L       1   0.8821359
# 28   1    28    InCongruent Alignment     L        L       1   0.6613254
# 29   1    29    Congruent   Alignment     A        A       1   0.6335351
# 30   1    30    InCongruent MissAlignment A        A       1   0.7356729
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮        ⋮       ⋮   ⋮
# 5731 36   131   Congruent   MissAlignment A        A       1   0.7629079
# 5732 36   132   InCongruent Alignment     A        L       0   0.9008504
# 5733 36   133   Congruent   Alignment     L        L       1   0.7279817
# 5734 36   134   InCongruent MissAlignment L        L       1   0.6890396
# 5735 36   135   Congruent   Alignment     A        A       1   0.5317806
# 5736 36   136   Congruent   MissAlignment A        A       1   0.6696927
# 5737 36   137   InCongruent MissAlignment A        L       0   0.6425399
# 5738 36   138   InCongruent MissAlignment A        A       1   0.7277805
# 5739 36   139   Congruent   MissAlignment A        A       1   0.7778394
# 5740 36   140   Congruent   MissAlignment A        A       1   0.4974028
# 5741 36   141   Congruent   Alignment     L        L       1   0.4618160
# 5742 36   142   InCongruent Alignment     L        L       1   0.4497688
# 5743 36   143   InCongruent MissAlignment L        L       1   0.5344961
# 5744 36   144   Congruent   MissAlignment L        L       1   0.4247023
# 5745 36   145   Congruent   Alignment     L        L       1   0.4555387
# 5746 36   146   InCongruent Alignment     A        A       1   0.4600863
# 5747 36   147   InCongruent MissAlignment A        A       1   0.5206470
# 5748 36   148   InCongruent Alignment     A        A       1   0.7622851
# 5749 36   149   Congruent   MissAlignment L        L       1   0.6359229
# 5750 36   150   Congruent   Alignment     A        A       1   0.6475607
# 5751 36   151   InCongruent MissAlignment L        L       1   0.7417422
# 5752 36   152   Congruent   Alignment     A        A       1   0.4948121
# 5753 36   153   InCongruent MissAlignment L        A       0   0.7139526
# 5754 36   154   InCongruent MissAlignment A        A       1   0.4844091
# 5755 36   155   Congruent   MissAlignment L        L       1   0.5926134
# 5756 36   156   Congruent   MissAlignment L        L       1   0.6479823
# 5757 36   157   Congruent   Alignment     L        L       1   0.5737203
# 5758 36   158   Congruent   Alignment     A        A       1   0.4455220
# 5759 36   159   Congruent   Alignment     A        A       1   0.6825628
# 5760 36   160   Congruent   Alignment     L        L       1   0.5595559
#      SDT
# 1    Hit
# 2    CorrReject
# 3    Hit
# 4    CorrReject
# 5    FalseAlarm
# 6    Hit
# 7    CorrReject
# 8    CorrReject
# 9    Hit
# 10   Hit
# 11   FalseAlarm
# 12   FalseAlarm
# 13   Hit
# 14   CorrReject
# 15   CorrReject
# 16   Hit
# 17   Hit
# 18   Hit
# 19   CorrReject
# 20   CorrReject
# 21   CorrReject
# 22   Hit
# 23   CorrReject
# 24   Hit
# 25   Hit
# 26   CorrReject
# 27   Hit
# 28   Hit
# 29   CorrReject
# 30   CorrReject
# ⋮    ⋮
# 5731 CorrReject
# 5732 Miss
# 5733 Hit
# 5734 Hit
# 5735 CorrReject
# 5736 CorrReject
# 5737 Miss
# 5738 CorrReject
# 5739 CorrReject
# 5740 CorrReject
# 5741 Hit
# 5742 Hit
# 5743 Hit
# 5744 Hit
# 5745 Hit
# 5746 CorrReject
# 5747 CorrReject
# 5748 CorrReject
# 5749 Hit
# 5750 CorrReject
# 5751 Hit
# 5752 CorrReject
# 5753 FalseAlarm
# 5754 CorrReject
# 5755 Hit
# 5756 Hit
# 5757 Hit
# 5758 CorrReject
# 5759 CorrReject
# 5760 Hit

# %%
CF_RPPC <- subset (CF_RPPC, select = - Key_Resp)
CF_RPPC <- subset (CF_RPPC, select = - Cor_Ans)
#CF_CZ <- subset (CF_CZ, select = - sex)
CF_RPPC
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    Congruent   MissAlignment 1   0.6071001 Hit
# 2    1     2    InCongruent MissAlignment 1   0.6535373 CorrReject
# 3    1     3    InCongruent Alignment     1   0.6341857 Hit
# 4    1     4    Congruent   MissAlignment 1   0.7268545 CorrReject
# 5    1     5    Congruent   Alignment     0   0.6975531 FalseAlarm
# 6    1     6    Congruent   MissAlignment 1   0.6856608 Hit
# 7    1     7    InCongruent Alignment     1   0.6889085 CorrReject
# 8    1     8    Congruent   MissAlignment 1   1.2445336 CorrReject
# 9    1     9    InCongruent MissAlignment 1   0.6734251 Hit
# 10   1    10    Congruent   MissAlignment 1   0.6538386 Hit
# 11   1    11    InCongruent Alignment     0   0.6262396 FalseAlarm
# 12   1    12    InCongruent Alignment     0   1.0082400 FalseAlarm
# 13   1    13    InCongruent MissAlignment 1   0.8625690 Hit
# 14   1    14    Congruent   Alignment     1   0.9862165 CorrReject
# 15   1    15    Congruent   Alignment     1   0.9700973 CorrReject
# 16   1    16    Congruent   MissAlignment 1   0.8671305 Hit
# 17   1    17    Congruent   Alignment     1   0.9194431 Hit
# 18   1    18    Congruent   Alignment     1   0.9216331 Hit
# 19   1    19    Congruent   MissAlignment 1   0.6830399 CorrReject
# 20   1    20    Congruent   MissAlignment 1   0.6632766 CorrReject
# 21   1    21    Congruent   Alignment     1   0.8916095 CorrReject
# 22   1    22    Congruent   Alignment     1   0.8238713 Hit
# 23   1    23    InCongruent Alignment     1   0.6858245 CorrReject
# 24   1    24    InCongruent MissAlignment 1   0.8248129 Hit
# 25   1    25    Congruent   Alignment     1   0.5908996 Hit
# 26   1    26    InCongruent MissAlignment 1   0.6865096 CorrReject
# 27   1    27    Congruent   Alignment     1   0.8821359 Hit
# 28   1    28    InCongruent Alignment     1   0.6613254 Hit
# 29   1    29    Congruent   Alignment     1   0.6335351 CorrReject
# 30   1    30    InCongruent MissAlignment 1   0.7356729 CorrReject
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5731 36   131   Congruent   MissAlignment 1   0.7629079 CorrReject
# 5732 36   132   InCongruent Alignment     0   0.9008504 Miss
# 5733 36   133   Congruent   Alignment     1   0.7279817 Hit
# 5734 36   134   InCongruent MissAlignment 1   0.6890396 Hit
# 5735 36   135   Congruent   Alignment     1   0.5317806 CorrReject
# 5736 36   136   Congruent   MissAlignment 1   0.6696927 CorrReject
# 5737 36   137   InCongruent MissAlignment 0   0.6425399 Miss
# 5738 36   138   InCongruent MissAlignment 1   0.7277805 CorrReject
# 5739 36   139   Congruent   MissAlignment 1   0.7778394 CorrReject
# 5740 36   140   Congruent   MissAlignment 1   0.4974028 CorrReject
# 5741 36   141   Congruent   Alignment     1   0.4618160 Hit
# 5742 36   142   InCongruent Alignment     1   0.4497688 Hit
# 5743 36   143   InCongruent MissAlignment 1   0.5344961 Hit
# 5744 36   144   Congruent   MissAlignment 1   0.4247023 Hit
# 5745 36   145   Congruent   Alignment     1   0.4555387 Hit
# 5746 36   146   InCongruent Alignment     1   0.4600863 CorrReject
# 5747 36   147   InCongruent MissAlignment 1   0.5206470 CorrReject
# 5748 36   148   InCongruent Alignment     1   0.7622851 CorrReject
# 5749 36   149   Congruent   MissAlignment 1   0.6359229 Hit
# 5750 36   150   Congruent   Alignment     1   0.6475607 CorrReject
# 5751 36   151   InCongruent MissAlignment 1   0.7417422 Hit
# 5752 36   152   Congruent   Alignment     1   0.4948121 CorrReject
# 5753 36   153   InCongruent MissAlignment 0   0.7139526 FalseAlarm
# 5754 36   154   InCongruent MissAlignment 1   0.4844091 CorrReject
# 5755 36   155   Congruent   MissAlignment 1   0.5926134 Hit
# 5756 36   156   Congruent   MissAlignment 1   0.6479823 Hit
# 5757 36   157   Congruent   Alignment     1   0.5737203 Hit
# 5758 36   158   Congruent   Alignment     1   0.4455220 CorrReject
# 5759 36   159   Congruent   Alignment     1   0.6825628 CorrReject
# 5760 36   160   Congruent   Alignment     1   0.5595559 Hit

# %% [markdown]
# Since an accuracy above 57.5% across 160 trials is unlikely due to random behavior alone,
# according to a binomial test (p < 0.05), only participants who surpassed this threshold were
# included in the analyses.
# - binom.test(91,160,p=0.5)  ,  p_value = 0.09657
# - binom.test(92,160,p=0.5)  ,  p_value = 0.06868
# - binom.test(93,160,p=0.5)  ,  p_value = 0.04777
# - binom.test(94,160,p=0.5)  ,  p_value = 0.03247
#
# Therefore we have 92/160 = 0.575

# %%
meanAcc <- data.frame(subj = NaN, MACC = NaN)
meanAcc2 <- data.frame(subj = NaN, MACC = NaN)
for(i in 1:36){
  meanAcc$subj <- i 
  meanAcc$MACC <- mean(CF_RPPC$Acc[CF_RPPC$subj == i])
  meanAcc2 <- rbind(meanAcc2, meanAcc)
}
meanAcc2
# Out:
#    subj MACC
# 1  NaN      NaN
# 2    1  0.89375
# 3    2  0.85000
# 4    3  0.71250
# 5    4  0.91250
# 6    5  0.82500
# 7    6  0.90000
# 8    7  0.85625
# 9    8  0.89375
# 10   9  0.60000
# 11  10  0.52500
# 12  11  0.80625
# 13  12  0.88125
# 14  13  0.91250
# 15  14  0.88125
# 16  15  0.73125
# 17  16  0.91250
# 18  17  0.93125
# 19  18  0.72500
# 20  19  0.92500
# 21  20  0.95625
# 22  21  0.94375
# 23  22  0.94375
# 24  23  0.75625
# 25  24  0.92500
# 26  25  0.90625
# 27  26  0.87500
# 28  27  0.92500
# 29  28  0.97500
# 30  29  0.93125
# 31  30  0.91875
# 32  31  0.92500
# 33  32  0.90000
# 34  33  0.87500
# 35  34  0.93125
# 36  35  0.95625
# 37  36  0.91250

# %% [markdown]
# Therefore data from 1 participant (participant number = 10) was discarded because of chance performance = 0.54375.

# %%
CF_RPPC<- CF_RPPC[which(CF_RPPC$subj != 10),]
CF_RPPC
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    Congruent   MissAlignment 1   0.6071001 Hit
# 2    1     2    InCongruent MissAlignment 1   0.6535373 CorrReject
# 3    1     3    InCongruent Alignment     1   0.6341857 Hit
# 4    1     4    Congruent   MissAlignment 1   0.7268545 CorrReject
# 5    1     5    Congruent   Alignment     0   0.6975531 FalseAlarm
# 6    1     6    Congruent   MissAlignment 1   0.6856608 Hit
# 7    1     7    InCongruent Alignment     1   0.6889085 CorrReject
# 8    1     8    Congruent   MissAlignment 1   1.2445336 CorrReject
# 9    1     9    InCongruent MissAlignment 1   0.6734251 Hit
# 10   1    10    Congruent   MissAlignment 1   0.6538386 Hit
# 11   1    11    InCongruent Alignment     0   0.6262396 FalseAlarm
# 12   1    12    InCongruent Alignment     0   1.0082400 FalseAlarm
# 13   1    13    InCongruent MissAlignment 1   0.8625690 Hit
# 14   1    14    Congruent   Alignment     1   0.9862165 CorrReject
# 15   1    15    Congruent   Alignment     1   0.9700973 CorrReject
# 16   1    16    Congruent   MissAlignment 1   0.8671305 Hit
# 17   1    17    Congruent   Alignment     1   0.9194431 Hit
# 18   1    18    Congruent   Alignment     1   0.9216331 Hit
# 19   1    19    Congruent   MissAlignment 1   0.6830399 CorrReject
# 20   1    20    Congruent   MissAlignment 1   0.6632766 CorrReject
# 21   1    21    Congruent   Alignment     1   0.8916095 CorrReject
# 22   1    22    Congruent   Alignment     1   0.8238713 Hit
# 23   1    23    InCongruent Alignment     1   0.6858245 CorrReject
# 24   1    24    InCongruent MissAlignment 1   0.8248129 Hit
# 25   1    25    Congruent   Alignment     1   0.5908996 Hit
# 26   1    26    InCongruent MissAlignment 1   0.6865096 CorrReject
# 27   1    27    Congruent   Alignment     1   0.8821359 Hit
# 28   1    28    InCongruent Alignment     1   0.6613254 Hit
# 29   1    29    Congruent   Alignment     1   0.6335351 CorrReject
# 30   1    30    InCongruent MissAlignment 1   0.7356729 CorrReject
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5731 36   131   Congruent   MissAlignment 1   0.7629079 CorrReject
# 5732 36   132   InCongruent Alignment     0   0.9008504 Miss
# 5733 36   133   Congruent   Alignment     1   0.7279817 Hit
# 5734 36   134   InCongruent MissAlignment 1   0.6890396 Hit
# 5735 36   135   Congruent   Alignment     1   0.5317806 CorrReject
# 5736 36   136   Congruent   MissAlignment 1   0.6696927 CorrReject
# 5737 36   137   InCongruent MissAlignment 0   0.6425399 Miss
# 5738 36   138   InCongruent MissAlignment 1   0.7277805 CorrReject
# 5739 36   139   Congruent   MissAlignment 1   0.7778394 CorrReject
# 5740 36   140   Congruent   MissAlignment 1   0.4974028 CorrReject
# 5741 36   141   Congruent   Alignment     1   0.4618160 Hit
# 5742 36   142   InCongruent Alignment     1   0.4497688 Hit
# 5743 36   143   InCongruent MissAlignment 1   0.5344961 Hit
# 5744 36   144   Congruent   MissAlignment 1   0.4247023 Hit
# 5745 36   145   Congruent   Alignment     1   0.4555387 Hit
# 5746 36   146   InCongruent Alignment     1   0.4600863 CorrReject
# 5747 36   147   InCongruent MissAlignment 1   0.5206470 CorrReject
# 5748 36   148   InCongruent Alignment     1   0.7622851 CorrReject
# 5749 36   149   Congruent   MissAlignment 1   0.6359229 Hit
# 5750 36   150   Congruent   Alignment     1   0.6475607 CorrReject
# 5751 36   151   InCongruent MissAlignment 1   0.7417422 Hit
# 5752 36   152   Congruent   Alignment     1   0.4948121 CorrReject
# 5753 36   153   InCongruent MissAlignment 0   0.7139526 FalseAlarm
# 5754 36   154   InCongruent MissAlignment 1   0.4844091 CorrReject
# 5755 36   155   Congruent   MissAlignment 1   0.5926134 Hit
# 5756 36   156   Congruent   MissAlignment 1   0.6479823 Hit
# 5757 36   157   Congruent   Alignment     1   0.5737203 Hit
# 5758 36   158   Congruent   Alignment     1   0.4455220 CorrReject
# 5759 36   159   Congruent   Alignment     1   0.6825628 CorrReject
# 5760 36   160   Congruent   Alignment     1   0.5595559 Hit

# %%
CF_RPPC[which(CF_RPPC$RT>5),]
CF_RPPC[which(CF_RPPC$RT<0.2),]
mean(CF_RPPC$RT[CF_RPPC$subj == 1])
3*sd(CF_RPPC$RT[CF_RPPC$subj == 1])

CF_RPPC[which(CF_RPPC$subj ==1 & CF_RPPC$RT> mean(CF_RPPC$RT[CF_RPPC$subj == 1])+3*sd(CF_RPPC$RT[CF_RPPC$subj == 1])),]
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 2241 15    1    InCongruent Alignment     0    5.481688 FalseAlarm
# 2473 16   73    InCongruent Alignment     1    5.160541 Hit
# 3385 22   25    Congruent   MissAlignment 0   15.210329 FalseAlarm
# 3522 23    2    InCongruent Alignment     0    5.098813 FalseAlarm
# 3548 23   28    Congruent   MissAlignment 0    6.543187 Miss
# 3554 23   34    InCongruent MissAlignment 0    8.528904 FalseAlarm
# 3556 23   36    InCongruent Alignment     0    7.662665 Miss
# 4037 26   37    Congruent   Alignment     1    6.234092 CorrReject
# 4681 30   41    Congruent   MissAlignment 0    6.076505 FalseAlarm
#      subj Trial Cong Alig Acc RT SDT
# [1] 0.7306836
# [1] 0.5592791
#     subj Trial Cong        Alig      Acc RT       SDT
# 115 1    115   InCongruent Alignment 1   1.290093 CorrReject
# 130 1    130   Congruent   Alignment 1   1.337768 CorrReject
# 136 1    136   Congruent   Alignment 0   1.338638 FalseAlarm

# %%
#j<-0
#for(i in 1: 5760){
#  if(CF_CZ$RT[i]>1)
#    j<-j+1
#}

#CF<- CF_CZZ[which(CF_CZZ$Acc == 1 & CF_CZZ$RT <= 1),]

#OUT <- CF_CZ %>% group_by(subj) %>% identify_outliers(RT)
#OUTT <- OUT[which(OUT$is.extreme == TRUE),]

#CF_CZ_no_outlier<- CF_CZ %>% 
#  anti_join(OUTT, by = "RT") 



OUT <- CF_RPPC[which(CF_RPPC$Acc ==1 & CF_RPPC$RT>5),]

CF_RPPC_n<- CF_RPPC %>% 
  anti_join(OUT, by = "RT") 

#CF_CZ_no_outlier<- CF_CZ  



#CF_CZ_no_outlier[which(CF_CZ_no_outlier$RT>4),]

#CF_CZ_no_outlier <- CF_CZ
CF_RPPC_n

OUT
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    Congruent   MissAlignment 1   0.6071001 Hit
# 2    1     2    InCongruent MissAlignment 1   0.6535373 CorrReject
# 3    1     3    InCongruent Alignment     1   0.6341857 Hit
# 4    1     4    Congruent   MissAlignment 1   0.7268545 CorrReject
# 5    1     5    Congruent   Alignment     0   0.6975531 FalseAlarm
# 6    1     6    Congruent   MissAlignment 1   0.6856608 Hit
# 7    1     7    InCongruent Alignment     1   0.6889085 CorrReject
# 8    1     8    Congruent   MissAlignment 1   1.2445336 CorrReject
# 9    1     9    InCongruent MissAlignment 1   0.6734251 Hit
# 10   1    10    Congruent   MissAlignment 1   0.6538386 Hit
# 11   1    11    InCongruent Alignment     0   0.6262396 FalseAlarm
# 12   1    12    InCongruent Alignment     0   1.0082400 FalseAlarm
# 13   1    13    InCongruent MissAlignment 1   0.8625690 Hit
# 14   1    14    Congruent   Alignment     1   0.9862165 CorrReject
# 15   1    15    Congruent   Alignment     1   0.9700973 CorrReject
# 16   1    16    Congruent   MissAlignment 1   0.8671305 Hit
# 17   1    17    Congruent   Alignment     1   0.9194431 Hit
# 18   1    18    Congruent   Alignment     1   0.9216331 Hit
# 19   1    19    Congruent   MissAlignment 1   0.6830399 CorrReject
# 20   1    20    Congruent   MissAlignment 1   0.6632766 CorrReject
# 21   1    21    Congruent   Alignment     1   0.8916095 CorrReject
# 22   1    22    Congruent   Alignment     1   0.8238713 Hit
# 23   1    23    InCongruent Alignment     1   0.6858245 CorrReject
# 24   1    24    InCongruent MissAlignment 1   0.8248129 Hit
# 25   1    25    Congruent   Alignment     1   0.5908996 Hit
# 26   1    26    InCongruent MissAlignment 1   0.6865096 CorrReject
# 27   1    27    Congruent   Alignment     1   0.8821359 Hit
# 28   1    28    InCongruent Alignment     1   0.6613254 Hit
# 29   1    29    Congruent   Alignment     1   0.6335351 CorrReject
# 30   1    30    InCongruent MissAlignment 1   0.7356729 CorrReject
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5569 36   131   Congruent   MissAlignment 1   0.7629079 CorrReject
# 5570 36   132   InCongruent Alignment     0   0.9008504 Miss
# 5571 36   133   Congruent   Alignment     1   0.7279817 Hit
# 5572 36   134   InCongruent MissAlignment 1   0.6890396 Hit
# 5573 36   135   Congruent   Alignment     1   0.5317806 CorrReject
# 5574 36   136   Congruent   MissAlignment 1   0.6696927 CorrReject
# 5575 36   137   InCongruent MissAlignment 0   0.6425399 Miss
# 5576 36   138   InCongruent MissAlignment 1   0.7277805 CorrReject
# 5577 36   139   Congruent   MissAlignment 1   0.7778394 CorrReject
# 5578 36   140   Congruent   MissAlignment 1   0.4974028 CorrReject
# 5579 36   141   Congruent   Alignment     1   0.4618160 Hit
# 5580 36   142   InCongruent Alignment     1   0.4497688 Hit
# 5581 36   143   InCongruent MissAlignment 1   0.5344961 Hit
# 5582 36   144   Congruent   MissAlignment 1   0.4247023 Hit
# 5583 36   145   Congruent   Alignment     1   0.4555387 Hit
# 5584 36   146   InCongruent Alignment     1   0.4600863 CorrReject
# 5585 36   147   InCongruent MissAlignment 1   0.5206470 CorrReject
# 5586 36   148   InCongruent Alignment     1   0.7622851 CorrReject
# 5587 36   149   Congruent   MissAlignment 1   0.6359229 Hit
# 5588 36   150   Congruent   Alignment     1   0.6475607 CorrReject
# 5589 36   151   InCongruent MissAlignment 1   0.7417422 Hit
# 5590 36   152   Congruent   Alignment     1   0.4948121 CorrReject
# 5591 36   153   InCongruent MissAlignment 0   0.7139526 FalseAlarm
# 5592 36   154   InCongruent MissAlignment 1   0.4844091 CorrReject
# 5593 36   155   Congruent   MissAlignment 1   0.5926134 Hit
# 5594 36   156   Congruent   MissAlignment 1   0.6479823 Hit
# 5595 36   157   Congruent   Alignment     1   0.5737203 Hit
# 5596 36   158   Congruent   Alignment     1   0.4455220 CorrReject
# 5597 36   159   Congruent   Alignment     1   0.6825628 CorrReject
# 5598 36   160   Congruent   Alignment     1   0.5595559 Hit
#      subj Trial Cong        Alig      Acc RT       SDT
# 2473 16   73    InCongruent Alignment 1   5.160541 Hit
# 4037 26   37    Congruent   Alignment 1   6.234092 CorrReject

# %%
for(i in 1:36)
    if(i != 10)
    {
        OUT <- CF_RPPC_n[which(CF_RPPC_n$subj == i & (CF_RPPC_n$RT > mean(CF_RPPC_n$RT[CF_RPPC_n$subj == i]) + 
                         3 * sd(CF_RPPC_n$RT[CF_RPPC_n$subj == i]) | 
                                                  CF_RPPC_n$RT < mean(CF_RPPC_n$RT[CF_RPPC_n$subj == i]) - 
                         3 * sd(CF_RPPC_n$RT[CF_RPPC_n$subj == i]))),]
        CF_RPPC_no_outlier<- CF_RPPC_n %>% anti_join(OUT, by = "RT") 
        CF_RPPC_n <- CF_RPPC_no_outlier
    }
OUT
CF_RPPC_no_outlier
# Out:
#      subj Trial Cong        Alig          Acc RT       SDT
# 5409 36   74    InCongruent MissAlignment 1   1.367911 Hit
# 5430 36   95    Congruent   MissAlignment 1   1.252821 Hit
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    Congruent   MissAlignment 1   0.6071001 Hit
# 2    1     2    InCongruent MissAlignment 1   0.6535373 CorrReject
# 3    1     3    InCongruent Alignment     1   0.6341857 Hit
# 4    1     4    Congruent   MissAlignment 1   0.7268545 CorrReject
# 5    1     5    Congruent   Alignment     0   0.6975531 FalseAlarm
# 6    1     6    Congruent   MissAlignment 1   0.6856608 Hit
# 7    1     7    InCongruent Alignment     1   0.6889085 CorrReject
# 8    1     8    Congruent   MissAlignment 1   1.2445336 CorrReject
# 9    1     9    InCongruent MissAlignment 1   0.6734251 Hit
# 10   1    10    Congruent   MissAlignment 1   0.6538386 Hit
# 11   1    11    InCongruent Alignment     0   0.6262396 FalseAlarm
# 12   1    12    InCongruent Alignment     0   1.0082400 FalseAlarm
# 13   1    13    InCongruent MissAlignment 1   0.8625690 Hit
# 14   1    14    Congruent   Alignment     1   0.9862165 CorrReject
# 15   1    15    Congruent   Alignment     1   0.9700973 CorrReject
# 16   1    16    Congruent   MissAlignment 1   0.8671305 Hit
# 17   1    17    Congruent   Alignment     1   0.9194431 Hit
# 18   1    18    Congruent   Alignment     1   0.9216331 Hit
# 19   1    19    Congruent   MissAlignment 1   0.6830399 CorrReject
# 20   1    20    Congruent   MissAlignment 1   0.6632766 CorrReject
# 21   1    21    Congruent   Alignment     1   0.8916095 CorrReject
# 22   1    22    Congruent   Alignment     1   0.8238713 Hit
# 23   1    23    InCongruent Alignment     1   0.6858245 CorrReject
# 24   1    24    InCongruent MissAlignment 1   0.8248129 Hit
# 25   1    25    Congruent   Alignment     1   0.5908996 Hit
# 26   1    26    InCongruent MissAlignment 1   0.6865096 CorrReject
# 27   1    27    Congruent   Alignment     1   0.8821359 Hit
# 28   1    28    InCongruent Alignment     1   0.6613254 Hit
# 29   1    29    Congruent   Alignment     1   0.6335351 CorrReject
# 30   1    30    InCongruent MissAlignment 1   0.7356729 CorrReject
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5464 36   131   Congruent   MissAlignment 1   0.7629079 CorrReject
# 5465 36   132   InCongruent Alignment     0   0.9008504 Miss
# 5466 36   133   Congruent   Alignment     1   0.7279817 Hit
# 5467 36   134   InCongruent MissAlignment 1   0.6890396 Hit
# 5468 36   135   Congruent   Alignment     1   0.5317806 CorrReject
# 5469 36   136   Congruent   MissAlignment 1   0.6696927 CorrReject
# 5470 36   137   InCongruent MissAlignment 0   0.6425399 Miss
# 5471 36   138   InCongruent MissAlignment 1   0.7277805 CorrReject
# 5472 36   139   Congruent   MissAlignment 1   0.7778394 CorrReject
# 5473 36   140   Congruent   MissAlignment 1   0.4974028 CorrReject
# 5474 36   141   Congruent   Alignment     1   0.4618160 Hit
# 5475 36   142   InCongruent Alignment     1   0.4497688 Hit
# 5476 36   143   InCongruent MissAlignment 1   0.5344961 Hit
# 5477 36   144   Congruent   MissAlignment 1   0.4247023 Hit
# 5478 36   145   Congruent   Alignment     1   0.4555387 Hit
# 5479 36   146   InCongruent Alignment     1   0.4600863 CorrReject
# 5480 36   147   InCongruent MissAlignment 1   0.5206470 CorrReject
# 5481 36   148   InCongruent Alignment     1   0.7622851 CorrReject
# 5482 36   149   Congruent   MissAlignment 1   0.6359229 Hit
# 5483 36   150   Congruent   Alignment     1   0.6475607 CorrReject
# 5484 36   151   InCongruent MissAlignment 1   0.7417422 Hit
# 5485 36   152   Congruent   Alignment     1   0.4948121 CorrReject
# 5486 36   153   InCongruent MissAlignment 0   0.7139526 FalseAlarm
# 5487 36   154   InCongruent MissAlignment 1   0.4844091 CorrReject
# 5488 36   155   Congruent   MissAlignment 1   0.5926134 Hit
# 5489 36   156   Congruent   MissAlignment 1   0.6479823 Hit
# 5490 36   157   Congruent   Alignment     1   0.5737203 Hit
# 5491 36   158   Congruent   Alignment     1   0.4455220 CorrReject
# 5492 36   159   Congruent   Alignment     1   0.6825628 CorrReject
# 5493 36   160   Congruent   Alignment     1   0.5595559 Hit

# %%
boxplot(CF_RPPC_no_outlier$RT[CF_RPPC_no_outlier$Alig == "MissAlignment" & CF_RPPC_no_outlier$Acc == 1], 
        CF_RPPC_no_outlier$RT[CF_RPPC_no_outlier$Alig == "Alignment" & CF_RPPC_no_outlier$Acc == 1])

ggdensity(CF_RPPC$RT[CF_RPPC$Alig == "MissAlignment" & CF_RPPC$Acc == 1], rug = TRUE, fill = "lightgray")
ggdensity(CF_RPPC_no_outlier$RT[CF_RPPC_no_outlier$Alig == "MissAlignment" & CF_RPPC_no_outlier$Acc == 1], rug = TRUE, fill = "lightgray")
# Out:
# plot without title
# plot without title
# plot without title

# %%
CF_RPPC_sum <- data.frame(subj = 1,
                       # Cond = NaN,
                        
                        Cong = NaN,
                        Alig = NaN,
                        Acc = NaN,
                        MRT = NaN,
                        SDT = NaN,
                        NumbersOf = NaN,
                        HitRate = NaN,
                        FalseAlarmRate = NaN,
                        dPrime = NaN,
                        bias = NaN)

CF_RPPC_sum2 <- data.frame(subj = NaN,
                      #  Cond = NaN,
                        
                        Cong = NaN,
                        Alig = NaN,
                        Acc = NaN,
                        MRT = NaN,
                        SDT = NaN,
                        NumbersOf = NaN,
                        HitRate = NaN,
                        FalseAlarmRate = NaN,
                        dPrime = NaN,
                        bias = NaN)

# %%
max(1,3)
# Out:
# [1] 3

# %%
iter <- 2
for(s in 1:36)
  if(s != 10)
  for(c in c("Congruent", "InCongruent"))
    for(a in c("Alignment", "MissAlignment")){
      for(condition in 1:4){
        CF_RPPC_sum$subj <- s
        CF_RPPC_sum$Cong <- c
          CF_RPPC_sum$Alig <- a
        if(condition == 1){
          CF_RPPC_sum$SDT <- "Hit"
          #CF_CZ_sum$Cond <- "Same"
          CF_RPPC_sum$NumbersOf <- length(CF_RPPC_no_outlier$Acc[CF_RPPC_no_outlier$subj == s & 
                                                               CF_RPPC_no_outlier$Cong == c & 
                                                               CF_RPPC_no_outlier$Alig == a & 
                                                               (CF_RPPC_no_outlier$SDT == "Hit")])
          CF_RPPC_sum$Acc <- mean(CF_RPPC_no_outlier$Acc[CF_RPPC_no_outlier$subj == s & 
                                                        CF_RPPC_no_outlier$Cong == c & 
                                                        CF_RPPC_no_outlier$Alig == a & 
                                                        (CF_RPPC_no_outlier$SDT == "Hit" | CF_RPPC_no_outlier$SDT == "Miss")])
          CF_RPPC_sum$MRT <- mean(CF_RPPC_no_outlier$RT[CF_RPPC_no_outlier$subj == s & 
                                                        CF_RPPC_no_outlier$Cong == c & 
                                                        CF_RPPC_no_outlier$Alig == a & 
                                                        (CF_RPPC_no_outlier$SDT == "Hit")])
          iter <- iter + 1
        }
        else if(condition == 2){
          CF_RPPC_sum$SDT <- "Miss"
       #   CF_CZ_sum$Cond <- "Same"
          CF_RPPC_sum$NumbersOf <- length(CF_RPPC_no_outlier$Acc[CF_RPPC_no_outlier$subj == s & 
                                                               CF_RPPC_no_outlier$Cong == c & 
                                                               CF_RPPC_no_outlier$Alig == a & 
                                                               (CF_RPPC_no_outlier$SDT == "Miss")])
            CF_RPPC_sum$Acc <- NaN
          #CF_CZ_sum$Acc <- mean(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
           #                                             CF_CZ_no_outlier$Cong == c & 
           #                                             CF_CZ_no_outlier$Alig == a & 
            #                                            (CF_CZ_no_outlier$SDT == "Miss")])
          CF_RPPC_sum$MRT <- mean(CF_RPPC_no_outlier$RT[CF_RPPC_no_outlier$subj == s & 
                                                      CF_RPPC_no_outlier$Cong == c & 
                                                      CF_RPPC_no_outlier$Alig == a & 
                                                      (CF_RPPC_no_outlier$SDT == "Miss")])
          CF_RPPC_sum2$HitRate[iter - 1] <- CF_RPPC_sum2$NumbersOf[iter -1]/(CF_RPPC_sum2$NumbersOf[iter -1] + CF_RPPC_sum$NumbersOf)
          Hitrate <- CF_RPPC_sum2$HitRate[iter - 1]
          iter <- iter + 1
        }
        else if(condition == 3){
          CF_RPPC_sum$SDT <- "FalseAlarm"
      #    CF_CZ_sum$Cond <- "Different"
          CF_RPPC_sum$NumbersOf <- length(CF_RPPC_no_outlier$Acc[CF_RPPC_no_outlier$subj == s & 
                                                               CF_RPPC_no_outlier$Cong == c & 
                                                               CF_RPPC_no_outlier$Alig == a & 
                                                               (CF_RPPC_no_outlier$SDT == "FalseAlarm")])
            CF_RPPC_sum$Acc <- NaN
            
        #  CF_CZ_sum$Acc <- mean(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
         #                                              CF_CZ_no_outlier$Cong == c & 
          #                                             CF_CZ_no_outlier$Alig == a & 
           #                                            (CF_CZ_no_outlier$SDT == "FalseAlarm")])
          CF_RPPC_sum$MRT <- mean(CF_RPPC_no_outlier$RT[CF_RPPC_no_outlier$subj == s & 
                                                      CF_RPPC_no_outlier$Cong == c & 
                                                      CF_RPPC_no_outlier$Alig == a & 
                                                      (CF_RPPC_no_outlier$SDT == "FalseAlarm")])
          iter <- iter + 1
        }
        else if(condition == 4){
          CF_RPPC_sum$SDT <- "CorrReject"
     #     CF_CZ_sum$Cond <- "Different"
          CF_RPPC_sum$NumbersOf <- length(CF_RPPC_no_outlier$Acc[CF_RPPC_no_outlier$subj == s & 
                                                               CF_RPPC_no_outlier$Cong == c & 
                                                               CF_RPPC_no_outlier$Alig == a & 
                                                               (CF_RPPC_no_outlier$SDT == "CorrReject")])
          CF_RPPC_sum$Acc <- mean(CF_RPPC_no_outlier$Acc[CF_RPPC_no_outlier$subj == s & 
                                                       CF_RPPC_no_outlier$Cong == c & 
                                                       CF_RPPC_no_outlier$Alig == a & 
                                                       (CF_RPPC_no_outlier$SDT == "CorrReject" | CF_RPPC_no_outlier$SDT == "FalseAlarm")])
          CF_RPPC_sum$MRT <- mean(CF_RPPC_no_outlier$RT[CF_RPPC_no_outlier$subj == s & 
                                                      CF_RPPC_no_outlier$Cong == c & 
                                                      CF_RPPC_no_outlier$Alig == a & 
                                                      (CF_RPPC_no_outlier$SDT == "CorrReject")])
          CF_RPPC_sum2$FalseAlarmRate[iter - 3] <- CF_RPPC_sum2$NumbersOf[iter -1]/(CF_RPPC_sum2$NumbersOf[iter -1] + CF_RPPC_sum$NumbersOf)
          Falsealarmrate <- CF_RPPC_sum2$FalseAlarmRate[iter - 3]
          iter <- iter + 1
        }
        CF_RPPC_sum2 <- rbind(CF_RPPC_sum2,CF_RPPC_sum)
      }
      le<- length(CF_RPPC_no_outlier$Acc[CF_RPPC_no_outlier$subj == s & 
                                                        CF_RPPC_no_outlier$Cong == c & 
                                                        CF_RPPC_no_outlier$Alig == a ])
      if(Hitrate == 1){
          qnorm_hit <- qnorm((le-0.5)/le)
          Hitrate <- 1-1/(2*le)
      }
      else if(Hitrate == 0){
          qnorm_hit <- qnorm((0.5)/le)
          Hitrate <- 1/(2*le)
      }
      else 
          qnorm_hit <- qnorm(Hitrate)
      if(Falsealarmrate == 1){
           Falsealarmrate <- 1-1/(2*le)
          qnorm_fa <- qnorm((le-0.5)/le)
      }
      else if(Falsealarmrate == 0){
          qnorm_fa <- qnorm((0.5)/le)
          Falsealarmrate <- 1/(2*le)
      }
      else
          qnorm_fa <- qnorm(Falsealarmrate)
      #CF_CZ_sum2$dPrime[iter - 4] <- pnorm((qnorm_hit - qnorm_fa)/sqrt(2))
     CF_RPPC_sum2$dPrime[iter - 4] <- (qnorm_hit - qnorm_fa)
      CF_RPPC_sum2$bias[iter - 4] <- -0.5 * (qnorm_hit + qnorm_fa)
      #CF_RPPC_sum2$dPrime[iter - 4] <- 0.5 + sign(Hitrate - Falsealarmrate) * 
       #   (((Hitrate - Falsealarmrate)^2 + abs(Hitrate - Falsealarmrate)) / 
        #  (4 * max(Hitrate , Falsealarmrate) - 4 * Hitrate * Falsealarmrate))
    }

# %%
CF_RPPC_sum2 <- CF_RPPC_sum2[-c(1),]
CF_RPPC_sum2
# Out:
#     subj Cong        Alig          Acc       MRT       SDT        NumbersOf
# 2   1    Congruent   Alignment     1.0000000 0.6810593 Hit        20
# 3   1    Congruent   Alignment           NaN       NaN Miss        0
# 4   1    Congruent   Alignment           NaN 0.9018239 FalseAlarm  2
# 5   1    Congruent   Alignment     0.8888889 0.7823176 CorrReject 16
# 6   1    Congruent   MissAlignment 0.9000000 0.7137102 Hit        18
# 7   1    Congruent   MissAlignment       NaN 0.5195815 Miss        2
# 8   1    Congruent   MissAlignment       NaN 0.7129103 FalseAlarm  3
# 9   1    Congruent   MissAlignment 0.8500000 0.7507276 CorrReject 17
# 10  1    InCongruent Alignment     1.0000000 0.6598742 Hit        20
# 11  1    InCongruent Alignment           NaN       NaN Miss        0
# 12  1    InCongruent Alignment           NaN 0.7342015 FalseAlarm  6
# 13  1    InCongruent Alignment     0.6842105 0.7231362 CorrReject 13
# 14  1    InCongruent MissAlignment 1.0000000 0.6929848 Hit        20
# 15  1    InCongruent MissAlignment       NaN       NaN Miss        0
# 16  1    InCongruent MissAlignment       NaN 0.8417379 FalseAlarm  3
# 17  1    InCongruent MissAlignment 0.8500000 0.7544438 CorrReject 17
# 18  2    Congruent   Alignment     0.9500000 0.7337975 Hit        19
# 19  2    Congruent   Alignment           NaN 0.9631770 Miss        1
# 20  2    Congruent   Alignment           NaN 0.5747961 FalseAlarm  4
# 21  2    Congruent   Alignment     0.8000000 1.0756009 CorrReject 16
# 22  2    Congruent   MissAlignment 0.7000000 0.8415072 Hit        14
# 23  2    Congruent   MissAlignment       NaN 0.8208733 Miss        6
# 24  2    Congruent   MissAlignment       NaN 0.4751392 FalseAlarm  1
# 25  2    Congruent   MissAlignment 0.9473684 0.7770480 CorrReject 18
# 26  2    InCongruent Alignment     0.9000000 0.7135951 Hit        18
# 27  2    InCongruent Alignment           NaN 0.5523465 Miss        2
# 28  2    InCongruent Alignment           NaN 0.9099049 FalseAlarm  3
# 29  2    InCongruent Alignment     0.8421053 1.0002187 CorrReject 16
# 30  2    InCongruent MissAlignment 0.7368421 0.6973320 Hit        14
# 31  2    InCongruent MissAlignment       NaN 0.9738103 Miss        5
# ⋮   ⋮    ⋮           ⋮             ⋮         ⋮         ⋮          ⋮
# 532 35   Congruent   Alignment           NaN 0.5649322 FalseAlarm  1
# 533 35   Congruent   Alignment     0.9500000 0.5745487 CorrReject 19
# 534 35   Congruent   MissAlignment 1.0000000 0.5733711 Hit        20
# 535 35   Congruent   MissAlignment       NaN       NaN Miss        0
# 536 35   Congruent   MissAlignment       NaN 0.5826452 FalseAlarm  1
# 537 35   Congruent   MissAlignment 0.9500000 0.5630393 CorrReject 19
# 538 35   InCongruent Alignment     1.0000000 0.4991427 Hit        18
# 539 35   InCongruent Alignment           NaN       NaN Miss        0
# 540 35   InCongruent Alignment           NaN       NaN FalseAlarm  0
# 541 35   InCongruent Alignment     1.0000000 0.6086849 CorrReject 20
# 542 35   InCongruent MissAlignment 0.8500000 0.5864044 Hit        17
# 543 35   InCongruent MissAlignment       NaN 0.7161734 Miss        3
# 544 35   InCongruent MissAlignment       NaN 0.8079769 FalseAlarm  1
# 545 35   InCongruent MissAlignment 0.9500000 0.5621369 CorrReject 19
# 546 36   Congruent   Alignment     1.0000000 0.6318742 Hit        20
# 547 36   Congruent   Alignment           NaN       NaN Miss        0
# 548 36   Congruent   Alignment           NaN       NaN FalseAlarm  0
# 549 36   Congruent   Alignment     1.0000000 0.6283297 CorrReject 20
# 550 36   Congruent   MissAlignment 0.8947368 0.6122100 Hit        17
# 551 36   Congruent   MissAlignment       NaN 0.5631823 Miss        2
# 552 36   Congruent   MissAlignment       NaN 0.7869960 FalseAlarm  1
# 553 36   Congruent   MissAlignment 0.9500000 0.6579655 CorrReject 19
# 554 36   InCongruent Alignment     0.7500000 0.6672326 Hit        15
# 555 36   InCongruent Alignment           NaN 0.6954495 Miss        5
# 556 36   InCongruent Alignment           NaN 0.6193709 FalseAlarm  2
# 557 36   InCongruent Alignment     0.9000000 0.6571839 CorrReject 18
# 558 36   InCongruent MissAlignment 0.8421053 0.7068353 Hit        16
# 559 36   InCongruent MissAlignment       NaN 0.6302718 Miss        3
# 560 36   InCongruent MissAlignment       NaN 0.7139526 FalseAlarm  1
# 561 36   InCongruent MissAlignment 0.9500000 0.7109079 CorrReject 19
#     HitRate   FalseAlarmRate dPrime   bias
# 2   1.0000000 0.11111111     3.442160 -0.5004396
# 3         NaN        NaN          NaN        NaN
# 4         NaN        NaN          NaN        NaN
# 5         NaN        NaN          NaN        NaN
# 6   0.9000000 0.15000000     2.317985 -0.1225591
# 7         NaN        NaN          NaN        NaN
# 8         NaN        NaN          NaN        NaN
# 9         NaN        NaN          NaN        NaN
# 10  1.0000000 0.31578947     2.711111 -0.8760501
# 11        NaN        NaN          NaN        NaN
# 12        NaN        NaN          NaN        NaN
# 13        NaN        NaN          NaN        NaN
# 14  1.0000000 0.15000000     3.277836 -0.6024847
# 15        NaN        NaN          NaN        NaN
# 16        NaN        NaN          NaN        NaN
# 17        NaN        NaN          NaN        NaN
# 18  0.9500000 0.20000000     2.486475 -0.4016162
# 19        NaN        NaN          NaN        NaN
# 20        NaN        NaN          NaN        NaN
# 21        NaN        NaN          NaN        NaN
# 22  0.7000000 0.05263158     2.144257  0.5477279
# 23        NaN        NaN          NaN        NaN
# 24        NaN        NaN          NaN        NaN
# 25        NaN        NaN          NaN        NaN
# 26  0.9000000 0.15789474     2.284700 -0.1392018
# 27        NaN        NaN          NaN        NaN
# 28        NaN        NaN          NaN        NaN
# 29        NaN        NaN          NaN        NaN
# 30  0.7368421 0.05000000     2.278494  0.5056068
# 31        NaN        NaN          NaN        NaN
# ⋮   ⋮         ⋮              ⋮        ⋮
# 532       NaN  NaN                NaN           NaN
# 533       NaN  NaN                NaN           NaN
# 534 1.0000000 0.05           3.886256 -2.982746e-01
# 535       NaN  NaN                NaN           NaN
# 536       NaN  NaN                NaN           NaN
# 537       NaN  NaN                NaN           NaN
# 538 1.0000000 0.00           4.443039  0.000000e+00
# 539       NaN  NaN                NaN           NaN
# 540       NaN  NaN                NaN           NaN
# 541       NaN  NaN                NaN           NaN
# 542 0.8500000 0.05           2.681287  3.042101e-01
# 543       NaN  NaN                NaN           NaN
# 544       NaN  NaN                NaN           NaN
# 545       NaN  NaN                NaN           NaN
# 546 1.0000000 0.00           4.482805 -8.881784e-16
# 547       NaN  NaN                NaN           NaN
# 548       NaN  NaN                NaN           NaN
# 549       NaN  NaN                NaN           NaN
# 550 0.8947368 0.05           2.896973  1.963671e-01
# 551       NaN  NaN                NaN           NaN
# 552       NaN  NaN                NaN           NaN
# 553       NaN  NaN                NaN           NaN
# 554 0.7500000 0.10           1.956041  3.035309e-01
# 555       NaN  NaN                NaN           NaN
# 556       NaN  NaN                NaN           NaN
# 557       NaN  NaN                NaN           NaN
# 558 0.8421053 0.05           2.648002  3.208528e-01
# 559       NaN  NaN                NaN           NaN
# 560       NaN  NaN                NaN           NaN
# 561       NaN  NaN                NaN           NaN

# %%
CF_RPPC_sum_dprime <- CF_RPPC_sum2[which(CF_RPPC_sum2$dPrime != "NaN"),]
#CF_CZ_sum_dprime <- CF_CZ_sum2[which(CF_CZ_sum2$dPrime != "NaN" & CF_CZ_sum2$dPrime != "Inf"),]

# %%
CF_RPPC_sum_dprime
# Out:
#     subj Cong        Alig          Acc       MRT       SDT NumbersOf HitRate
# 2   1    Congruent   Alignment     1.0000000 0.6810593 Hit 20        1.0000000
# 6   1    Congruent   MissAlignment 0.9000000 0.7137102 Hit 18        0.9000000
# 10  1    InCongruent Alignment     1.0000000 0.6598742 Hit 20        1.0000000
# 14  1    InCongruent MissAlignment 1.0000000 0.6929848 Hit 20        1.0000000
# 18  2    Congruent   Alignment     0.9500000 0.7337975 Hit 19        0.9500000
# 22  2    Congruent   MissAlignment 0.7000000 0.8415072 Hit 14        0.7000000
# 26  2    InCongruent Alignment     0.9000000 0.7135951 Hit 18        0.9000000
# 30  2    InCongruent MissAlignment 0.7368421 0.6973320 Hit 14        0.7368421
# 34  3    Congruent   Alignment     0.8000000 1.1824445 Hit 16        0.8000000
# 38  3    Congruent   MissAlignment 0.7894737 1.1499775 Hit 15        0.7894737
# 42  3    InCongruent Alignment     0.7222222 1.1885676 Hit 13        0.7222222
# 46  3    InCongruent MissAlignment 0.5500000 1.3451776 Hit 11        0.5500000
# 50  4    Congruent   Alignment     0.9473684 0.8904892 Hit 18        0.9473684
# 54  4    Congruent   MissAlignment 1.0000000 1.0598330 Hit 20        1.0000000
# 58  4    InCongruent Alignment     0.7894737 0.8405324 Hit 15        0.7894737
# 62  4    InCongruent MissAlignment 0.9473684 0.9848471 Hit 18        0.9473684
# 66  5    Congruent   Alignment     0.7500000 0.5457415 Hit 15        0.7500000
# 70  5    Congruent   MissAlignment 0.7500000 0.6345177 Hit 15        0.7500000
# 74  5    InCongruent Alignment     0.7000000 0.6660932 Hit 14        0.7000000
# 78  5    InCongruent MissAlignment 0.6111111 0.7584813 Hit 11        0.6111111
# 82  6    Congruent   Alignment     0.8500000 0.5300975 Hit 17        0.8500000
# 86  6    Congruent   MissAlignment 0.8000000 0.6448788 Hit 16        0.8000000
# 90  6    InCongruent Alignment     0.9000000 0.6168661 Hit 18        0.9000000
# 94  6    InCongruent MissAlignment 0.8000000 0.6129591 Hit 16        0.8000000
# 98  7    Congruent   Alignment     0.9000000 0.6540330 Hit 18        0.9000000
# 102 7    Congruent   MissAlignment 0.7368421 0.7898496 Hit 14        0.7368421
# 106 7    InCongruent Alignment     0.9000000 0.7974512 Hit 18        0.9000000
# 110 7    InCongruent MissAlignment 0.8500000 0.8039596 Hit 17        0.8500000
# 114 8    Congruent   Alignment     0.9000000 0.6076341 Hit 18        0.9000000
# 118 8    Congruent   MissAlignment 1.0000000 0.7534059 Hit 20        1.0000000
# ⋮   ⋮    ⋮           ⋮             ⋮         ⋮         ⋮   ⋮         ⋮
# 442 29   InCongruent Alignment     0.8500000 0.7024886 Hit 17        0.8500000
# 446 29   InCongruent MissAlignment 0.9500000 0.6551287 Hit 19        0.9500000
# 450 30   Congruent   Alignment     1.0000000 0.5174688 Hit 20        1.0000000
# 454 30   Congruent   MissAlignment 0.9000000 0.5172002 Hit 18        0.9000000
# 458 30   InCongruent Alignment     0.9500000 0.5515208 Hit 19        0.9500000
# 462 30   InCongruent MissAlignment 0.8500000 0.5171511 Hit 17        0.8500000
# 466 31   Congruent   Alignment     1.0000000 0.5102685 Hit 20        1.0000000
# 470 31   Congruent   MissAlignment 0.9500000 0.5414328 Hit 19        0.9500000
# 474 31   InCongruent Alignment     0.9000000 0.5297764 Hit 18        0.9000000
# 478 31   InCongruent MissAlignment 0.9500000 0.5711761 Hit 19        0.9500000
# 482 32   Congruent   Alignment     1.0000000 0.6200003 Hit 20        1.0000000
# 486 32   Congruent   MissAlignment 0.9500000 0.6275718 Hit 19        0.9500000
# 490 32   InCongruent Alignment     0.9000000 0.7010587 Hit 18        0.9000000
# 494 32   InCongruent MissAlignment 0.8947368 0.7250000 Hit 17        0.8947368
# 498 33   Congruent   Alignment     0.8500000 0.5698607 Hit 17        0.8500000
# 502 33   Congruent   MissAlignment 0.7000000 0.6154968 Hit 14        0.7000000
# 506 33   InCongruent Alignment     0.8500000 0.6081657 Hit 17        0.8500000
# 510 33   InCongruent MissAlignment 0.8500000 0.6027416 Hit 17        0.8500000
# 514 34   Congruent   Alignment     1.0000000 0.5890851 Hit 20        1.0000000
# 518 34   Congruent   MissAlignment 1.0000000 0.6782475 Hit 19        1.0000000
# 522 34   InCongruent Alignment     0.7894737 0.7401963 Hit 15        0.7894737
# 526 34   InCongruent MissAlignment 0.8421053 0.6653947 Hit 16        0.8421053
# 530 35   Congruent   Alignment     1.0000000 0.5000790 Hit 20        1.0000000
# 534 35   Congruent   MissAlignment 1.0000000 0.5733711 Hit 20        1.0000000
# 538 35   InCongruent Alignment     1.0000000 0.4991427 Hit 18        1.0000000
# 542 35   InCongruent MissAlignment 0.8500000 0.5864044 Hit 17        0.8500000
# 546 36   Congruent   Alignment     1.0000000 0.6318742 Hit 20        1.0000000
# 550 36   Congruent   MissAlignment 0.8947368 0.6122100 Hit 17        0.8947368
# 554 36   InCongruent Alignment     0.7500000 0.6672326 Hit 15        0.7500000
# 558 36   InCongruent MissAlignment 0.8421053 0.7068353 Hit 16        0.8421053
#     FalseAlarmRate dPrime    bias
# 2   0.11111111     3.4421599 -0.50043962
# 6   0.15000000     2.3179850 -0.12255909
# 10  0.31578947     2.7111115 -0.87605009
# 14  0.15000000     3.2778361 -0.60248467
# 18  0.20000000     2.4864749 -0.40161620
# 22  0.05263158     2.1442568  0.54772787
# 26  0.15789474     2.2846995 -0.13920180
# 30  0.05000000     2.2784936  0.50560681
# 34  0.15000000     1.8780546  0.09740608
# 38  0.25000000     1.4790861 -0.06505332
# 42  0.45000000     0.7151171 -0.23189723
# 46  0.25000000     0.8001511  0.27441420
# 50  0.05000000     3.2647099  0.01249868
# 54  0.10000000     3.5229543 -0.47992558
# 58  0.10526316     2.0567159  0.22376157
# 62  0.10526316     2.8719758 -0.18386837
# 66  0.00000000     2.9158925  0.78345649
# 70  0.00000000     2.9158925  0.78345649
# 74  0.10526316     1.7765200  0.36385950
# 78  0.10000000     1.5637677  0.49966771
# 82  0.05000000     2.6812870  0.30421012
# 86  0.05263158     2.4614775  0.38911751
# 90  0.00000000     3.5131574  0.47502713
# 94  0.05000000     2.4864749  0.40161620
# 98  0.05000000     2.9264052  0.18165103
# 102 0.15789474     1.6367880  0.18475398
# 106 0.21052632     2.0861479 -0.23847759
# 110 0.10526316     2.2885529  0.10784307
# 114 0.00000000     3.5131574  0.47502713
# 118 0.11111111     3.4421599 -0.50043962
# ⋮   ⋮              ⋮         ⋮
# 442 0.15789474     2.039581  -1.664271e-02
# 446 0.05882353     3.209580  -4.006358e-02
# 450 0.00000000     4.482805  -8.881784e-16
# 454 0.15789474     2.284700  -1.392018e-01
# 458 0.05000000     3.289707   5.551115e-16
# 462 0.10000000     2.317985   1.225591e-01
# 466 0.15000000     3.277836  -6.024847e-01
# 470 0.00000000     3.876459   2.933761e-01
# 474 0.10000000     2.563103   0.000000e+00
# 478 0.15789474     2.648002  -3.208528e-01
# 482 0.15000000     3.277836  -6.024847e-01
# 486 0.10526316     2.896973  -1.963671e-01
# 490 0.25000000     1.956041  -3.035309e-01
# 494 0.05263158     2.871976   1.838684e-01
# 498 0.05000000     2.681287   3.042101e-01
# 502 0.00000000     2.765803   8.585011e-01
# 506 0.10000000     2.317985   1.225591e-01
# 510 0.10526316     2.288553   1.078431e-01
# 514 0.10000000     3.522954  -4.799256e-01
# 518 0.00000000     4.463212  -6.661338e-16
# 522 0.00000000     3.036202   7.135047e-01
# 526 0.00000000     3.214275   6.039896e-01
# 530 0.05000000     3.886256  -2.982746e-01
# 534 0.05000000     3.886256  -2.982746e-01
# 538 0.00000000     4.443039   0.000000e+00
# 542 0.05000000     2.681287   3.042101e-01
# 546 0.00000000     4.482805  -8.881784e-16
# 550 0.05000000     2.896973   1.963671e-01
# 554 0.10000000     1.956041   3.035309e-01
# 558 0.05000000     2.648002   3.208528e-01

# %%
#save(CF_RPPC_sum_dprime,file="CF_RPPC_sum_dprime.Rda")

# %%
CF_RPPC_sum_dprime %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(dPrime, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean  sd
# 1 Congruent   Alignment     dPrime   35 3.304 0.650
# 2 Congruent   MissAlignment dPrime   35 2.907 0.914
# 3 InCongruent Alignment     dPrime   35 2.440 1.080
# 4 InCongruent MissAlignment dPrime   35 2.448 1.053

# %%
# dd <- CF_RPPC_sum_dprime[which(CF_RPPC_sum_dprime$dPrime<=0.6),]

# #qnorm(0.65) - qnorm(0.85)

# CF_RPPC_sum_dprime2<- CF_RPPC_sum_dprime %>% 
#   anti_join(dd, by = "dPrime") 
# CF_RPPC_sum_dprime2[which(CF_RPPC_sum_dprime2$dPrime<=0.6),]

# %%
# CF_RPPC_sum_dprime2 %>%
#   group_by(Cong, Alig) %>%
#   get_summary_stats(dPrime, type = "mean_sd")

# %%
# ggdensity(CF_RPPC_sum_dprime2$dPrime[CF_RPPC_sum_dprime2$Cong == "InCongruent" & 
#                                             CF_RPPC_sum_dprime2$Alig == "Alignment" ], rug = TRUE, fill = "lightgray")

# %%
ggdensity(CF_RPPC_sum_dprime, x = "dPrime",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
# CF_RPPC_sum_dprime2 %>%
#   group_by(Cong, Alig) %>%
#   get_summary_stats(dPrime, type = "mean_sd")

# %%
CF_RPPC_sum_dprime %>% group_by(Cong, Alig) %>% shapiro_test(dPrime)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     dPrime   0.9591188 0.21512995
# 2 Congruent   MissAlignment dPrime   0.9649437 0.31993764
# 3 InCongruent Alignment     dPrime   0.9686313 0.40676686
# 4 InCongruent MissAlignment dPrime   0.9244818 0.01923481

# %%
ggqqplot(CF_RPPC_sum_dprime, "dPrime", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_RPPC_sum_dprime, x = "Alig", y = "dPrime",
  color = "Cong", palette = "jco", 
    #outlier.shape = NA, 
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
CF_RPPC_sum_dprime %>%
  group_by(Cong, Alig) %>%
  identify_outliers(dPrime)
# Out:
#   Cong        Alig          subj Acc  MRT       SDT NumbersOf HitRate
# 1 Congruent   Alignment      3   0.80 1.1824445 Hit 16        0.80
# 2 Congruent   Alignment     15   0.90 0.7180838 Hit 18        0.90
# 3 Congruent   Alignment     21   1.00 0.4807577 Hit 20        1.00
# 4 Congruent   Alignment     28   1.00 0.5833067 Hit 20        1.00
# 5 Congruent   Alignment     30   1.00 0.5174688 Hit 20        1.00
# 6 Congruent   Alignment     36   1.00 0.6318742 Hit 20        1.00
# 7 InCongruent Alignment      9   0.75 0.6524614 Hit 15        0.75
# 8 InCongruent Alignment     18   0.50 0.7248585 Hit 10        0.50
# 9 InCongruent MissAlignment  9   0.35 0.7129705 Hit  7        0.35
#   FalseAlarmRate dPrime     bias          is.outlier is.extreme
# 1 0.1500000       1.8780546  9.740608e-02 TRUE       FALSE
# 2 0.2500000       1.9560413 -3.035309e-01 TRUE       FALSE
# 3 0.0000000       4.4632117 -6.661338e-16 TRUE       FALSE
# 4 0.0000000       4.4828055 -8.881784e-16 TRUE       FALSE
# 5 0.0000000       4.4828055 -8.881784e-16 TRUE       FALSE
# 6 0.0000000       4.4828055 -8.881784e-16 TRUE       FALSE
# 7 0.7000000       0.1500892 -5.994451e-01 TRUE       FALSE
# 8 0.7000000      -0.5244005 -2.622003e-01 TRUE       FALSE
# 9 0.7647059      -1.1068428 -1.681009e-01 TRUE        TRUE

# %%
dd <- CF_RPPC_sum_dprime %>%
  group_by(Cong, Alig) %>%
  identify_outliers(dPrime)

#dd <- dd[which(dd$is.extreme == TRUE),]

#qnorm(0.65) - qnorm(0.85)

CF_RPPC_sum_dprime2<- CF_RPPC_sum_dprime %>% 
  anti_join(dd, by = "dPrime") 

CF_RPPC_sum_dprime2 %>%
  group_by(Cong, Alig) %>%
  identify_outliers(dPrime)

bxp <- ggboxplot(
  CF_RPPC_sum_dprime2, x = "Alig", y = "dPrime",
  color = "Cong", palette = "jco", 
  #facet.by = "group", short.panel.labs = FALSE
) 
bxp
# Out:
#      Cong Alig subj Acc MRT SDT NumbersOf HitRate FalseAlarmRate dPrime bias
#      is.outlier is.extreme
# plot without title

# %%
CF_RPPC_sum_dprime2 %>% group_by(Cong, Alig) %>% shapiro_test(dPrime)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     dPrime   0.9359921 0.07876253
# 2 Congruent   MissAlignment dPrime   0.9624193 0.30213712
# 3 InCongruent Alignment     dPrime   0.9917171 0.99710564
# 4 InCongruent MissAlignment dPrime   0.9613655 0.28238015

# %%
ggqqplot(CF_RPPC_sum_dprime2, "dPrime", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
#save(CF_RPPC_sum_dprime4,file="CF_RPPC_sum_dprime4.Rda")

# %%
res.aov <- anova_test(
  data = CF_RPPC_sum_dprime2, dv = dPrime, wid = subj,
  within = c(Cong, Alig)
)
get_anova_table(res.aov)
# Out:
#   Effect    DFn DFd F      p        p<.05 ges
# 1 Cong      1   22  21.471 0.000128 *     0.146
# 2 Alig      1   22   3.176 0.089000       0.023
# 3 Cong:Alig 1   22   0.915 0.349000       0.006

# %%
one.way <- CF_RPPC_sum_dprime2 %>%
  group_by(Cong) %>%
  anova_test(dv = dPrime, wid = subj, within = Alig) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way
# Out:
#   Cong        Effect DFn DFd F     p     p<.05 ges   p.adj
# 1 Congruent   Alig   1   26  7.999 0.009 *     0.069 0.018
# 2 InCongruent Alig   1   28  0.733 0.399       0.006 0.798

# %%
one.way2 <- CF_RPPC_sum_dprime2 %>%
  group_by(Alig) %>%
  anova_test(dv = dPrime, wid = subj, within = Cong) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way2
# Out:
#   Alig          Effect DFn DFd F      p        p<.05 ges   p.adj
# 1 Alignment     Cong   1   25  17.295 0.000329 *     0.211 0.000658
# 2 MissAlignment Cong   1   30  11.098 0.002000 *     0.061 0.004000

# %% [markdown]
# # Bias

# %%
#CF_CZ_sum_bias <- CF_CZ_sum2[which(CF_CZ_sum2$bias != "NaN"),]
#CF_CZ_sum_bias
CF_RPPC_sum_bias <- CF_RPPC_sum_dprime2

# %%
CF_RPPC_sum_bias %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(bias, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean   sd
# 1 Congruent   Alignment     bias     29 -0.224 0.402
# 2 Congruent   MissAlignment bias     33  0.031 0.396
# 3 InCongruent Alignment     bias     30 -0.127 0.389
# 4 InCongruent MissAlignment bias     33  0.097 0.436

# %%
ggdensity(CF_RPPC_sum_bias, x = "bias",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_RPPC_sum_bias, x = "Alig", y = "bias",
  color = "Cong", palette = "jco", outlier.shape = NA, 
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
CF_RPPC_sum_bias %>% group_by(Cong, Alig) %>% shapiro_test(bias)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     bias     0.9311063 0.05876572
# 2 Congruent   MissAlignment bias     0.9594777 0.24983466
# 3 InCongruent Alignment     bias     0.9800037 0.82565164
# 4 InCongruent MissAlignment bias     0.9692293 0.45920782

# %%
ggqqplot(CF_RPPC_sum_bias, "bias", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
#save(CF_RPPC_sum_bias,file="CF_RPPC_sum_bias.Rda")

# %%
CF_RPPC_sum_bias %>%
  group_by(Cong, Alig) %>%
  identify_outliers(bias)
# Out:
#   Cong      Alig      subj Acc  MRT       SDT NumbersOf HitRate FalseAlarmRate
# 1 Congruent Alignment 5    0.75 0.5457415 Hit 15        0.75    0
#   dPrime   bias      is.outlier is.extreme
# 1 2.915892 0.7834565 TRUE       FALSE

# %%
res.aov <- anova_test(
  data = CF_RPPC_sum_bias, dv = bias, wid = subj,
  within = c(Cong, Alig)
)
get_anova_table(res.aov)
# Out:
#   Effect    DFn DFd F     p     p<.05 ges
# 1 Cong      1   22  0.017 0.896       9.88e-05
# 2 Alig      1   22  9.184 0.006 *     1.04e-01
# 3 Cong:Alig 1   22  0.053 0.821       2.66e-04

# %%
one.way <- CF_RPPC_sum_bias %>%
  group_by(Cong) %>%
  anova_test(dv = dPrime, wid = subj, within = Alig) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way
# Out:
#   Cong        Effect DFn DFd F     p     p<.05 ges   p.adj
# 1 Congruent   Alig   1   26  7.999 0.009 *     0.069 0.018
# 2 InCongruent Alig   1   28  0.733 0.399       0.006 0.798

# %%
# comparisons for Alig variable
one.way2 <- CF_RPPC_sum_bias %>%
  group_by(Alig) %>%
  anova_test(dv = dPrime, wid = subj, within = Cong) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way2
# Out:
#   Alig          Effect DFn DFd F      p        p<.05 ges   p.adj
# 1 Alignment     Cong   1   25  17.295 0.000329 *     0.211 0.000658
# 2 MissAlignment Cong   1   30  11.098 0.002000 *     0.061 0.004000

# %%
bxp <- ggboxplot(
  CF_RPPC_sum_bias, x = "Alig", y = "bias",
  #color = "Cong", palette = "jco", outlier.shape = NA, 
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %% [markdown]
# # RT

# %%
CF_RPPC_no_outlier[which(CF_RPPC_no_outlier$Acc == 1),]

#CF_CZ_sum_dprime2[which(CF_CZ_sum_dprime2$MRT != "NaN"),]

#CF_CZ_sum_RT <- CF_CZ_sum2[which(CF_CZ_sum2$MRT != "NaN"),]
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    Congruent   MissAlignment 1   0.6071001 Hit
# 2    1     2    InCongruent MissAlignment 1   0.6535373 CorrReject
# 3    1     3    InCongruent Alignment     1   0.6341857 Hit
# 4    1     4    Congruent   MissAlignment 1   0.7268545 CorrReject
# 6    1     6    Congruent   MissAlignment 1   0.6856608 Hit
# 7    1     7    InCongruent Alignment     1   0.6889085 CorrReject
# 8    1     8    Congruent   MissAlignment 1   1.2445336 CorrReject
# 9    1     9    InCongruent MissAlignment 1   0.6734251 Hit
# 10   1    10    Congruent   MissAlignment 1   0.6538386 Hit
# 13   1    13    InCongruent MissAlignment 1   0.8625690 Hit
# 14   1    14    Congruent   Alignment     1   0.9862165 CorrReject
# 15   1    15    Congruent   Alignment     1   0.9700973 CorrReject
# 16   1    16    Congruent   MissAlignment 1   0.8671305 Hit
# 17   1    17    Congruent   Alignment     1   0.9194431 Hit
# 18   1    18    Congruent   Alignment     1   0.9216331 Hit
# 19   1    19    Congruent   MissAlignment 1   0.6830399 CorrReject
# 20   1    20    Congruent   MissAlignment 1   0.6632766 CorrReject
# 21   1    21    Congruent   Alignment     1   0.8916095 CorrReject
# 22   1    22    Congruent   Alignment     1   0.8238713 Hit
# 23   1    23    InCongruent Alignment     1   0.6858245 CorrReject
# 24   1    24    InCongruent MissAlignment 1   0.8248129 Hit
# 25   1    25    Congruent   Alignment     1   0.5908996 Hit
# 26   1    26    InCongruent MissAlignment 1   0.6865096 CorrReject
# 27   1    27    Congruent   Alignment     1   0.8821359 Hit
# 28   1    28    InCongruent Alignment     1   0.6613254 Hit
# 29   1    29    Congruent   Alignment     1   0.6335351 CorrReject
# 30   1    30    InCongruent MissAlignment 1   0.7356729 CorrReject
# 31   1    31    InCongruent MissAlignment 1   0.8810300 Hit
# 32   1    32    InCongruent Alignment     1   1.0676757 CorrReject
# 33   1    33    Congruent   MissAlignment 1   0.5996929 Hit
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5461 36   128   InCongruent Alignment     1   0.4950380 Hit
# 5462 36   129   InCongruent Alignment     1   0.5460191 CorrReject
# 5463 36   130   InCongruent Alignment     1   0.7305303 Hit
# 5464 36   131   Congruent   MissAlignment 1   0.7629079 CorrReject
# 5466 36   133   Congruent   Alignment     1   0.7279817 Hit
# 5467 36   134   InCongruent MissAlignment 1   0.6890396 Hit
# 5468 36   135   Congruent   Alignment     1   0.5317806 CorrReject
# 5469 36   136   Congruent   MissAlignment 1   0.6696927 CorrReject
# 5471 36   138   InCongruent MissAlignment 1   0.7277805 CorrReject
# 5472 36   139   Congruent   MissAlignment 1   0.7778394 CorrReject
# 5473 36   140   Congruent   MissAlignment 1   0.4974028 CorrReject
# 5474 36   141   Congruent   Alignment     1   0.4618160 Hit
# 5475 36   142   InCongruent Alignment     1   0.4497688 Hit
# 5476 36   143   InCongruent MissAlignment 1   0.5344961 Hit
# 5477 36   144   Congruent   MissAlignment 1   0.4247023 Hit
# 5478 36   145   Congruent   Alignment     1   0.4555387 Hit
# 5479 36   146   InCongruent Alignment     1   0.4600863 CorrReject
# 5480 36   147   InCongruent MissAlignment 1   0.5206470 CorrReject
# 5481 36   148   InCongruent Alignment     1   0.7622851 CorrReject
# 5482 36   149   Congruent   MissAlignment 1   0.6359229 Hit
# 5483 36   150   Congruent   Alignment     1   0.6475607 CorrReject
# 5484 36   151   InCongruent MissAlignment 1   0.7417422 Hit
# 5485 36   152   Congruent   Alignment     1   0.4948121 CorrReject
# 5487 36   154   InCongruent MissAlignment 1   0.4844091 CorrReject
# 5488 36   155   Congruent   MissAlignment 1   0.5926134 Hit
# 5489 36   156   Congruent   MissAlignment 1   0.6479823 Hit
# 5490 36   157   Congruent   Alignment     1   0.5737203 Hit
# 5491 36   158   Congruent   Alignment     1   0.4455220 CorrReject
# 5492 36   159   Congruent   Alignment     1   0.6825628 CorrReject
# 5493 36   160   Congruent   Alignment     1   0.5595559 Hit

# %%
CF_RPPC_sum <- data.frame(subj = 1,
                       # Cond = NaN,
                        Cong = NaN,
                        Alig = NaN,
                        MRT = NaN
                        )

CF_RPPC_sum2 <- data.frame(subj = NaN,
                      #  Cond = NaN,
                        Cong = NaN,
                        Alig = NaN,
                        MRT = NaN
                        )

# %%
iter <- 2
for(s in 1:36)
  if(s != 10)
  for(c in c("Congruent", "InCongruent"))
    for(a in c("Alignment", "MissAlignment")){
        CF_RPPC_sum$subj <- s
        CF_RPPC_sum$Cong <- c
        CF_RPPC_sum$Alig <- a
        CF_RPPC_sum$MRT <- mean(CF_RPPC_no_outlier$RT[CF_RPPC_no_outlier$subj == s & 
                                                        CF_RPPC_no_outlier$Cong == c & 
                                                        CF_RPPC_no_outlier$Alig == a  
                                                        ])
        iter <- iter + 1
        
        
        CF_RPPC_sum2 <- rbind(CF_RPPC_sum2,CF_RPPC_sum)

    }

# %%
CF_RPPC_sum_RT <- CF_RPPC_sum2

CF_RPPC_sum_RT <- CF_RPPC_sum_RT[-c(1),]

# %%
CF_RPPC_sum_RT
# Out:
#     subj Cong        Alig          MRT
# 2   1    Congruent   Alignment     0.7353136
# 3   1    Congruent   MissAlignment 0.7196762
# 4   1    InCongruent Alignment     0.6923965
# 5   1    InCongruent MissAlignment 0.7302614
# 6   2    Congruent   Alignment     0.8603532
# 7   2    Congruent   MissAlignment 0.7991883
# 8   2    InCongruent Alignment     0.8380159
# 9   2    InCongruent MissAlignment 0.8419624
# 10  3    Congruent   Alignment     1.2097507
# 11  3    Congruent   MissAlignment 1.1843659
# 12  3    InCongruent Alignment     1.1327156
# 13  3    InCongruent MissAlignment 1.2114605
# 14  4    Congruent   Alignment     0.8873328
# 15  4    Congruent   MissAlignment 1.0895393
# 16  4    InCongruent Alignment     1.0188900
# 17  4    InCongruent MissAlignment 1.0435991
# 18  5    Congruent   Alignment     0.5723146
# 19  5    Congruent   MissAlignment 0.6246597
# 20  5    InCongruent Alignment     0.6487797
# 21  5    InCongruent MissAlignment 0.6569557
# 22  6    Congruent   Alignment     0.6432446
# 23  6    Congruent   MissAlignment 0.6840286
# 24  6    InCongruent Alignment     0.6951024
# 25  6    InCongruent MissAlignment 0.6969345
# 26  7    Congruent   Alignment     0.7319739
# 27  7    Congruent   MissAlignment 0.7995928
# 28  7    InCongruent Alignment     0.8673935
# 29  7    InCongruent MissAlignment 0.8189090
# 30  8    Congruent   Alignment     0.6947909
# 31  8    Congruent   MissAlignment 0.8375527
# ⋮   ⋮    ⋮           ⋮             ⋮
# 112 29   InCongruent Alignment     0.7258476
# 113 29   InCongruent MissAlignment 0.6981951
# 114 30   Congruent   Alignment     0.5379858
# 115 30   Congruent   MissAlignment 0.5278045
# 116 30   InCongruent Alignment     0.5616965
# 117 30   InCongruent MissAlignment 0.5746926
# 118 31   Congruent   Alignment     0.5280588
# 119 31   Congruent   MissAlignment 0.5357587
# 120 31   InCongruent Alignment     0.5261868
# 121 31   InCongruent MissAlignment 0.5713789
# 122 32   Congruent   Alignment     0.6810738
# 123 32   Congruent   MissAlignment 0.7097176
# 124 32   InCongruent Alignment     0.7233417
# 125 32   InCongruent MissAlignment 0.7427569
# 126 33   Congruent   Alignment     0.6373782
# 127 33   Congruent   MissAlignment 0.6728614
# 128 33   InCongruent Alignment     0.6307286
# 129 33   InCongruent MissAlignment 0.6649845
# 130 34   Congruent   Alignment     0.6786704
# 131 34   Congruent   MissAlignment 0.6993980
# 132 34   InCongruent Alignment     0.7925140
# 133 34   InCongruent MissAlignment 0.6810476
# 134 35   Congruent   Alignment     0.5370734
# 135 35   Congruent   MissAlignment 0.5686954
# 136 35   InCongruent Alignment     0.5567965
# 137 35   InCongruent MissAlignment 0.5901493
# 138 36   Congruent   Alignment     0.6301019
# 139 36   Congruent   MissAlignment 0.6364686
# 140 36   InCongruent Alignment     0.6638447
# 141 36   InCongruent MissAlignment 0.7031124

# %%
length(CF_RPPC_sum_dprime$MRT)
length(CF_RPPC_sum_RT$MRT)
# Out:
# [1] 140
# [1] 140

# %%
CF_RPPC_sum_dprime$MRT <- CF_RPPC_sum_RT$MRT

# %%
#install.packages("writexl")
library("writexl")
write_xlsx(CF_RPPC_sum_dprime,"/Users/j.amanirad/Desktop/CompositeFace/CF_RPPC_sum_DP.xlsx")

# %%
CF_RPPC_sum_RT %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(MRT, type = "mean_sd")

# %%
ggdensity(CF_RPPC_sum_RT, x = "MRT",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")

# %%
CF_RPPC_sum_RT %>%
  group_by(Cong, Alig) %>%
  identify_outliers(MRT)

# %%
CF_RPPC_sum_RT %>% group_by(Cong, Alig) %>% shapiro_test(MRT)

# %%
ggqqplot(CF_RPPC_sum_RT, "MRT", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")

# %%
bxp <- ggboxplot(
  CF_RPPC_sum_RT, x = "Alig", y = "MRT",
  color = "Cong", palette = "jco",
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp

# %%
dd <- CF_RPPC_sum_RT %>%
  group_by(Cong, Alig) %>%
  identify_outliers(MRT)

#dd <- dd[which(dd$is.extreme == TRUE),]

#qnorm(0.65) - qnorm(0.85)

CF_RPPC_sum_RT2<- CF_RPPC_sum_RT %>% 
  anti_join(dd, by = "MRT") 

CF_RPPC_sum_RT2 %>%
  group_by(Cong, Alig) %>%
  identify_outliers(MRT)

bxp <- ggboxplot(
  CF_RPPC_sum_RT2, x = "Alig", y = "MRT",
  color = "Cong", palette = "jco", 
  #facet.by = "group", short.panel.labs = FALSE
) 
bxp

# %%
CF_RPPC_sum_RT2 %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(MRT, type = "mean_sd")

# %%
ggdensity(CF_RPPC_sum_RT2, x = "MRT",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")

# %%
CF_RPPC_sum_RT2 %>% group_by(Cong, Alig) %>% shapiro_test(MRT)

# %%
ggqqplot(CF_RPPC_sum_RT2, "MRT", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")

# %%
#save(CF_RPPC_sum_RT3,file="CF_RPPC_sum_RT3.Rda")

# %%
#t2way(dPrime ~ Cong*Alig, data = CF_CZ_sum_dprime)
#bwtrim(MRT ~ Cong*Alig, id = subj, data = CF_CZ_sum_RT)

# %%
#res.Co <- CF_CZ_sum_RT %>% group_by(Alig) %>% friedman_test(MRT ~ Cong |subj)
#res.Co

# %%
#res.Alig <- CF_CZ_sum_RT %>% group_by(Cong) %>% friedman_test(MRT ~ Alig |subj)
#res.Alig

# %%
res.aov <- anova_test(
  data = CF_RPPC_sum_RT2, dv = MRT, wid = subj,
  within = c(Cong, Alig)
)
get_anova_table(res.aov)

# %%
one.way <- CF_RPPC_sum_RT2 %>%
  group_by(Alig) %>%
  anova_test(dv = MRT, wid = subj, within = Cong) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way

# %%
one.way2 <- CF_RPPC_sum_RT2 %>%
  group_by(Cong) %>%
  anova_test(dv = MRT, wid = subj, within = Alig) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way2
