# %% [markdown]
# # Composite Face: LPPC

# %%
library(tidyverse)
library(ggpubr)
library(rstatix)
library(readxl)
library(dplyr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.1     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘rstatix’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
#install.packages('WRS2')
library(WRS2)
#conda install -c conda-forge r-wrs2

# %%
setwd("/Users/j.amanirad/Desktop/CompositeFace") 
CF_LPPCC <- read_excel("CF_LPPC.xlsx")
CF_LPPCC
# Out:
#      subject sex    Face_1    Face_2    Face_Gender Congruency Block Trial
# 1    1       male   A_09_14_M R_09_12_M Male        0          1     1
# 2    1       male   A_01_04_F A_03_04_F Female      0          1     2
# 3    1       male   A_12_15_M A_12_09_M Male        0          1     3
# 4    1       male   A_10_09_M A_10_09_M Male        1          1     4
# 5    1       male   A_14_12_M R_10_12_M Male        0          1     5
# 6    1       male   A_01_05_F R_06_05_F Female      0          1     6
# 7    1       male   A_05_07_F A_05_08_F Female      0          1     7
# 8    1       male   A_14_12_M A_09_12_M Male        0          1     8
# 9    1       male   A_11_09_M A_14_09_M Male        0          1     9
# 10   1       male   A_05_07_F A_05_01_F Female      0          1     10
# 11   1       male   A_02_06_F A_05_06_F Female      0          1     11
# 12   1       male   A_01_03_F R_01_02_F Female      0          1     12
# 13   1       male   A_05_08_F A_05_08_F Female      1          1     13
# 14   1       male   A_10_11_M R_14_11_M Male        0          1     14
# 15   1       male   A_10_13_M R_10_12_M Male        0          1     15
# 16   1       male   A_03_04_F R_03_02_F Female      0          1     16
# 17   1       male   A_06_08_F R_05_08_F Female      0          1     17
# 18   1       male   A_09_14_M A_09_12_M Male        0          1     18
# 19   1       male   A_05_01_F R_01_04_F Female      1          1     19
# 20   1       male   A_09_11_M A_09_12_M Male        0          1     20
# 21   1       male   A_12_10_M R_12_10_M Male        1          1     21
# 22   1       male   A_10_13_M R_10_13_M Male        1          1     22
# 23   1       male   A_02_01_F A_03_01_F Female      0          1     23
# 24   1       male   A_10_13_M R_10_12_M Male        0          1     24
# 25   1       male   A_01_02_F R_03_02_F Female      0          1     25
# 26   1       male   A_03_08_F R_03_08_F Female      1          1     26
# 27   1       male   A_06_03_F A_01_05_F Female      1          1     27
# 28   1       male   A_10_09_M R_10_09_M Male        1          1     28
# 29   1       male   A_03_08_F A_02_03_F Female      1          1     29
# 30   1       male   A_03_04_F R_03_04_F Female      1          1     30
# ⋮    ⋮       ⋮      ⋮         ⋮         ⋮           ⋮          ⋮     ⋮
# 5731 36      female A_02_06_F R_02_06_F Female      1          4     131
# 5732 36      female A_11_13_M R_11_14_M Male        0          4     132
# 5733 36      female A_09_10_M A_12_10_M Male        0          4     133
# 5734 36      female A_03_01_F R_05_01_F Female      0          4     134
# 5735 36      female A_09_11_M R_09_11_M Male        1          4     135
# 5736 36      female A_14_11_M R_10_11_M Male        0          4     136
# 5737 36      female A_14_15_M R_14_09_M Male        0          4     137
# 5738 36      female A_02_04_F A_02_03_F Female      0          4     138
# 5739 36      female A_06_08_F A_02_04_F Female      1          4     139
# 5740 36      female A_11_10_M A_10_12_M Male        1          4     140
# 5741 36      female A_14_15_M A_11_14_M Male        1          4     141
# 5742 36      female A_03_08_F R_05_08_F Female      0          4     142
# 5743 36      female A_02_04_F R_02_01_F Female      0          4     143
# 5744 36      female A_05_01_F R_01_04_F Female      1          4     144
# 5745 36      female A_02_06_F A_05_06_F Female      0          4     145
# 5746 36      female A_11_09_M R_11_09_M Male        1          4     146
# 5747 36      female A_12_14_M A_12_14_M Male        1          4     147
# 5748 36      female A_12_10_M R_10_11_M Male        1          4     148
# 5749 36      female A_09_11_M R_10_12_M Male        1          4     149
# 5750 36      female A_05_01_F A_05_06_F Female      0          4     150
# 5751 36      female A_12_10_M A_12_15_M Male        0          4     151
# 5752 36      female A_01_02_F A_03_02_F Female      0          4     152
# 5753 36      female A_11_13_M A_10_13_M Male        0          4     153
# 5754 36      female A_06_05_F R_06_03_F Female      0          4     154
# 5755 36      female A_05_08_F R_06_08_F Female      0          4     155
# 5756 36      female A_10_13_M A_10_12_M Male        0          4     156
# 5757 36      female A_14_12_M A_14_12_M Male        1          4     157
# 5758 36      female A_11_09_M A_11_14_M Male        0          4     158
# 5759 36      female A_02_04_F A_02_04_F Female      1          4     159
# 5760 36      female A_05_01_F A_05_01_F Female      1          4     160
#      Alignment Condition Type                   Key_Resp Cor_Ans Accuracy
# 1    0         2         Misaligned Incongruent A        L       0
# 2    1         3         Aligned Incongruent    L        A       0
# 3    1         2         Aligned Incongruent    L        L       1
# 4    1         1         Aligned Congruent      L        L       1
# 5    0         3         Misaligned Incongruent A        A       1
# 6    0         3         Misaligned Incongruent L        A       0
# 7    1         2         Aligned Incongruent    L        L       1
# 8    1         3         Aligned Incongruent    A        A       1
# 9    1         3         Aligned Incongruent    L        A       0
# 10   1         2         Aligned Incongruent    L        L       1
# 11   1         3         Aligned Incongruent    A        A       1
# 12   0         2         Misaligned Incongruent L        L       1
# 13   1         1         Aligned Congruent      L        L       1
# 14   0         3         Misaligned Incongruent A        A       1
# 15   0         2         Misaligned Incongruent L        L       1
# 16   0         2         Misaligned Incongruent L        L       1
# 17   0         3         Misaligned Incongruent A        A       1
# 18   1         2         Aligned Incongruent    L        L       1
# 19   0         4         Misaligned Congruent   A        A       1
# 20   1         2         Aligned Incongruent    L        L       1
# 21   0         1         Misaligned Congruent   L        L       1
# 22   0         1         Misaligned Congruent   L        L       1
# 23   1         3         Aligned Incongruent    A        A       1
# 24   0         2         Misaligned Incongruent L        L       1
# 25   0         3         Misaligned Incongruent A        A       1
# 26   0         1         Misaligned Congruent   L        L       1
# 27   1         4         Aligned Congruent      A        A       1
# 28   0         1         Misaligned Congruent   A        L       0
# 29   1         4         Aligned Congruent      A        A       1
# 30   0         1         Misaligned Congruent   L        L       1
# ⋮    ⋮         ⋮         ⋮                      ⋮        ⋮       ⋮
# 5731 0         1         Misaligned Congruent   L        L       1
# 5732 0         2         Misaligned Incongruent L        L       1
# 5733 1         3         Aligned Incongruent    A        A       1
# 5734 0         3         Misaligned Incongruent A        A       1
# 5735 0         1         Misaligned Congruent   L        L       1
# 5736 0         3         Misaligned Incongruent A        A       1
# 5737 0         2         Misaligned Incongruent L        L       1
# 5738 1         2         Aligned Incongruent    L        L       1
# 5739 1         4         Aligned Congruent      A        A       1
# 5740 1         4         Aligned Congruent      A        A       1
# 5741 1         4         Aligned Congruent      A        A       1
# 5742 0         3         Misaligned Incongruent A        A       1
# 5743 0         2         Misaligned Incongruent L        L       1
# 5744 0         4         Misaligned Congruent   A        A       1
# 5745 1         3         Aligned Incongruent    A        A       1
# 5746 0         1         Misaligned Congruent   L        L       1
# 5747 1         1         Aligned Congruent      L        L       1
# 5748 0         4         Misaligned Congruent   A        A       1
# 5749 0         4         Misaligned Congruent   A        A       1
# 5750 1         2         Aligned Incongruent    L        L       1
# 5751 1         2         Aligned Incongruent    A        L       0
# 5752 1         3         Aligned Incongruent    A        A       1
# 5753 1         3         Aligned Incongruent    A        A       1
# 5754 0         2         Misaligned Incongruent L        L       1
# 5755 0         3         Misaligned Incongruent A        A       1
# 5756 1         2         Aligned Incongruent    A        L       0
# 5757 1         1         Aligned Congruent      L        L       1
# 5758 1         2         Aligned Incongruent    A        L       0
# 5759 1         1         Aligned Congruent      L        L       1
# 5760 1         1         Aligned Congruent      L        L       1
#      R_time              Trial-Start        Key-Resp-Start
# 1    2.7332195000009962  49.95315599999958  53.93637550000058
# 2    1.3722107000005053  54.93637550000058  57.55858620000109
# 3    0.8274069000010058  58.55858620000109  60.635993100002096
# 4    0.45750739999966755 61.635993100002096 63.34350050000177
# 5    0.7660545000009733  64.34350050000177  66.35955500000274
# 6    0.7583048000007693  67.35955500000274  69.36785980000352
# 7    0.5510096999998495  70.36785980000352  72.16886950000337
# 8    0.6153222000004461  73.16886950000337  75.03419170000382
# 9    0.6050403000001097  76.03419170000382  77.88923200000393
# 10   0.5955361999996966  78.88923200000393  80.73476820000363
# 11   0.6110963000002811  81.73476820000363  83.59586450000391
# 12   0.857375900000261   84.59586450000391  86.70324040000418
# 13   0.9585952999997971  87.70324040000418  89.91183570000398
# 14   0.6466817999982595  90.91183570000398  92.80851750000224
# 15   0.907749799999874   93.80851750000224  95.96626730000212
# 16   0.8222932000000582  96.96626730000212  99.03856050000218
# 17   0.6041763999994145  100.03856050000218 101.8927369000016
# 18   0.8984539000004588  102.8927369000016  105.04119080000206
# 19   0.6361470999992889  106.04119080000206 107.92733790000135
# 20   0.6267027000005327  108.92733790000135 110.80404060000188
# 21   0.5690404999997554  111.80404060000188 113.62308110000164
# 22   0.40231049999893004 114.62308110000164 116.27539160000057
# 23   0.5203193999997893  117.27539160000057 119.04571100000037
# 24   0.41049809999931314 120.04571100000037 121.70620909999968
# 25   0.5693485999992844  122.70620909999968 124.52555769999897
# 26   0.6019606999991083  125.52555769999897 127.37751839999808
# 27   0.5596054999998159  128.37751839999808 130.18712389999789
# 28   0.6584778000007645  131.18712389999789 133.09560169999864
# 29   0.622397300000739   134.09560169999864 135.96799899999937
# 30   0.5901805000004969  136.96799899999937 138.80817949999985
# ⋮    ⋮                   ⋮                  ⋮
# 5731 0.5616034999995463  430.44806269999646 432.259666199996
# 5732 0.5691233999998075  433.259666199996   435.0787895999958
# 5733 0.5610647000004974  436.0787895999958  437.8898542999963
# 5734 0.849999300001582   438.8898542999963  440.98985359999784
# 5735 0.7754753000001073  441.98985359999784 444.01532889999794
# 5736 0.6625018000006093  445.01532889999794 446.92783069999854
# 5737 0.6992758999997022  447.92783069999854 449.8771065999982
# 5738 0.6774494000012055  450.8771065999982  452.8045559999994
# 5739 0.8094425999999657  453.8045559999994  455.8639985999994
# 5740 0.6242037999993044  456.8639985999994  458.73820239999867
# 5741 0.6542733999987831  459.73820239999867 461.64247579999744
# 5742 0.7485993000002054  462.64247579999744 464.64107509999764
# 5743 0.6364574000010179  465.64107509999764 467.52753249999864
# 5744 0.5134005000010802  468.52753249999864 470.2909329999997
# 5745 0.5723828000001958  471.2909329999997  473.1133157999999
# 5746 0.6455698999991     474.1133157999999  476.008885699999
# 5747 0.7069662000005337  477.008885699999   478.9658518999995
# 5748 0.5167188999996142  479.9658518999995  481.7325707999991
# 5749 0.7435976999997365  482.7325707999991  484.72616849999883
# 5750 0.5133723000009922  485.72616849999883 487.4895407999998
# 5751 0.6026875999988988  488.4895407999998  490.3422283999987
# 5752 1.0263196000007155  491.3422283999987  493.6185479999994
# 5753 0.6393395999995846  494.6185479999994  496.507887599999
# 5754 0.6123247999996237  497.507887599999   499.3702123999986
# 5755 0.6510673000004317  500.3702123999986  502.271279699999
# 5756 0.6874713999997766  503.271279699999   505.2087510999988
# 5757 0.7558953999989171  506.2087510999988  508.2146464999977
# 5758 0.6194559999996272  509.2146464999977  511.0841024999973
# 5759 0.6032860000006621  512.0841024999972  513.937388499998
# 5760 0.5302202000013494  514.937388499998   516.7176086999993

# %%
CF_LPPC <- data.frame(subj = as.numeric(CF_LPPCC$subject),
                 #sex = CF_CZZ$'sex',
                 Trial = as.numeric(CF_LPPCC$Trial),
                 #Cond = as.numeric(CF_CZZ$Condition),
                 #Type = CF_CZZ$'Type',
                 Cong = as.numeric(CF_LPPCC$Congruency),
                 Alig = as.numeric(CF_LPPCC$Alignment),
                 Key_Resp = CF_LPPCC$'Key_Resp',
                 Cor_Ans = CF_LPPCC$'Cor_Ans',
                 Acc = as.numeric(CF_LPPCC$Accuracy),
                 RT = as.numeric(CF_LPPCC$R_time)
)
CF_LPPC <- CF_LPPC %>% mutate(Cong = ifelse(Cong == "1", "Congruent", ifelse(Cong == "0", "InCongruent", 
                                                                             "NaN")))
CF_LPPC <- CF_LPPC %>% mutate(Alig = ifelse(Alig == "1", "Alignment", ifelse(Alig == "0", "MissAlignment", 
                                                                             "NaN")))
CF_LPPC<- CF_LPPC[which(CF_LPPC$subj != 4),]

CF_LPPC
# Out:
#      subj Trial Cong        Alig          Key_Resp Cor_Ans Acc RT
# 1    1     1    InCongruent MissAlignment A        L       0   2.7332195
# 2    1     2    InCongruent Alignment     L        A       0   1.3722107
# 3    1     3    InCongruent Alignment     L        L       1   0.8274069
# 4    1     4    Congruent   Alignment     L        L       1   0.4575074
# 5    1     5    InCongruent MissAlignment A        A       1   0.7660545
# 6    1     6    InCongruent MissAlignment L        A       0   0.7583048
# 7    1     7    InCongruent Alignment     L        L       1   0.5510097
# 8    1     8    InCongruent Alignment     A        A       1   0.6153222
# 9    1     9    InCongruent Alignment     L        A       0   0.6050403
# 10   1    10    InCongruent Alignment     L        L       1   0.5955362
# 11   1    11    InCongruent Alignment     A        A       1   0.6110963
# 12   1    12    InCongruent MissAlignment L        L       1   0.8573759
# 13   1    13    Congruent   Alignment     L        L       1   0.9585953
# 14   1    14    InCongruent MissAlignment A        A       1   0.6466818
# 15   1    15    InCongruent MissAlignment L        L       1   0.9077498
# 16   1    16    InCongruent MissAlignment L        L       1   0.8222932
# 17   1    17    InCongruent MissAlignment A        A       1   0.6041764
# 18   1    18    InCongruent Alignment     L        L       1   0.8984539
# 19   1    19    Congruent   MissAlignment A        A       1   0.6361471
# 20   1    20    InCongruent Alignment     L        L       1   0.6267027
# 21   1    21    Congruent   MissAlignment L        L       1   0.5690405
# 22   1    22    Congruent   MissAlignment L        L       1   0.4023105
# 23   1    23    InCongruent Alignment     A        A       1   0.5203194
# 24   1    24    InCongruent MissAlignment L        L       1   0.4104981
# 25   1    25    InCongruent MissAlignment A        A       1   0.5693486
# 26   1    26    Congruent   MissAlignment L        L       1   0.6019607
# 27   1    27    Congruent   Alignment     A        A       1   0.5596055
# 28   1    28    Congruent   MissAlignment A        L       0   0.6584778
# 29   1    29    Congruent   Alignment     A        A       1   0.6223973
# 30   1    30    Congruent   MissAlignment L        L       1   0.5901805
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮        ⋮       ⋮   ⋮
# 5731 36   131   Congruent   MissAlignment L        L       1   0.5616035
# 5732 36   132   InCongruent MissAlignment L        L       1   0.5691234
# 5733 36   133   InCongruent Alignment     A        A       1   0.5610647
# 5734 36   134   InCongruent MissAlignment A        A       1   0.8499993
# 5735 36   135   Congruent   MissAlignment L        L       1   0.7754753
# 5736 36   136   InCongruent MissAlignment A        A       1   0.6625018
# 5737 36   137   InCongruent MissAlignment L        L       1   0.6992759
# 5738 36   138   InCongruent Alignment     L        L       1   0.6774494
# 5739 36   139   Congruent   Alignment     A        A       1   0.8094426
# 5740 36   140   Congruent   Alignment     A        A       1   0.6242038
# 5741 36   141   Congruent   Alignment     A        A       1   0.6542734
# 5742 36   142   InCongruent MissAlignment A        A       1   0.7485993
# 5743 36   143   InCongruent MissAlignment L        L       1   0.6364574
# 5744 36   144   Congruent   MissAlignment A        A       1   0.5134005
# 5745 36   145   InCongruent Alignment     A        A       1   0.5723828
# 5746 36   146   Congruent   MissAlignment L        L       1   0.6455699
# 5747 36   147   Congruent   Alignment     L        L       1   0.7069662
# 5748 36   148   Congruent   MissAlignment A        A       1   0.5167189
# 5749 36   149   Congruent   MissAlignment A        A       1   0.7435977
# 5750 36   150   InCongruent Alignment     L        L       1   0.5133723
# 5751 36   151   InCongruent Alignment     A        L       0   0.6026876
# 5752 36   152   InCongruent Alignment     A        A       1   1.0263196
# 5753 36   153   InCongruent Alignment     A        A       1   0.6393396
# 5754 36   154   InCongruent MissAlignment L        L       1   0.6123248
# 5755 36   155   InCongruent MissAlignment A        A       1   0.6510673
# 5756 36   156   InCongruent Alignment     A        L       0   0.6874714
# 5757 36   157   Congruent   Alignment     L        L       1   0.7558954
# 5758 36   158   InCongruent Alignment     A        L       0   0.6194560
# 5759 36   159   Congruent   Alignment     L        L       1   0.6032860
# 5760 36   160   Congruent   Alignment     L        L       1   0.5302202

# %%
for(it in 1:length(CF_LPPC$subj)){
  if(CF_LPPC$subj[it] >= 10 & CF_LPPC$subj[it]<= 27){
    if(CF_LPPC$Key_Resp[it] == "A" & CF_LPPC$Cor_Ans[it] == "A")
      CF_LPPC$SDT[it] <- "Hit"
    else if(CF_LPPC$Key_Resp[it] == "A" & CF_LPPC$Cor_Ans[it] == "L")
      CF_LPPC$SDT[it] <- "FalseAlarm"
    else if(CF_LPPC$Key_Resp[it] == "L" & CF_LPPC$Cor_Ans[it] == "A")
      CF_LPPC$SDT[it] <- "Miss"
    else
      CF_LPPC$SDT[it] <- "CorrReject"
  }
  else{
    if(CF_LPPC$Key_Resp[it] == "L" & CF_LPPC$Cor_Ans[it] == "L")
      CF_LPPC$SDT[it] <- "Hit"
    else if(CF_LPPC$Key_Resp[it] == "L" & CF_LPPC$Cor_Ans[it] == "A")
      CF_LPPC$SDT[it] <- "FalseAlarm"
    else if(CF_LPPC$Key_Resp[it] == "A" & CF_LPPC$Cor_Ans[it] == "L")
      CF_LPPC$SDT[it] <- "Miss"
    else
      CF_LPPC$SDT[it] <- "CorrReject"
  }
}
CF_LPPC
# Out:
#      subj Trial Cong        Alig          Key_Resp Cor_Ans Acc RT
# 1    1     1    InCongruent MissAlignment A        L       0   2.7332195
# 2    1     2    InCongruent Alignment     L        A       0   1.3722107
# 3    1     3    InCongruent Alignment     L        L       1   0.8274069
# 4    1     4    Congruent   Alignment     L        L       1   0.4575074
# 5    1     5    InCongruent MissAlignment A        A       1   0.7660545
# 6    1     6    InCongruent MissAlignment L        A       0   0.7583048
# 7    1     7    InCongruent Alignment     L        L       1   0.5510097
# 8    1     8    InCongruent Alignment     A        A       1   0.6153222
# 9    1     9    InCongruent Alignment     L        A       0   0.6050403
# 10   1    10    InCongruent Alignment     L        L       1   0.5955362
# 11   1    11    InCongruent Alignment     A        A       1   0.6110963
# 12   1    12    InCongruent MissAlignment L        L       1   0.8573759
# 13   1    13    Congruent   Alignment     L        L       1   0.9585953
# 14   1    14    InCongruent MissAlignment A        A       1   0.6466818
# 15   1    15    InCongruent MissAlignment L        L       1   0.9077498
# 16   1    16    InCongruent MissAlignment L        L       1   0.8222932
# 17   1    17    InCongruent MissAlignment A        A       1   0.6041764
# 18   1    18    InCongruent Alignment     L        L       1   0.8984539
# 19   1    19    Congruent   MissAlignment A        A       1   0.6361471
# 20   1    20    InCongruent Alignment     L        L       1   0.6267027
# 21   1    21    Congruent   MissAlignment L        L       1   0.5690405
# 22   1    22    Congruent   MissAlignment L        L       1   0.4023105
# 23   1    23    InCongruent Alignment     A        A       1   0.5203194
# 24   1    24    InCongruent MissAlignment L        L       1   0.4104981
# 25   1    25    InCongruent MissAlignment A        A       1   0.5693486
# 26   1    26    Congruent   MissAlignment L        L       1   0.6019607
# 27   1    27    Congruent   Alignment     A        A       1   0.5596055
# 28   1    28    Congruent   MissAlignment A        L       0   0.6584778
# 29   1    29    Congruent   Alignment     A        A       1   0.6223973
# 30   1    30    Congruent   MissAlignment L        L       1   0.5901805
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮        ⋮       ⋮   ⋮
# 5731 36   131   Congruent   MissAlignment L        L       1   0.5616035
# 5732 36   132   InCongruent MissAlignment L        L       1   0.5691234
# 5733 36   133   InCongruent Alignment     A        A       1   0.5610647
# 5734 36   134   InCongruent MissAlignment A        A       1   0.8499993
# 5735 36   135   Congruent   MissAlignment L        L       1   0.7754753
# 5736 36   136   InCongruent MissAlignment A        A       1   0.6625018
# 5737 36   137   InCongruent MissAlignment L        L       1   0.6992759
# 5738 36   138   InCongruent Alignment     L        L       1   0.6774494
# 5739 36   139   Congruent   Alignment     A        A       1   0.8094426
# 5740 36   140   Congruent   Alignment     A        A       1   0.6242038
# 5741 36   141   Congruent   Alignment     A        A       1   0.6542734
# 5742 36   142   InCongruent MissAlignment A        A       1   0.7485993
# 5743 36   143   InCongruent MissAlignment L        L       1   0.6364574
# 5744 36   144   Congruent   MissAlignment A        A       1   0.5134005
# 5745 36   145   InCongruent Alignment     A        A       1   0.5723828
# 5746 36   146   Congruent   MissAlignment L        L       1   0.6455699
# 5747 36   147   Congruent   Alignment     L        L       1   0.7069662
# 5748 36   148   Congruent   MissAlignment A        A       1   0.5167189
# 5749 36   149   Congruent   MissAlignment A        A       1   0.7435977
# 5750 36   150   InCongruent Alignment     L        L       1   0.5133723
# 5751 36   151   InCongruent Alignment     A        L       0   0.6026876
# 5752 36   152   InCongruent Alignment     A        A       1   1.0263196
# 5753 36   153   InCongruent Alignment     A        A       1   0.6393396
# 5754 36   154   InCongruent MissAlignment L        L       1   0.6123248
# 5755 36   155   InCongruent MissAlignment A        A       1   0.6510673
# 5756 36   156   InCongruent Alignment     A        L       0   0.6874714
# 5757 36   157   Congruent   Alignment     L        L       1   0.7558954
# 5758 36   158   InCongruent Alignment     A        L       0   0.6194560
# 5759 36   159   Congruent   Alignment     L        L       1   0.6032860
# 5760 36   160   Congruent   Alignment     L        L       1   0.5302202
#      SDT
# 1    Miss
# 2    FalseAlarm
# 3    Hit
# 4    Hit
# 5    CorrReject
# 6    FalseAlarm
# 7    Hit
# 8    CorrReject
# 9    FalseAlarm
# 10   Hit
# 11   CorrReject
# 12   Hit
# 13   Hit
# 14   CorrReject
# 15   Hit
# 16   Hit
# 17   CorrReject
# 18   Hit
# 19   CorrReject
# 20   Hit
# 21   Hit
# 22   Hit
# 23   CorrReject
# 24   Hit
# 25   CorrReject
# 26   Hit
# 27   CorrReject
# 28   Miss
# 29   CorrReject
# 30   Hit
# ⋮    ⋮
# 5731 Hit
# 5732 Hit
# 5733 CorrReject
# 5734 CorrReject
# 5735 Hit
# 5736 CorrReject
# 5737 Hit
# 5738 Hit
# 5739 CorrReject
# 5740 CorrReject
# 5741 CorrReject
# 5742 CorrReject
# 5743 Hit
# 5744 CorrReject
# 5745 CorrReject
# 5746 Hit
# 5747 Hit
# 5748 CorrReject
# 5749 CorrReject
# 5750 Hit
# 5751 Miss
# 5752 CorrReject
# 5753 CorrReject
# 5754 Hit
# 5755 CorrReject
# 5756 Miss
# 5757 Hit
# 5758 Miss
# 5759 Hit
# 5760 Hit

# %%
CF_LPPC <- subset (CF_LPPC, select = - Key_Resp)
CF_LPPC <- subset (CF_LPPC, select = - Cor_Ans)
#CF_CZ <- subset (CF_CZ, select = - sex)
CF_LPPC
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    InCongruent MissAlignment 0   2.7332195 Miss
# 2    1     2    InCongruent Alignment     0   1.3722107 FalseAlarm
# 3    1     3    InCongruent Alignment     1   0.8274069 Hit
# 4    1     4    Congruent   Alignment     1   0.4575074 Hit
# 5    1     5    InCongruent MissAlignment 1   0.7660545 CorrReject
# 6    1     6    InCongruent MissAlignment 0   0.7583048 FalseAlarm
# 7    1     7    InCongruent Alignment     1   0.5510097 Hit
# 8    1     8    InCongruent Alignment     1   0.6153222 CorrReject
# 9    1     9    InCongruent Alignment     0   0.6050403 FalseAlarm
# 10   1    10    InCongruent Alignment     1   0.5955362 Hit
# 11   1    11    InCongruent Alignment     1   0.6110963 CorrReject
# 12   1    12    InCongruent MissAlignment 1   0.8573759 Hit
# 13   1    13    Congruent   Alignment     1   0.9585953 Hit
# 14   1    14    InCongruent MissAlignment 1   0.6466818 CorrReject
# 15   1    15    InCongruent MissAlignment 1   0.9077498 Hit
# 16   1    16    InCongruent MissAlignment 1   0.8222932 Hit
# 17   1    17    InCongruent MissAlignment 1   0.6041764 CorrReject
# 18   1    18    InCongruent Alignment     1   0.8984539 Hit
# 19   1    19    Congruent   MissAlignment 1   0.6361471 CorrReject
# 20   1    20    InCongruent Alignment     1   0.6267027 Hit
# 21   1    21    Congruent   MissAlignment 1   0.5690405 Hit
# 22   1    22    Congruent   MissAlignment 1   0.4023105 Hit
# 23   1    23    InCongruent Alignment     1   0.5203194 CorrReject
# 24   1    24    InCongruent MissAlignment 1   0.4104981 Hit
# 25   1    25    InCongruent MissAlignment 1   0.5693486 CorrReject
# 26   1    26    Congruent   MissAlignment 1   0.6019607 Hit
# 27   1    27    Congruent   Alignment     1   0.5596055 CorrReject
# 28   1    28    Congruent   MissAlignment 0   0.6584778 Miss
# 29   1    29    Congruent   Alignment     1   0.6223973 CorrReject
# 30   1    30    Congruent   MissAlignment 1   0.5901805 Hit
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5731 36   131   Congruent   MissAlignment 1   0.5616035 Hit
# 5732 36   132   InCongruent MissAlignment 1   0.5691234 Hit
# 5733 36   133   InCongruent Alignment     1   0.5610647 CorrReject
# 5734 36   134   InCongruent MissAlignment 1   0.8499993 CorrReject
# 5735 36   135   Congruent   MissAlignment 1   0.7754753 Hit
# 5736 36   136   InCongruent MissAlignment 1   0.6625018 CorrReject
# 5737 36   137   InCongruent MissAlignment 1   0.6992759 Hit
# 5738 36   138   InCongruent Alignment     1   0.6774494 Hit
# 5739 36   139   Congruent   Alignment     1   0.8094426 CorrReject
# 5740 36   140   Congruent   Alignment     1   0.6242038 CorrReject
# 5741 36   141   Congruent   Alignment     1   0.6542734 CorrReject
# 5742 36   142   InCongruent MissAlignment 1   0.7485993 CorrReject
# 5743 36   143   InCongruent MissAlignment 1   0.6364574 Hit
# 5744 36   144   Congruent   MissAlignment 1   0.5134005 CorrReject
# 5745 36   145   InCongruent Alignment     1   0.5723828 CorrReject
# 5746 36   146   Congruent   MissAlignment 1   0.6455699 Hit
# 5747 36   147   Congruent   Alignment     1   0.7069662 Hit
# 5748 36   148   Congruent   MissAlignment 1   0.5167189 CorrReject
# 5749 36   149   Congruent   MissAlignment 1   0.7435977 CorrReject
# 5750 36   150   InCongruent Alignment     1   0.5133723 Hit
# 5751 36   151   InCongruent Alignment     0   0.6026876 Miss
# 5752 36   152   InCongruent Alignment     1   1.0263196 CorrReject
# 5753 36   153   InCongruent Alignment     1   0.6393396 CorrReject
# 5754 36   154   InCongruent MissAlignment 1   0.6123248 Hit
# 5755 36   155   InCongruent MissAlignment 1   0.6510673 CorrReject
# 5756 36   156   InCongruent Alignment     0   0.6874714 Miss
# 5757 36   157   Congruent   Alignment     1   0.7558954 Hit
# 5758 36   158   InCongruent Alignment     0   0.6194560 Miss
# 5759 36   159   Congruent   Alignment     1   0.6032860 Hit
# 5760 36   160   Congruent   Alignment     1   0.5302202 Hit

# %% [markdown]
# Since an accuracy above 57.5% across 160 trials is unlikely due to random behavior alone,
# according to a binomial test (p < 0.05), only participants who surpassed this threshold were
# included in the analyses.
# - binom.test(91,160,p=0.5)  ,  p_value = 0.09657
# - binom.test(92,160,p=0.5)  ,  p_value = 0.06868
# - binom.test(93,160,p=0.5)  ,  p_value = 0.04777
# - binom.test(94,160,p=0.5)  ,  p_value = 0.03247
#
# Therefore we have 92/160 = 0.575

# %%
meanAcc <- data.frame(subj = NaN, MACC = NaN)
meanAcc2 <- data.frame(subj = NaN, MACC = NaN)
for(i in 1:36){
  meanAcc$subj <- i 
  meanAcc$MACC <- mean(CF_LPPC$Acc[CF_LPPC$subj == i])
  meanAcc2 <- rbind(meanAcc2, meanAcc)
}
meanAcc2
# Out:
#    subj MACC
# 1  NaN      NaN
# 2    1  0.88750
# 3    2  0.88750
# 4    3  0.75000
# 5    4      NaN
# 6    5  0.88750
# 7    6  0.93750
# 8    7  0.80625
# 9    8  0.94375
# 10   9  0.51250
# 11  10  0.53750
# 12  11  0.76875
# 13  12  0.91250
# 14  13  0.94375
# 15  14  0.85625
# 16  15  0.66875
# 17  16  0.90625
# 18  17  0.92500
# 19  18  0.69375
# 20  19  0.92500
# 21  20  0.97500
# 22  21  0.96875
# 23  22  0.96250
# 24  23  0.83750
# 25  24  0.96250
# 26  25  0.88750
# 27  26  0.87500
# 28  27  0.82500
# 29  28  0.97500
# 30  29  0.94375
# 31  30  0.94375
# 32  31  0.90625
# 33  32  0.87500
# 34  33  0.91875
# 35  34  0.92500
# 36  35  0.93750
# 37  36  0.91250

# %% [markdown]
# Therefore data from 1 participant (participant number = 10) was discarded because of chance performance = 0.54375.

# %%
CF_LPPC<- CF_LPPC[which(CF_LPPC$subj != 10 & CF_LPPC$subj != 9),]
CF_LPPC
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    InCongruent MissAlignment 0   2.7332195 Miss
# 2    1     2    InCongruent Alignment     0   1.3722107 FalseAlarm
# 3    1     3    InCongruent Alignment     1   0.8274069 Hit
# 4    1     4    Congruent   Alignment     1   0.4575074 Hit
# 5    1     5    InCongruent MissAlignment 1   0.7660545 CorrReject
# 6    1     6    InCongruent MissAlignment 0   0.7583048 FalseAlarm
# 7    1     7    InCongruent Alignment     1   0.5510097 Hit
# 8    1     8    InCongruent Alignment     1   0.6153222 CorrReject
# 9    1     9    InCongruent Alignment     0   0.6050403 FalseAlarm
# 10   1    10    InCongruent Alignment     1   0.5955362 Hit
# 11   1    11    InCongruent Alignment     1   0.6110963 CorrReject
# 12   1    12    InCongruent MissAlignment 1   0.8573759 Hit
# 13   1    13    Congruent   Alignment     1   0.9585953 Hit
# 14   1    14    InCongruent MissAlignment 1   0.6466818 CorrReject
# 15   1    15    InCongruent MissAlignment 1   0.9077498 Hit
# 16   1    16    InCongruent MissAlignment 1   0.8222932 Hit
# 17   1    17    InCongruent MissAlignment 1   0.6041764 CorrReject
# 18   1    18    InCongruent Alignment     1   0.8984539 Hit
# 19   1    19    Congruent   MissAlignment 1   0.6361471 CorrReject
# 20   1    20    InCongruent Alignment     1   0.6267027 Hit
# 21   1    21    Congruent   MissAlignment 1   0.5690405 Hit
# 22   1    22    Congruent   MissAlignment 1   0.4023105 Hit
# 23   1    23    InCongruent Alignment     1   0.5203194 CorrReject
# 24   1    24    InCongruent MissAlignment 1   0.4104981 Hit
# 25   1    25    InCongruent MissAlignment 1   0.5693486 CorrReject
# 26   1    26    Congruent   MissAlignment 1   0.6019607 Hit
# 27   1    27    Congruent   Alignment     1   0.5596055 CorrReject
# 28   1    28    Congruent   MissAlignment 0   0.6584778 Miss
# 29   1    29    Congruent   Alignment     1   0.6223973 CorrReject
# 30   1    30    Congruent   MissAlignment 1   0.5901805 Hit
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5731 36   131   Congruent   MissAlignment 1   0.5616035 Hit
# 5732 36   132   InCongruent MissAlignment 1   0.5691234 Hit
# 5733 36   133   InCongruent Alignment     1   0.5610647 CorrReject
# 5734 36   134   InCongruent MissAlignment 1   0.8499993 CorrReject
# 5735 36   135   Congruent   MissAlignment 1   0.7754753 Hit
# 5736 36   136   InCongruent MissAlignment 1   0.6625018 CorrReject
# 5737 36   137   InCongruent MissAlignment 1   0.6992759 Hit
# 5738 36   138   InCongruent Alignment     1   0.6774494 Hit
# 5739 36   139   Congruent   Alignment     1   0.8094426 CorrReject
# 5740 36   140   Congruent   Alignment     1   0.6242038 CorrReject
# 5741 36   141   Congruent   Alignment     1   0.6542734 CorrReject
# 5742 36   142   InCongruent MissAlignment 1   0.7485993 CorrReject
# 5743 36   143   InCongruent MissAlignment 1   0.6364574 Hit
# 5744 36   144   Congruent   MissAlignment 1   0.5134005 CorrReject
# 5745 36   145   InCongruent Alignment     1   0.5723828 CorrReject
# 5746 36   146   Congruent   MissAlignment 1   0.6455699 Hit
# 5747 36   147   Congruent   Alignment     1   0.7069662 Hit
# 5748 36   148   Congruent   MissAlignment 1   0.5167189 CorrReject
# 5749 36   149   Congruent   MissAlignment 1   0.7435977 CorrReject
# 5750 36   150   InCongruent Alignment     1   0.5133723 Hit
# 5751 36   151   InCongruent Alignment     0   0.6026876 Miss
# 5752 36   152   InCongruent Alignment     1   1.0263196 CorrReject
# 5753 36   153   InCongruent Alignment     1   0.6393396 CorrReject
# 5754 36   154   InCongruent MissAlignment 1   0.6123248 Hit
# 5755 36   155   InCongruent MissAlignment 1   0.6510673 CorrReject
# 5756 36   156   InCongruent Alignment     0   0.6874714 Miss
# 5757 36   157   Congruent   Alignment     1   0.7558954 Hit
# 5758 36   158   InCongruent Alignment     0   0.6194560 Miss
# 5759 36   159   Congruent   Alignment     1   0.6032860 Hit
# 5760 36   160   Congruent   Alignment     1   0.5302202 Hit

# %%
CF_LPPC[which(CF_LPPC$RT>5),]
CF_LPPC[which(CF_LPPC$RT<0.2),]
mean(CF_LPPC$RT[CF_LPPC$subj == 1])
3*sd(CF_LPPC$RT[CF_LPPC$subj == 1])

CF_LPPC[which(CF_LPPC$subj ==1 & CF_LPPC$RT> mean(CF_LPPC$RT[CF_LPPC$subj == 1])+3*sd(CF_LPPC$RT[CF_LPPC$subj == 1])),]
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 2468 16    68   InCongruent MissAlignment 1    6.496159 CorrReject
# 2499 16    99   Congruent   MissAlignment 0    5.811716 FalseAlarm
# 3950 25   110   InCongruent MissAlignment 1   14.991228 Hit
# 4481 29     1   InCongruent MissAlignment 1   11.023347 Hit
# 4961 32     1   Congruent   MissAlignment 1    7.366235 Hit
# 4962 32     2   Congruent   MissAlignment 0    5.319644 FalseAlarm
# 4974 32    14   InCongruent Alignment     1    7.964382 Hit
# 4977 32    17   InCongruent Alignment     0    6.147414 FalseAlarm
# 4978 32    18   InCongruent MissAlignment 0    9.423332 FalseAlarm
# 4979 32    19   InCongruent MissAlignment 1    7.052269 CorrReject
#      subj Trial Cong Alig Acc RT SDT
# [1] 0.6306659
# [1] 0.6760076
#   subj Trial Cong        Alig          Acc RT       SDT
# 1 1    1     InCongruent MissAlignment 0   2.733220 Miss
# 2 1    2     InCongruent Alignment     0   1.372211 FalseAlarm

# %%
#j<-0
#for(i in 1: 5760){
#  if(CF_CZ$RT[i]>1)
#    j<-j+1
#}

#CF<- CF_CZZ[which(CF_CZZ$Acc == 1 & CF_CZZ$RT <= 1),]

#OUT <- CF_CZ %>% group_by(subj) %>% identify_outliers(RT)
#OUTT <- OUT[which(OUT$is.extreme == TRUE),]

#CF_CZ_no_outlier<- CF_CZ %>% 
#  anti_join(OUTT, by = "RT") 



OUT <- CF_LPPC[which(CF_LPPC$Acc ==1 & CF_LPPC$RT>5),]

CF_LPPC_n<- CF_LPPC %>% 
  anti_join(OUT, by = "RT") 

#CF_CZ_no_outlier<- CF_CZ  



#CF_CZ_no_outlier[which(CF_CZ_no_outlier$RT>4),]

#CF_CZ_no_outlier <- CF_CZ
CF_LPPC_n

OUT
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    InCongruent MissAlignment 0   2.7332195 Miss
# 2    1     2    InCongruent Alignment     0   1.3722107 FalseAlarm
# 3    1     3    InCongruent Alignment     1   0.8274069 Hit
# 4    1     4    Congruent   Alignment     1   0.4575074 Hit
# 5    1     5    InCongruent MissAlignment 1   0.7660545 CorrReject
# 6    1     6    InCongruent MissAlignment 0   0.7583048 FalseAlarm
# 7    1     7    InCongruent Alignment     1   0.5510097 Hit
# 8    1     8    InCongruent Alignment     1   0.6153222 CorrReject
# 9    1     9    InCongruent Alignment     0   0.6050403 FalseAlarm
# 10   1    10    InCongruent Alignment     1   0.5955362 Hit
# 11   1    11    InCongruent Alignment     1   0.6110963 CorrReject
# 12   1    12    InCongruent MissAlignment 1   0.8573759 Hit
# 13   1    13    Congruent   Alignment     1   0.9585953 Hit
# 14   1    14    InCongruent MissAlignment 1   0.6466818 CorrReject
# 15   1    15    InCongruent MissAlignment 1   0.9077498 Hit
# 16   1    16    InCongruent MissAlignment 1   0.8222932 Hit
# 17   1    17    InCongruent MissAlignment 1   0.6041764 CorrReject
# 18   1    18    InCongruent Alignment     1   0.8984539 Hit
# 19   1    19    Congruent   MissAlignment 1   0.6361471 CorrReject
# 20   1    20    InCongruent Alignment     1   0.6267027 Hit
# 21   1    21    Congruent   MissAlignment 1   0.5690405 Hit
# 22   1    22    Congruent   MissAlignment 1   0.4023105 Hit
# 23   1    23    InCongruent Alignment     1   0.5203194 CorrReject
# 24   1    24    InCongruent MissAlignment 1   0.4104981 Hit
# 25   1    25    InCongruent MissAlignment 1   0.5693486 CorrReject
# 26   1    26    Congruent   MissAlignment 1   0.6019607 Hit
# 27   1    27    Congruent   Alignment     1   0.5596055 CorrReject
# 28   1    28    Congruent   MissAlignment 0   0.6584778 Miss
# 29   1    29    Congruent   Alignment     1   0.6223973 CorrReject
# 30   1    30    Congruent   MissAlignment 1   0.5901805 Hit
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5245 36   131   Congruent   MissAlignment 1   0.5616035 Hit
# 5246 36   132   InCongruent MissAlignment 1   0.5691234 Hit
# 5247 36   133   InCongruent Alignment     1   0.5610647 CorrReject
# 5248 36   134   InCongruent MissAlignment 1   0.8499993 CorrReject
# 5249 36   135   Congruent   MissAlignment 1   0.7754753 Hit
# 5250 36   136   InCongruent MissAlignment 1   0.6625018 CorrReject
# 5251 36   137   InCongruent MissAlignment 1   0.6992759 Hit
# 5252 36   138   InCongruent Alignment     1   0.6774494 Hit
# 5253 36   139   Congruent   Alignment     1   0.8094426 CorrReject
# 5254 36   140   Congruent   Alignment     1   0.6242038 CorrReject
# 5255 36   141   Congruent   Alignment     1   0.6542734 CorrReject
# 5256 36   142   InCongruent MissAlignment 1   0.7485993 CorrReject
# 5257 36   143   InCongruent MissAlignment 1   0.6364574 Hit
# 5258 36   144   Congruent   MissAlignment 1   0.5134005 CorrReject
# 5259 36   145   InCongruent Alignment     1   0.5723828 CorrReject
# 5260 36   146   Congruent   MissAlignment 1   0.6455699 Hit
# 5261 36   147   Congruent   Alignment     1   0.7069662 Hit
# 5262 36   148   Congruent   MissAlignment 1   0.5167189 CorrReject
# 5263 36   149   Congruent   MissAlignment 1   0.7435977 CorrReject
# 5264 36   150   InCongruent Alignment     1   0.5133723 Hit
# 5265 36   151   InCongruent Alignment     0   0.6026876 Miss
# 5266 36   152   InCongruent Alignment     1   1.0263196 CorrReject
# 5267 36   153   InCongruent Alignment     1   0.6393396 CorrReject
# 5268 36   154   InCongruent MissAlignment 1   0.6123248 Hit
# 5269 36   155   InCongruent MissAlignment 1   0.6510673 CorrReject
# 5270 36   156   InCongruent Alignment     0   0.6874714 Miss
# 5271 36   157   Congruent   Alignment     1   0.7558954 Hit
# 5272 36   158   InCongruent Alignment     0   0.6194560 Miss
# 5273 36   159   Congruent   Alignment     1   0.6032860 Hit
# 5274 36   160   Congruent   Alignment     1   0.5302202 Hit
#      subj Trial Cong        Alig          Acc RT        SDT
# 2468 16    68   InCongruent MissAlignment 1    6.496159 CorrReject
# 3950 25   110   InCongruent MissAlignment 1   14.991228 Hit
# 4481 29     1   InCongruent MissAlignment 1   11.023347 Hit
# 4961 32     1   Congruent   MissAlignment 1    7.366235 Hit
# 4974 32    14   InCongruent Alignment     1    7.964382 Hit
# 4979 32    19   InCongruent MissAlignment 1    7.052269 CorrReject

# %%
for(i in 1:36)
    if(i != 10)
    {
        OUT <- CF_LPPC_n[which(CF_LPPC_n$subj == i & (CF_LPPC_n$RT > mean(CF_LPPC_n$RT[CF_LPPC_n$subj == i]) + 
                         3 * sd(CF_LPPC_n$RT[CF_LPPC_n$subj == i]) | 
                                                  CF_LPPC_n$RT < mean(CF_LPPC_n$RT[CF_LPPC_n$subj == i]) - 
                         3 * sd(CF_LPPC_n$RT[CF_LPPC_n$subj == i]))),]
        CF_LPPC_no_outlier<- CF_LPPC_n %>% anti_join(OUT, by = "RT") 
        CF_LPPC_n <- CF_LPPC_no_outlier
    }
OUT
CF_LPPC_no_outlier
# Out:
#      subj Trial Cong        Alig      Acc RT       SDT
# 5063 36   41    InCongruent Alignment 1   3.226521 Hit
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     3    InCongruent Alignment     1   0.8274069 Hit
# 2    1     4    Congruent   Alignment     1   0.4575074 Hit
# 3    1     5    InCongruent MissAlignment 1   0.7660545 CorrReject
# 4    1     6    InCongruent MissAlignment 0   0.7583048 FalseAlarm
# 5    1     7    InCongruent Alignment     1   0.5510097 Hit
# 6    1     8    InCongruent Alignment     1   0.6153222 CorrReject
# 7    1     9    InCongruent Alignment     0   0.6050403 FalseAlarm
# 8    1    10    InCongruent Alignment     1   0.5955362 Hit
# 9    1    11    InCongruent Alignment     1   0.6110963 CorrReject
# 10   1    12    InCongruent MissAlignment 1   0.8573759 Hit
# 11   1    13    Congruent   Alignment     1   0.9585953 Hit
# 12   1    14    InCongruent MissAlignment 1   0.6466818 CorrReject
# 13   1    15    InCongruent MissAlignment 1   0.9077498 Hit
# 14   1    16    InCongruent MissAlignment 1   0.8222932 Hit
# 15   1    17    InCongruent MissAlignment 1   0.6041764 CorrReject
# 16   1    18    InCongruent Alignment     1   0.8984539 Hit
# 17   1    19    Congruent   MissAlignment 1   0.6361471 CorrReject
# 18   1    20    InCongruent Alignment     1   0.6267027 Hit
# 19   1    21    Congruent   MissAlignment 1   0.5690405 Hit
# 20   1    22    Congruent   MissAlignment 1   0.4023105 Hit
# 21   1    23    InCongruent Alignment     1   0.5203194 CorrReject
# 22   1    24    InCongruent MissAlignment 1   0.4104981 Hit
# 23   1    25    InCongruent MissAlignment 1   0.5693486 CorrReject
# 24   1    26    Congruent   MissAlignment 1   0.6019607 Hit
# 25   1    27    Congruent   Alignment     1   0.5596055 CorrReject
# 26   1    28    Congruent   MissAlignment 0   0.6584778 Miss
# 27   1    29    Congruent   Alignment     1   0.6223973 CorrReject
# 28   1    30    Congruent   MissAlignment 1   0.5901805 Hit
# 29   1    31    Congruent   Alignment     1   0.7014056 CorrReject
# 30   1    32    Congruent   MissAlignment 1   0.6962265 CorrReject
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5152 36   131   Congruent   MissAlignment 1   0.5616035 Hit
# 5153 36   132   InCongruent MissAlignment 1   0.5691234 Hit
# 5154 36   133   InCongruent Alignment     1   0.5610647 CorrReject
# 5155 36   134   InCongruent MissAlignment 1   0.8499993 CorrReject
# 5156 36   135   Congruent   MissAlignment 1   0.7754753 Hit
# 5157 36   136   InCongruent MissAlignment 1   0.6625018 CorrReject
# 5158 36   137   InCongruent MissAlignment 1   0.6992759 Hit
# 5159 36   138   InCongruent Alignment     1   0.6774494 Hit
# 5160 36   139   Congruent   Alignment     1   0.8094426 CorrReject
# 5161 36   140   Congruent   Alignment     1   0.6242038 CorrReject
# 5162 36   141   Congruent   Alignment     1   0.6542734 CorrReject
# 5163 36   142   InCongruent MissAlignment 1   0.7485993 CorrReject
# 5164 36   143   InCongruent MissAlignment 1   0.6364574 Hit
# 5165 36   144   Congruent   MissAlignment 1   0.5134005 CorrReject
# 5166 36   145   InCongruent Alignment     1   0.5723828 CorrReject
# 5167 36   146   Congruent   MissAlignment 1   0.6455699 Hit
# 5168 36   147   Congruent   Alignment     1   0.7069662 Hit
# 5169 36   148   Congruent   MissAlignment 1   0.5167189 CorrReject
# 5170 36   149   Congruent   MissAlignment 1   0.7435977 CorrReject
# 5171 36   150   InCongruent Alignment     1   0.5133723 Hit
# 5172 36   151   InCongruent Alignment     0   0.6026876 Miss
# 5173 36   152   InCongruent Alignment     1   1.0263196 CorrReject
# 5174 36   153   InCongruent Alignment     1   0.6393396 CorrReject
# 5175 36   154   InCongruent MissAlignment 1   0.6123248 Hit
# 5176 36   155   InCongruent MissAlignment 1   0.6510673 CorrReject
# 5177 36   156   InCongruent Alignment     0   0.6874714 Miss
# 5178 36   157   Congruent   Alignment     1   0.7558954 Hit
# 5179 36   158   InCongruent Alignment     0   0.6194560 Miss
# 5180 36   159   Congruent   Alignment     1   0.6032860 Hit
# 5181 36   160   Congruent   Alignment     1   0.5302202 Hit

# %%
boxplot(CF_LPPC_no_outlier$RT[CF_LPPC_no_outlier$Alig == "MissAlignment" & CF_LPPC_no_outlier$Acc == 1], 
        CF_LPPC_no_outlier$RT[CF_LPPC_no_outlier$Alig == "Alignment" & CF_LPPC_no_outlier$Acc == 1])

ggdensity(CF_LPPC$RT[CF_LPPC$Alig == "MissAlignment" & CF_LPPC$Acc == 1], rug = TRUE, fill = "lightgray")
ggdensity(CF_LPPC_no_outlier$RT[CF_LPPC_no_outlier$Alig == "MissAlignment" & CF_LPPC_no_outlier$Acc == 1], rug = TRUE, fill = "lightgray")
# Out:
# plot without title
# plot without title
# plot without title

# %%
CF_LPPC_sum <- data.frame(subj = 1,
                       # Cond = NaN,
                        
                        Cong = NaN,
                        Alig = NaN,
                        Acc = NaN,
                        MRT = NaN,
                        SDT = NaN,
                        NumbersOf = NaN,
                        HitRate = NaN,
                        FalseAlarmRate = NaN,
                        dPrime = NaN,
                        bias = NaN)

CF_LPPC_sum2 <- data.frame(subj = NaN,
                      #  Cond = NaN,
                        
                        Cong = NaN,
                        Alig = NaN,
                        Acc = NaN,
                        MRT = NaN,
                        SDT = NaN,
                        NumbersOf = NaN,
                        HitRate = NaN,
                        FalseAlarmRate = NaN,
                        dPrime = NaN,
                        bias = NaN)

# %%
max(1,3)
# Out:
# [1] 3

# %%
iter <- 2
for(s in 1:36)
  if(s != 10 & s != 9 & s != 4)
  for(c in c("Congruent", "InCongruent"))
    for(a in c("Alignment", "MissAlignment")){
      for(condition in 1:4){
        CF_LPPC_sum$subj <- s
        CF_LPPC_sum$Cong <- c
          CF_LPPC_sum$Alig <- a
        if(condition == 1){
          CF_LPPC_sum$SDT <- "Hit"
          #CF_CZ_sum$Cond <- "Same"
          CF_LPPC_sum$NumbersOf <- length(CF_LPPC_no_outlier$Acc[CF_LPPC_no_outlier$subj == s & 
                                                               CF_LPPC_no_outlier$Cong == c & 
                                                               CF_LPPC_no_outlier$Alig == a & 
                                                               (CF_LPPC_no_outlier$SDT == "Hit")])
          CF_LPPC_sum$Acc <- mean(CF_LPPC_no_outlier$Acc[CF_LPPC_no_outlier$subj == s & 
                                                        CF_LPPC_no_outlier$Cong == c & 
                                                        CF_LPPC_no_outlier$Alig == a & 
                                                        (CF_LPPC_no_outlier$SDT == "Hit" | CF_LPPC_no_outlier$SDT == "Miss")])
          CF_LPPC_sum$MRT <- mean(CF_LPPC_no_outlier$RT[CF_LPPC_no_outlier$subj == s & 
                                                        CF_LPPC_no_outlier$Cong == c & 
                                                        CF_LPPC_no_outlier$Alig == a & 
                                                        (CF_LPPC_no_outlier$SDT == "Hit")])
          iter <- iter + 1
        }
        else if(condition == 2){
          CF_LPPC_sum$SDT <- "Miss"
       #   CF_CZ_sum$Cond <- "Same"
          CF_LPPC_sum$NumbersOf <- length(CF_LPPC_no_outlier$Acc[CF_LPPC_no_outlier$subj == s & 
                                                               CF_LPPC_no_outlier$Cong == c & 
                                                               CF_LPPC_no_outlier$Alig == a & 
                                                               (CF_LPPC_no_outlier$SDT == "Miss")])
            CF_LPPC_sum$Acc <- NaN
          #CF_CZ_sum$Acc <- mean(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
           #                                             CF_CZ_no_outlier$Cong == c & 
           #                                             CF_CZ_no_outlier$Alig == a & 
            #                                            (CF_CZ_no_outlier$SDT == "Miss")])
          CF_LPPC_sum$MRT <- mean(CF_LPPC_no_outlier$RT[CF_LPPC_no_outlier$subj == s & 
                                                      CF_LPPC_no_outlier$Cong == c & 
                                                      CF_LPPC_no_outlier$Alig == a & 
                                                      (CF_LPPC_no_outlier$SDT == "Miss")])
          CF_LPPC_sum2$HitRate[iter - 1] <- CF_LPPC_sum2$NumbersOf[iter -1]/(CF_LPPC_sum2$NumbersOf[iter -1] + CF_LPPC_sum$NumbersOf)
          Hitrate <- CF_LPPC_sum2$HitRate[iter - 1]
          iter <- iter + 1
        }
        else if(condition == 3){
          CF_LPPC_sum$SDT <- "FalseAlarm"
      #    CF_CZ_sum$Cond <- "Different"
          CF_LPPC_sum$NumbersOf <- length(CF_LPPC_no_outlier$Acc[CF_LPPC_no_outlier$subj == s & 
                                                               CF_LPPC_no_outlier$Cong == c & 
                                                               CF_LPPC_no_outlier$Alig == a & 
                                                               (CF_LPPC_no_outlier$SDT == "FalseAlarm")])
            CF_LPPC_sum$Acc <- NaN
            
        #  CF_CZ_sum$Acc <- mean(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
         #                                              CF_CZ_no_outlier$Cong == c & 
          #                                             CF_CZ_no_outlier$Alig == a & 
           #                                            (CF_CZ_no_outlier$SDT == "FalseAlarm")])
          CF_LPPC_sum$MRT <- mean(CF_LPPC_no_outlier$RT[CF_LPPC_no_outlier$subj == s & 
                                                      CF_LPPC_no_outlier$Cong == c & 
                                                      CF_LPPC_no_outlier$Alig == a & 
                                                      (CF_LPPC_no_outlier$SDT == "FalseAlarm")])
          iter <- iter + 1
        }
        else if(condition == 4){
          CF_LPPC_sum$SDT <- "CorrReject"
     #     CF_CZ_sum$Cond <- "Different"
          CF_LPPC_sum$NumbersOf <- length(CF_LPPC_no_outlier$Acc[CF_LPPC_no_outlier$subj == s & 
                                                               CF_LPPC_no_outlier$Cong == c & 
                                                               CF_LPPC_no_outlier$Alig == a & 
                                                               (CF_LPPC_no_outlier$SDT == "CorrReject")])
          CF_LPPC_sum$Acc <- mean(CF_LPPC_no_outlier$Acc[CF_LPPC_no_outlier$subj == s & 
                                                       CF_LPPC_no_outlier$Cong == c & 
                                                       CF_LPPC_no_outlier$Alig == a & 
                                                       (CF_LPPC_no_outlier$SDT == "CorrReject" | CF_LPPC_no_outlier$SDT == "FalseAlarm")])
          CF_LPPC_sum$MRT <- mean(CF_LPPC_no_outlier$RT[CF_LPPC_no_outlier$subj == s & 
                                                      CF_LPPC_no_outlier$Cong == c & 
                                                      CF_LPPC_no_outlier$Alig == a & 
                                                      (CF_LPPC_no_outlier$SDT == "CorrReject")])
          CF_LPPC_sum2$FalseAlarmRate[iter - 3] <- CF_LPPC_sum2$NumbersOf[iter -1]/(CF_LPPC_sum2$NumbersOf[iter -1] + CF_LPPC_sum$NumbersOf)
          Falsealarmrate <- CF_LPPC_sum2$FalseAlarmRate[iter - 3]
          iter <- iter + 1
        }
        CF_LPPC_sum2 <- rbind(CF_LPPC_sum2,CF_LPPC_sum)
      }
      le<- length(CF_LPPC_no_outlier$Acc[CF_LPPC_no_outlier$subj == s & 
                                                        CF_LPPC_no_outlier$Cong == c & 
                                                        CF_LPPC_no_outlier$Alig == a ])
      if(Hitrate == 1){
          qnorm_hit <- qnorm((le-0.5)/le)
          Hitrate <- 1-1/(2*le)
      }
      else if(Hitrate == 0){
          qnorm_hit <- qnorm((0.5)/le)
          Hitrate <- 1/(2*le)
      }
      else 
          qnorm_hit <- qnorm(Hitrate)
      if(Falsealarmrate == 1){
           Falsealarmrate <- 1-1/(2*le)
          qnorm_fa <- qnorm((le-0.5)/le)
      }
      else if(Falsealarmrate == 0){
          qnorm_fa <- qnorm((0.5)/le)
          Falsealarmrate <- 1/(2*le)
      }
      else 
          qnorm_fa <- qnorm(Falsealarmrate)
      #CF_CZ_sum2$dPrime[iter - 4] <- pnorm((qnorm_hit - qnorm_fa)/sqrt(2))
      CF_LPPC_sum2$dPrime[iter - 4] <- (qnorm_hit - qnorm_fa)
      CF_LPPC_sum2$bias[iter - 4] <- -0.5 * (qnorm_hit + qnorm_fa)
      #CF_LPPC_sum2$dPrime[iter - 4] <- 0.5 + sign(Hitrate - Falsealarmrate) * 
       #   (((Hitrate - Falsealarmrate)^2 + abs(Hitrate - Falsealarmrate)) / 
        #  (4 * max(Hitrate , Falsealarmrate) - 4 * Hitrate * Falsealarmrate))
    }

# %%
CF_LPPC_sum2 <- CF_LPPC_sum2[-c(1),]
CF_LPPC_sum2
# Out:
#     subj Cong        Alig          Acc       MRT       SDT        NumbersOf
# 2   1    Congruent   Alignment     0.9500000 0.5759594 Hit        19
# 3   1    Congruent   Alignment           NaN 0.4054459 Miss        1
# 4   1    Congruent   Alignment           NaN 0.3539888 FalseAlarm  1
# 5   1    Congruent   Alignment     0.9500000 0.6817532 CorrReject 19
# 6   1    Congruent   MissAlignment 0.9000000 0.5376414 Hit        18
# 7   1    Congruent   MissAlignment       NaN 0.5991664 Miss        2
# 8   1    Congruent   MissAlignment       NaN 0.5355876 FalseAlarm  3
# 9   1    Congruent   MissAlignment 0.8500000 0.6790747 CorrReject 17
# 10  1    InCongruent Alignment     0.9000000 0.5595056 Hit        18
# 11  1    InCongruent Alignment           NaN 0.6368194 Miss        2
# 12  1    InCongruent Alignment           NaN 0.5860820 FalseAlarm  3
# 13  1    InCongruent Alignment     0.8421053 0.6179911 CorrReject 16
# 14  1    InCongruent MissAlignment 1.0000000 0.6024559 Hit        19
# 15  1    InCongruent MissAlignment       NaN       NaN Miss        0
# 16  1    InCongruent MissAlignment       NaN 0.7284719 FalseAlarm  4
# 17  1    InCongruent MissAlignment 0.8000000 0.6729276 CorrReject 16
# 18  2    Congruent   Alignment     1.0000000 0.4529808 Hit        20
# 19  2    Congruent   Alignment           NaN       NaN Miss        0
# 20  2    Congruent   Alignment           NaN 0.5099061 FalseAlarm  2
# 21  2    Congruent   Alignment     0.9000000 0.5627743 CorrReject 18
# 22  2    Congruent   MissAlignment 0.7500000 0.5731975 Hit        15
# 23  2    Congruent   MissAlignment       NaN 0.7193572 Miss        5
# 24  2    Congruent   MissAlignment       NaN 0.6083368 FalseAlarm  1
# 25  2    Congruent   MissAlignment 0.9500000 0.5708208 CorrReject 19
# 26  2    InCongruent Alignment     0.8421053 0.5173748 Hit        16
# 27  2    InCongruent Alignment           NaN 0.7466983 Miss        3
# 28  2    InCongruent Alignment           NaN       NaN FalseAlarm  0
# 29  2    InCongruent Alignment     1.0000000 0.6340164 CorrReject 20
# 30  2    InCongruent MissAlignment 0.7368421 0.5190730 Hit        14
# 31  2    InCongruent MissAlignment       NaN 0.6713483 Miss        5
# ⋮   ⋮    ⋮           ⋮             ⋮         ⋮         ⋮          ⋮
# 500 35   Congruent   Alignment           NaN 0.6686539 FalseAlarm  4
# 501 35   Congruent   Alignment     0.8000000 0.6384369 CorrReject 16
# 502 35   Congruent   MissAlignment 0.9000000 0.6012651 Hit        18
# 503 35   Congruent   MissAlignment       NaN 0.7863462 Miss        2
# 504 35   Congruent   MissAlignment       NaN       NaN FalseAlarm  0
# 505 35   Congruent   MissAlignment 1.0000000 0.6418805 CorrReject 19
# 506 35   InCongruent Alignment     1.0000000 0.4896043 Hit        20
# 507 35   InCongruent Alignment           NaN       NaN Miss        0
# 508 35   InCongruent Alignment           NaN 0.6568061 FalseAlarm  2
# 509 35   InCongruent Alignment     0.9000000 0.6221552 CorrReject 18
# 510 35   InCongruent MissAlignment 1.0000000 0.6188222 Hit        20
# 511 35   InCongruent MissAlignment       NaN       NaN Miss        0
# 512 35   InCongruent MissAlignment       NaN 0.5503381 FalseAlarm  1
# 513 35   InCongruent MissAlignment 0.9500000 0.6034698 CorrReject 19
# 514 36   Congruent   Alignment     0.9000000 0.6475334 Hit        18
# 515 36   Congruent   Alignment           NaN 0.6431990 Miss        2
# 516 36   Congruent   Alignment           NaN       NaN FalseAlarm  0
# 517 36   Congruent   Alignment     1.0000000 0.5757720 CorrReject 20
# 518 36   Congruent   MissAlignment 0.9500000 0.6680381 Hit        19
# 519 36   Congruent   MissAlignment       NaN 0.4546345 Miss        1
# 520 36   Congruent   MissAlignment       NaN       NaN FalseAlarm  0
# 521 36   Congruent   MissAlignment 1.0000000 0.5958187 CorrReject 20
# 522 36   InCongruent Alignment     0.5789474 0.6139592 Hit        11
# 523 36   InCongruent Alignment           NaN 0.6650115 Miss        8
# 524 36   InCongruent Alignment           NaN       NaN FalseAlarm  0
# 525 36   InCongruent Alignment     1.0000000 0.6099607 CorrReject 20
# 526 36   InCongruent MissAlignment 0.9000000 0.7077158 Hit        18
# 527 36   InCongruent MissAlignment       NaN 0.8665917 Miss        2
# 528 36   InCongruent MissAlignment       NaN 0.5364310 FalseAlarm  1
# 529 36   InCongruent MissAlignment 0.9500000 0.6808294 CorrReject 19
#     HitRate   FalseAlarmRate dPrime   bias
# 2   0.9500000 0.0500000      3.289707  5.551115e-16
# 3         NaN       NaN           NaN           NaN
# 4         NaN       NaN           NaN           NaN
# 5         NaN       NaN           NaN           NaN
# 6   0.9000000 0.1500000      2.317985 -1.225591e-01
# 7         NaN       NaN           NaN           NaN
# 8         NaN       NaN           NaN           NaN
# 9         NaN       NaN           NaN           NaN
# 10  0.9000000 0.1578947      2.284700 -1.392018e-01
# 11        NaN       NaN           NaN           NaN
# 12        NaN       NaN           NaN           NaN
# 13        NaN       NaN           NaN           NaN
# 14  1.0000000 0.2000000      3.073227 -6.949923e-01
# 15        NaN       NaN           NaN           NaN
# 16        NaN       NaN           NaN           NaN
# 17        NaN       NaN           NaN           NaN
# 18  1.0000000 0.1000000      3.522954 -4.799256e-01
# 19        NaN       NaN           NaN           NaN
# 20        NaN       NaN           NaN           NaN
# 21        NaN       NaN           NaN           NaN
# 22  0.7500000 0.0500000      2.319343  4.851819e-01
# 23        NaN       NaN           NaN           NaN
# 24        NaN       NaN           NaN           NaN
# 25        NaN       NaN           NaN           NaN
# 26  0.8421053 0.0000000      3.234754  6.142289e-01
# 27        NaN       NaN           NaN           NaN
# 28        NaN       NaN           NaN           NaN
# 29        NaN       NaN           NaN           NaN
# 30  0.7368421 0.0000000      2.855160  7.939398e-01
# 31        NaN       NaN           NaN           NaN
# ⋮   ⋮         ⋮              ⋮        ⋮
# 500       NaN  NaN                NaN        NaN
# 501       NaN  NaN                NaN        NaN
# 502 0.9000000 0.00           3.513157  0.4750271
# 503       NaN  NaN                NaN        NaN
# 504       NaN  NaN                NaN        NaN
# 505       NaN  NaN                NaN        NaN
# 506 1.0000000 0.10           3.522954 -0.4799256
# 507       NaN  NaN                NaN        NaN
# 508       NaN  NaN                NaN        NaN
# 509       NaN  NaN                NaN        NaN
# 510 1.0000000 0.05           3.886256 -0.2982746
# 511       NaN  NaN                NaN        NaN
# 512       NaN  NaN                NaN        NaN
# 513       NaN  NaN                NaN        NaN
# 514 0.9000000 0.00           3.522954  0.4799256
# 515       NaN  NaN                NaN        NaN
# 516       NaN  NaN                NaN        NaN
# 517       NaN  NaN                NaN        NaN
# 518 0.9500000 0.00           3.886256  0.2982746
# 519       NaN  NaN                NaN        NaN
# 520       NaN  NaN                NaN        NaN
# 521       NaN  NaN                NaN        NaN
# 522 0.5789474 0.00           2.430807  1.0162023
# 523       NaN  NaN                NaN        NaN
# 524       NaN  NaN                NaN        NaN
# 525       NaN  NaN                NaN        NaN
# 526 0.9000000 0.05           2.926405  0.1816510
# 527       NaN  NaN                NaN        NaN
# 528       NaN  NaN                NaN        NaN
# 529       NaN  NaN                NaN        NaN

# %%
CF_LPPC_sum_dprime <- CF_LPPC_sum2[which(CF_LPPC_sum2$dPrime != "NaN"),]
#CF_CZ_sum_dprime <- CF_CZ_sum2[which(CF_CZ_sum2$dPrime != "NaN" & CF_CZ_sum2$dPrime != "Inf"),]

# %%
CF_LPPC_sum_dprime
# Out:
#     subj Cong        Alig          Acc       MRT       SDT NumbersOf HitRate
# 2    1   Congruent   Alignment     0.9500000 0.5759594 Hit 19        0.9500000
# 6    1   Congruent   MissAlignment 0.9000000 0.5376414 Hit 18        0.9000000
# 10   1   InCongruent Alignment     0.9000000 0.5595056 Hit 18        0.9000000
# 14   1   InCongruent MissAlignment 1.0000000 0.6024559 Hit 19        1.0000000
# 18   2   Congruent   Alignment     1.0000000 0.4529808 Hit 20        1.0000000
# 22   2   Congruent   MissAlignment 0.7500000 0.5731975 Hit 15        0.7500000
# 26   2   InCongruent Alignment     0.8421053 0.5173748 Hit 16        0.8421053
# 30   2   InCongruent MissAlignment 0.7368421 0.5190730 Hit 14        0.7368421
# 34   3   Congruent   Alignment     0.8888889 1.0620800 Hit 16        0.8888889
# 38   3   Congruent   MissAlignment 0.7000000 1.1715136 Hit 14        0.7000000
# 42   3   InCongruent Alignment     0.4500000 1.3524986 Hit  9        0.4500000
# 46   3   InCongruent MissAlignment 0.6315789 1.1746741 Hit 12        0.6315789
# 50   5   Congruent   Alignment     1.0000000 0.5006951 Hit 20        1.0000000
# 54   5   Congruent   MissAlignment 0.9500000 0.5076162 Hit 19        0.9500000
# 58   5   InCongruent Alignment     0.7368421 0.5018797 Hit 14        0.7368421
# 62   5   InCongruent MissAlignment 0.8947368 0.5219494 Hit 17        0.8947368
# 66   6   Congruent   Alignment     0.9500000 0.6117815 Hit 19        0.9500000
# 70   6   Congruent   MissAlignment 1.0000000 0.6590172 Hit 20        1.0000000
# 74   6   InCongruent Alignment     0.9000000 0.6857008 Hit 18        0.9000000
# 78   6   InCongruent MissAlignment 0.9500000 0.6336097 Hit 19        0.9500000
# 82   7   Congruent   Alignment     0.9500000 0.9210175 Hit 19        0.9500000
# 86   7   Congruent   MissAlignment 0.5789474 0.9407388 Hit 11        0.5789474
# 90   7   InCongruent Alignment     0.6500000 0.9521614 Hit 13        0.6500000
# 94   7   InCongruent MissAlignment 0.7894737 1.1427487 Hit 15        0.7894737
# 98   8   Congruent   Alignment     0.9500000 0.8898591 Hit 19        0.9500000
# 102  8   Congruent   MissAlignment 0.9500000 0.9149754 Hit 19        0.9500000
# 106  8   InCongruent Alignment     0.9500000 1.1278698 Hit 19        0.9500000
# 110  8   InCongruent MissAlignment 1.0000000 0.8010059 Hit 20        1.0000000
# 114 11   Congruent   Alignment     0.9000000 0.6276869 Hit 18        0.9000000
# 118 11   Congruent   MissAlignment 0.6500000 0.7064724 Hit 13        0.6500000
# ⋮   ⋮    ⋮           ⋮             ⋮         ⋮         ⋮   ⋮         ⋮
# 410 29   InCongruent Alignment     0.9444444 0.7489858 Hit 17        0.9444444
# 414 29   InCongruent MissAlignment 0.9473684 0.7275354 Hit 18        0.9473684
# 418 30   Congruent   Alignment     1.0000000 0.5034887 Hit 20        1.0000000
# 422 30   Congruent   MissAlignment 1.0000000 0.5343914 Hit 20        1.0000000
# 426 30   InCongruent Alignment     1.0000000 0.5531455 Hit 20        1.0000000
# 430 30   InCongruent MissAlignment 0.9500000 0.5589545 Hit 19        0.9500000
# 434 31   Congruent   Alignment     0.9500000 0.4860119 Hit 19        0.9500000
# 438 31   Congruent   MissAlignment 0.9000000 0.4834507 Hit 18        0.9000000
# 442 31   InCongruent Alignment     0.9000000 0.5339250 Hit 18        0.9000000
# 446 31   InCongruent MissAlignment 0.8947368 0.5661962 Hit 17        0.8947368
# 450 32   Congruent   Alignment     1.0000000 0.6528953 Hit 20        1.0000000
# 454 32   Congruent   MissAlignment 1.0000000 0.7380030 Hit 19        1.0000000
# 458 32   InCongruent Alignment     0.8947368 0.7499736 Hit 17        0.8947368
# 462 32   InCongruent MissAlignment 0.9500000 0.8001234 Hit 19        0.9500000
# 466 33   Congruent   Alignment     1.0000000 0.6296572 Hit 20        1.0000000
# 470 33   Congruent   MissAlignment 0.8947368 0.6474264 Hit 17        0.8947368
# 474 33   InCongruent Alignment     1.0000000 0.6767898 Hit 20        1.0000000
# 478 33   InCongruent MissAlignment 0.8421053 0.6155200 Hit 16        0.8421053
# 482 34   Congruent   Alignment     1.0000000 0.5877669 Hit 20        1.0000000
# 486 34   Congruent   MissAlignment 0.9500000 0.7002336 Hit 19        0.9500000
# 490 34   InCongruent Alignment     0.8500000 0.6837920 Hit 17        0.8500000
# 494 34   InCongruent MissAlignment 0.7500000 0.6830697 Hit 15        0.7500000
# 498 35   Congruent   Alignment     1.0000000 0.4794247 Hit 19        1.0000000
# 502 35   Congruent   MissAlignment 0.9000000 0.6012651 Hit 18        0.9000000
# 506 35   InCongruent Alignment     1.0000000 0.4896043 Hit 20        1.0000000
# 510 35   InCongruent MissAlignment 1.0000000 0.6188222 Hit 20        1.0000000
# 514 36   Congruent   Alignment     0.9000000 0.6475334 Hit 18        0.9000000
# 518 36   Congruent   MissAlignment 0.9500000 0.6680381 Hit 19        0.9500000
# 522 36   InCongruent Alignment     0.5789474 0.6139592 Hit 11        0.5789474
# 526 36   InCongruent MissAlignment 0.9000000 0.7077158 Hit 18        0.9000000
#     FalseAlarmRate dPrime    bias
# 2   0.05000000     3.2897073  5.551115e-16
# 6   0.15000000     2.3179850 -1.225591e-01
# 10  0.15789474     2.2846995 -1.392018e-01
# 14  0.20000000     3.0732271 -6.949923e-01
# 18  0.10000000     3.5229543 -4.799256e-01
# 22  0.05000000     2.3193434  4.851819e-01
# 26  0.00000000     3.2347538  6.142289e-01
# 30  0.00000000     2.8551596  7.939398e-01
# 34  0.10000000     2.5021919  3.045561e-02
# 38  0.05000000     2.1692541  5.602266e-01
# 42  0.15000000     0.9107720  5.810474e-01
# 46  0.30000000     0.8604387  9.418119e-02
# 50  0.10000000     3.5229543 -4.799256e-01
# 54  0.05000000     3.2897073  5.551115e-16
# 58  0.10000000     1.9151916  3.239558e-01
# 62  0.20000000     2.0937408 -2.052491e-01
# 66  0.10000000     2.9264052 -1.816510e-01
# 70  0.05000000     3.8862564 -2.982746e-01
# 74  0.15000000     2.3179850 -1.225591e-01
# 78  0.00000000     3.8663732  2.883330e-01
# 82  0.05000000     3.2897073  5.551115e-16
# 86  0.16666667     1.1666229  3.841101e-01
# 90  0.25000000     1.0598102  1.445846e-01
# 94  0.10000000     2.0861479  2.384776e-01
# 98  0.00000000     3.8764595  2.933761e-01
# 102 0.00000000     3.8764595  2.933761e-01
# 106 0.05555556     3.2380724 -2.581740e-02
# 110 0.10000000     3.5229543 -4.799256e-01
# 114 0.15000000     2.3179850 -1.225591e-01
# 118 0.05000000     2.0301741  6.297666e-01
# ⋮   ⋮              ⋮         ⋮
# 410 0.05000000     3.238072   2.581740e-02
# 414 0.05000000     3.264710   1.249868e-02
# 418 0.10000000     3.522954  -4.799256e-01
# 422 0.15789474     3.234754  -6.142289e-01
# 426 0.00000000     4.463212  -6.661338e-16
# 430 0.05000000     3.289707   5.551115e-16
# 434 0.10000000     2.926405  -1.816510e-01
# 438 0.10000000     2.563103   0.000000e+00
# 442 0.10000000     2.563103   0.000000e+00
# 446 0.05263158     2.871976   1.838684e-01
# 450 0.10000000     3.522954  -4.799256e-01
# 454 0.10526316     3.473639  -4.847000e-01
# 458 0.31578947     1.731625  -3.863069e-01
# 462 0.22222222     2.409563  -4.400720e-01
# 466 0.00000000     4.463212  -6.661338e-16
# 470 0.10000000     2.533671   1.471602e-02
# 474 0.15789474     3.234754  -6.142289e-01
# 478 0.05263158     2.623004   3.083541e-01
# 482 0.00000000     4.482805  -8.881784e-16
# 486 0.00000000     3.876459   2.933761e-01
# 490 0.05263158     2.656290   2.917114e-01
# 494 0.05000000     2.319343   4.851819e-01
# 498 0.20000000     3.073227  -6.949923e-01
# 502 0.00000000     3.513157   4.750271e-01
# 506 0.10000000     3.522954  -4.799256e-01
# 510 0.05000000     3.886256  -2.982746e-01
# 514 0.00000000     3.522954   4.799256e-01
# 518 0.00000000     3.886256   2.982746e-01
# 522 0.00000000     2.430807   1.016202e+00
# 526 0.05000000     2.926405   1.816510e-01

# %%
#save(CF_LPPC_sum_dprime,file="CF_LPPC_sum_dprime.Rda")

# %%
CF_LPPC_sum_dprime %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(dPrime, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean  sd
# 1 Congruent   Alignment     dPrime   33 3.377 0.811
# 2 Congruent   MissAlignment dPrime   33 3.038 0.835
# 3 InCongruent Alignment     dPrime   33 2.630 1.081
# 4 InCongruent MissAlignment dPrime   33 2.635 1.023

# %%
# CF_LPPC_sum_dprime[which(CF_LPPC_sum_dprime$dPrime<=0.6),]

# %%
# dd <- CF_LPPC_sum_dprime[which(CF_LPPC_sum_dprime$dPrime<=0.6),]

# #qnorm(0.65) - qnorm(0.85)

# CF_LPPC_sum_dprime2<- CF_LPPC_sum_dprime %>% 
#   anti_join(dd, by = "dPrime") 
# CF_LPPC_sum_dprime2[which(CF_LPPC_sum_dprime2$dPrime<=0.6),]

# %%
# CF_LPPC_sum_dprime2 %>%
#   group_by(Cong, Alig) %>%
#   get_summary_stats(dPrime, type = "mean_sd")

# %%
# ggdensity(CF_LPPC_sum_dprime2$dPrime[CF_LPPC_sum_dprime2$Cong == "InCongruent" & 
#                                             CF_LPPC_sum_dprime2$Alig == "Alignment" ], rug = TRUE, fill = "lightgray")

# %%
ggdensity(CF_LPPC_sum_dprime, x = "dPrime",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
# CF_LPPC_sum_dprime %>%
#   group_by(Cong, Alig) %>%
#   get_summary_stats(dPrime, type = "mean_sd")

# %%
CF_LPPC_sum_dprime %>% group_by(Cong, Alig) %>% shapiro_test(dPrime)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     dPrime   0.9420467 0.07792366
# 2 Congruent   MissAlignment dPrime   0.9602436 0.26260900
# 3 InCongruent Alignment     dPrime   0.9581438 0.22893097
# 4 InCongruent MissAlignment dPrime   0.9585050 0.23442661

# %%
ggqqplot(CF_LPPC_sum_dprime, "dPrime", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_LPPC_sum_dprime, x = "Alig", y = "dPrime",
  color = "Cong", palette = "jco", 
    #outlier.shape = NA, 
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
CF_LPPC_sum_dprime %>%
  group_by(Cong, Alig) %>%
  identify_outliers(dPrime)
# Out:
#   Cong        Alig          subj Acc       MRT       SDT NumbersOf HitRate
# 1 Congruent   Alignment     15   0.9000000 0.6065537 Hit 18        0.9000000
# 2 Congruent   MissAlignment 15   0.8000000 0.6496785 Hit 16        0.8000000
# 3 InCongruent Alignment     15   0.8500000 0.6268208 Hit 17        0.8500000
# 4 InCongruent Alignment     18   0.5500000 0.7424563 Hit 11        0.5500000
# 5 InCongruent MissAlignment 11   0.5789474 0.8912614 Hit 11        0.5789474
#   FalseAlarmRate dPrime     bias        is.outlier is.extreme
# 1 0.4736842       1.3475634 -0.60776988 TRUE       FALSE
# 2 0.4500000       0.9672826 -0.35797994 TRUE       FALSE
# 3 0.6000000       0.7830863 -0.64489025 TRUE       FALSE
# 4 0.6842105      -0.3538443 -0.30258350 TRUE       FALSE
# 5 0.5000000       0.1992013 -0.09960066 TRUE       FALSE

# %%
#save(CF_LPPC_sum_dprime3,file="CF_LPPC_sum_dprime3.Rda")

# %%
res.aov <- anova_test(
  data = CF_LPPC_sum_dprime, dv = dPrime, wid = subj,
  within = c(Cong, Alig)
)
get_anova_table(res.aov)
# Out:
#   Effect    DFn DFd F      p        p<.05 ges
# 1 Cong      1   32  27.473 9.84e-06 *     0.087
# 2 Alig      1   32   2.230 1.45e-01       0.008
# 3 Cong:Alig 1   32   2.860 1.01e-01       0.008

# %%
one.way <- CF_LPPC_sum_dprime %>%
  group_by(Cong) %>%
  anova_test(dv = dPrime, wid = subj, within = Alig) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way
# Out:
#   Cong        Effect DFn DFd F        p     p<.05 ges      p.adj
# 1 Congruent   Alig   1   32  5.641000 0.024 *     4.20e-02 0.048
# 2 InCongruent Alig   1   32  0.000713 0.979       4.19e-06 1.000

# %%
one.way2 <- CF_LPPC_sum_dprime %>%
  group_by(Alig) %>%
  anova_test(dv = dPrime, wid = subj, within = Cong) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way2
# Out:
#   Alig          Effect DFn DFd F      p        p<.05 ges   p.adj
# 1 Alignment     Cong   1   32  20.118 8.81e-05 *     0.136 0.0001762
# 2 MissAlignment Cong   1   32   9.651 4.00e-03 *     0.046 0.0080000

# %% [markdown]
# # Bias

# %%
#CF_CZ_sum_bias <- CF_CZ_sum2[which(CF_CZ_sum2$bias != "NaN"),]
#CF_CZ_sum_bias
CF_LPPC_sum_bias <- CF_LPPC_sum_dprime

# %%
CF_LPPC_sum_bias %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(bias, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean   sd
# 1 Congruent   Alignment     bias     33 -0.177 0.294
# 2 Congruent   MissAlignment bias     33  0.068 0.416
# 3 InCongruent Alignment     bias     33  0.009 0.420
# 4 InCongruent MissAlignment bias     33 -0.028 0.365

# %%
ggdensity(CF_LPPC_sum_bias, x = "bias",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_LPPC_sum_bias, x = "Alig", y = "bias",
  color = "Cong", palette = "jco", outlier.shape = NA, 
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
CF_LPPC_sum_bias %>% group_by(Cong, Alig) %>% shapiro_test(bias)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     bias     0.9537502 0.1710599
# 2 Congruent   MissAlignment bias     0.9689463 0.4516593
# 3 InCongruent Alignment     bias     0.9884277 0.9732969
# 4 InCongruent MissAlignment bias     0.9788544 0.7510570

# %%
ggqqplot(CF_LPPC_sum_bias, "bias", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
#save(CF_LPPC_sum_bias,file="CF_LPPC_sum_bias.Rda")

# %%
CF_LPPC_sum_bias %>%
  group_by(Cong, Alig) %>%
  identify_outliers(bias)
# Out:
#      Cong Alig subj Acc MRT SDT NumbersOf HitRate FalseAlarmRate dPrime bias
#      is.outlier is.extreme

# %%
res.aov <- anova_test(
  data = CF_LPPC_sum_bias, dv = bias, wid = subj,
  within = c(Cong, Alig)
)
get_anova_table(res.aov)
# Out:
#   Effect    DFn DFd F     p     p<.05 ges
# 1 Cong      1   32  0.733 0.398       0.004
# 2 Alig      1   32  3.510 0.070       0.019
# 3 Cong:Alig 1   32  8.106 0.008 *     0.035

# %%
one.way <- CF_LPPC_sum_bias %>%
  group_by(Cong) %>%
  anova_test(dv = dPrime, wid = subj, within = Alig) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way
# Out:
#   Cong        Effect DFn DFd F        p     p<.05 ges      p.adj
# 1 Congruent   Alig   1   32  5.641000 0.024 *     4.20e-02 0.048
# 2 InCongruent Alig   1   32  0.000713 0.979       4.19e-06 1.000

# %%
# comparisons for Alig variable
one.way2 <- CF_LPPC_sum_bias %>%
  group_by(Alig) %>%
  anova_test(dv = dPrime, wid = subj, within = Cong) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way2
# Out:
#   Alig          Effect DFn DFd F      p        p<.05 ges   p.adj
# 1 Alignment     Cong   1   32  20.118 8.81e-05 *     0.136 0.0001762
# 2 MissAlignment Cong   1   32   9.651 4.00e-03 *     0.046 0.0080000

# %%
bxp <- ggboxplot(
  CF_LPPC_sum_bias, x = "Alig", y = "bias",
  #color = "Cong", palette = "jco", outlier.shape = NA, 
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %% [markdown]
# # RT

# %%
CF_LPPC_no_outlier[which(CF_LPPC_no_outlier$Acc == 1),]

#CF_CZ_sum_dprime2[which(CF_CZ_sum_dprime2$MRT != "NaN"),]

#CF_CZ_sum_RT <- CF_CZ_sum2[which(CF_CZ_sum2$MRT != "NaN"),]
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     3    InCongruent Alignment     1   0.8274069 Hit
# 2    1     4    Congruent   Alignment     1   0.4575074 Hit
# 3    1     5    InCongruent MissAlignment 1   0.7660545 CorrReject
# 5    1     7    InCongruent Alignment     1   0.5510097 Hit
# 6    1     8    InCongruent Alignment     1   0.6153222 CorrReject
# 8    1    10    InCongruent Alignment     1   0.5955362 Hit
# 9    1    11    InCongruent Alignment     1   0.6110963 CorrReject
# 10   1    12    InCongruent MissAlignment 1   0.8573759 Hit
# 11   1    13    Congruent   Alignment     1   0.9585953 Hit
# 12   1    14    InCongruent MissAlignment 1   0.6466818 CorrReject
# 13   1    15    InCongruent MissAlignment 1   0.9077498 Hit
# 14   1    16    InCongruent MissAlignment 1   0.8222932 Hit
# 15   1    17    InCongruent MissAlignment 1   0.6041764 CorrReject
# 16   1    18    InCongruent Alignment     1   0.8984539 Hit
# 17   1    19    Congruent   MissAlignment 1   0.6361471 CorrReject
# 18   1    20    InCongruent Alignment     1   0.6267027 Hit
# 19   1    21    Congruent   MissAlignment 1   0.5690405 Hit
# 20   1    22    Congruent   MissAlignment 1   0.4023105 Hit
# 21   1    23    InCongruent Alignment     1   0.5203194 CorrReject
# 22   1    24    InCongruent MissAlignment 1   0.4104981 Hit
# 23   1    25    InCongruent MissAlignment 1   0.5693486 CorrReject
# 24   1    26    Congruent   MissAlignment 1   0.6019607 Hit
# 25   1    27    Congruent   Alignment     1   0.5596055 CorrReject
# 27   1    29    Congruent   Alignment     1   0.6223973 CorrReject
# 28   1    30    Congruent   MissAlignment 1   0.5901805 Hit
# 29   1    31    Congruent   Alignment     1   0.7014056 CorrReject
# 30   1    32    Congruent   MissAlignment 1   0.6962265 CorrReject
# 31   1    33    Congruent   Alignment     1   0.6992236 CorrReject
# 32   1    34    Congruent   MissAlignment 1   0.5905003 CorrReject
# 33   1    35    Congruent   Alignment     1   1.0708348 CorrReject
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5149 36   128   InCongruent MissAlignment 1   0.7710805 CorrReject
# 5150 36   129   InCongruent MissAlignment 1   0.7705332 Hit
# 5151 36   130   Congruent   MissAlignment 1   0.6191959 Hit
# 5152 36   131   Congruent   MissAlignment 1   0.5616035 Hit
# 5153 36   132   InCongruent MissAlignment 1   0.5691234 Hit
# 5154 36   133   InCongruent Alignment     1   0.5610647 CorrReject
# 5155 36   134   InCongruent MissAlignment 1   0.8499993 CorrReject
# 5156 36   135   Congruent   MissAlignment 1   0.7754753 Hit
# 5157 36   136   InCongruent MissAlignment 1   0.6625018 CorrReject
# 5158 36   137   InCongruent MissAlignment 1   0.6992759 Hit
# 5159 36   138   InCongruent Alignment     1   0.6774494 Hit
# 5160 36   139   Congruent   Alignment     1   0.8094426 CorrReject
# 5161 36   140   Congruent   Alignment     1   0.6242038 CorrReject
# 5162 36   141   Congruent   Alignment     1   0.6542734 CorrReject
# 5163 36   142   InCongruent MissAlignment 1   0.7485993 CorrReject
# 5164 36   143   InCongruent MissAlignment 1   0.6364574 Hit
# 5165 36   144   Congruent   MissAlignment 1   0.5134005 CorrReject
# 5166 36   145   InCongruent Alignment     1   0.5723828 CorrReject
# 5167 36   146   Congruent   MissAlignment 1   0.6455699 Hit
# 5168 36   147   Congruent   Alignment     1   0.7069662 Hit
# 5169 36   148   Congruent   MissAlignment 1   0.5167189 CorrReject
# 5170 36   149   Congruent   MissAlignment 1   0.7435977 CorrReject
# 5171 36   150   InCongruent Alignment     1   0.5133723 Hit
# 5173 36   152   InCongruent Alignment     1   1.0263196 CorrReject
# 5174 36   153   InCongruent Alignment     1   0.6393396 CorrReject
# 5175 36   154   InCongruent MissAlignment 1   0.6123248 Hit
# 5176 36   155   InCongruent MissAlignment 1   0.6510673 CorrReject
# 5178 36   157   Congruent   Alignment     1   0.7558954 Hit
# 5180 36   159   Congruent   Alignment     1   0.6032860 Hit
# 5181 36   160   Congruent   Alignment     1   0.5302202 Hit

# %%
CF_LPPC_sum <- data.frame(subj = 1,
                       # Cond = NaN,
                        Cong = NaN,
                        Alig = NaN,
                        MRT = NaN
                        )

CF_LPPC_sum2 <- data.frame(subj = NaN,
                      #  Cond = NaN,
                        Cong = NaN,
                        Alig = NaN,
                        MRT = NaN
                        )

# %%
iter <- 2
for(s in 1:36)
  if(s != 10 & s != 9 & s != 4)
  for(c in c("Congruent", "InCongruent"))
    for(a in c("Alignment", "MissAlignment")){
        CF_LPPC_sum$subj <- s
        CF_LPPC_sum$Cong <- c
        CF_LPPC_sum$Alig <- a
        CF_LPPC_sum$MRT <- mean(CF_LPPC_no_outlier$RT[CF_LPPC_no_outlier$subj == s & 
                                                        CF_LPPC_no_outlier$Cong == c & 
                                                        CF_LPPC_no_outlier$Alig == a  
                                                        ])
        iter <- iter + 1
        
        
        CF_LPPC_sum2 <- rbind(CF_LPPC_sum2,CF_LPPC_sum)

    }

# %%
CF_LPPC_sum_RT <- CF_LPPC_sum2

CF_LPPC_sum_RT <- CF_LPPC_sum_RT[-c(1),]

# %%
CF_LPPC_sum_RT
# Out:
#     subj Cong        Alig          MRT
# 2    1   Congruent   Alignment     0.6163994
# 3    1   Congruent   MissAlignment 0.6006728
# 4    1   InCongruent Alignment     0.5895088
# 5    1   InCongruent MissAlignment 0.6442921
# 6    2   Congruent   Alignment     0.5052341
# 7    2   Congruent   MissAlignment 0.5912170
# 8    2   InCongruent Alignment     0.5948313
# 9    2   InCongruent MissAlignment 0.5610024
# 10   3   Congruent   Alignment     1.1357678
# 11   3   Congruent   MissAlignment 1.1480742
# 12   3   InCongruent Alignment     1.2758749
# 13   3   InCongruent MissAlignment 1.1388793
# 14   5   Congruent   Alignment     0.5125412
# 15   5   Congruent   MissAlignment 0.5213904
# 16   5   InCongruent Alignment     0.5501312
# 17   5   InCongruent MissAlignment 0.5373365
# 18   6   Congruent   Alignment     0.6755165
# 19   6   Congruent   MissAlignment 0.6639098
# 20   6   InCongruent Alignment     0.7307038
# 21   6   InCongruent MissAlignment 0.6679484
# 22   7   Congruent   Alignment     1.0055434
# 23   7   Congruent   MissAlignment 1.0695728
# 24   7   InCongruent Alignment     1.2051919
# 25   7   InCongruent MissAlignment 1.0664251
# 26   8   Congruent   Alignment     0.9225928
# 27   8   Congruent   MissAlignment 0.9711760
# 28   8   InCongruent Alignment     1.0631061
# 29   8   InCongruent MissAlignment 0.8807827
# 30  11   Congruent   Alignment     0.6403785
# 31  11   Congruent   MissAlignment 0.6877237
# ⋮   ⋮    ⋮           ⋮             ⋮
# 104 29   InCongruent Alignment     0.7520956
# 105 29   InCongruent MissAlignment 0.7268950
# 106 30   Congruent   Alignment     0.5428416
# 107 30   Congruent   MissAlignment 0.5696142
# 108 30   InCongruent Alignment     0.5735008
# 109 30   InCongruent MissAlignment 0.5808841
# 110 31   Congruent   Alignment     0.5191899
# 111 31   Congruent   MissAlignment 0.5033304
# 112 31   InCongruent Alignment     0.5612575
# 113 31   InCongruent MissAlignment 0.5475297
# 114 32   Congruent   Alignment     0.7059329
# 115 32   Congruent   MissAlignment 0.8549598
# 116 32   InCongruent Alignment     0.7311522
# 117 32   InCongruent MissAlignment 0.8883852
# 118 33   Congruent   Alignment     0.6616211
# 119 33   Congruent   MissAlignment 0.6743753
# 120 33   InCongruent Alignment     0.7067111
# 121 33   InCongruent MissAlignment 0.6401532
# 122 34   Congruent   Alignment     0.6462971
# 123 34   Congruent   MissAlignment 0.6999851
# 124 34   InCongruent Alignment     0.7344471
# 125 34   InCongruent MissAlignment 0.7225611
# 126 35   Congruent   Alignment     0.5640686
# 127 35   Congruent   MissAlignment 0.6305435
# 128 35   InCongruent Alignment     0.5576123
# 129 35   InCongruent MissAlignment 0.6098177
# 130 36   Congruent   Alignment     0.6114360
# 131 36   Congruent   MissAlignment 0.6265933
# 132 36   InCongruent Alignment     0.6223810
# 133 36   InCongruent MissAlignment 0.6986064

# %%
CF_LPPC_sum_dprime$MRT <- CF_LPPC_sum_RT$MRT

# %%
#install.packages("writexl")
library("writexl")
write_xlsx(CF_LPPC_sum_dprime,"/Users/j.amanirad/Desktop/CompositeFace/CF_LPPC_sum_DP.xlsx")

# %%
CF_LPPC_sum_RT %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(MRT, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean  sd
# 1 Congruent   Alignment     MRT      33 0.717 0.166
# 2 Congruent   MissAlignment MRT      33 0.760 0.172
# 3 InCongruent Alignment     MRT      33 0.775 0.200
# 4 InCongruent MissAlignment MRT      33 0.794 0.212

# %%
ggdensity(CF_LPPC_sum_RT, x = "MRT",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
CF_LPPC_sum_RT %>%
  group_by(Cong, Alig) %>%
  identify_outliers(MRT)
# Out:
#   Cong        Alig          subj MRT      is.outlier is.extreme
# 1 Congruent   Alignment      3   1.135768 TRUE       FALSE
# 2 InCongruent MissAlignment 16   1.503673 TRUE       FALSE

# %%
CF_LPPC_sum_RT %>% group_by(Cong, Alig) %>% shapiro_test(MRT)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     MRT      0.9339399 0.04537103
# 2 Congruent   MissAlignment MRT      0.9573435 0.21717547
# 3 InCongruent Alignment     MRT      0.9175299 0.01566056
# 4 InCongruent MissAlignment MRT      0.9234783 0.02289830

# %%
ggqqplot(CF_LPPC_sum_RT, "MRT", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_LPPC_sum_RT, x = "Alig", y = "MRT",
  color = "Cong", palette = "jco",
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
dd <- CF_LPPC_sum_RT %>%
  group_by(Cong, Alig) %>%
  identify_outliers(MRT)

#dd <- dd[which(dd$is.extreme == TRUE),]

#qnorm(0.65) - qnorm(0.85)

CF_LPPC_sum_RT2<- CF_LPPC_sum_RT %>% 
  anti_join(dd, by = "MRT") 

CF_LPPC_sum_RT2 %>%
  group_by(Cong, Alig) %>%
  identify_outliers(MRT)

bxp <- ggboxplot(
  CF_LPPC_sum_RT2, x = "Alig", y = "MRT",
  color = "Cong", palette = "jco", 
  #facet.by = "group", short.panel.labs = FALSE
) 
bxp
# Out:
#      Cong Alig subj MRT is.outlier is.extreme
# plot without title

# %%
CF_LPPC_sum_RT2 %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(MRT, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean  sd
# 1 Congruent   Alignment     MRT      32 0.704 0.150
# 2 Congruent   MissAlignment MRT      33 0.760 0.172
# 3 InCongruent Alignment     MRT      33 0.775 0.200
# 4 InCongruent MissAlignment MRT      32 0.771 0.172

# %%
ggdensity(CF_LPPC_sum_RT2, x = "MRT",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
CF_LPPC_sum_RT2 %>% group_by(Cong, Alig) %>% shapiro_test(MRT)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     MRT      0.9411271 0.08059151
# 2 Congruent   MissAlignment MRT      0.9573435 0.21717547
# 3 InCongruent Alignment     MRT      0.9175299 0.01566056
# 4 InCongruent MissAlignment MRT      0.9717583 0.54929431

# %%
ggqqplot(CF_LPPC_sum_RT2, "MRT", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
#save(CF_LPPC_sum_RT2,file="CF_LPPC_sum_RT2.Rda")

# %%
#t2way(dPrime ~ Cong*Alig, data = CF_CZ_sum_dprime)
#bwtrim(MRT ~ Cong*Alig, id = subj, data = CF_CZ_sum_RT)

# %%
#res.Co <- CF_CZ_sum_RT %>% group_by(Alig) %>% friedman_test(MRT ~ Cong |subj)
#res.Co

# %%
#res.Alig <- CF_CZ_sum_RT %>% group_by(Cong) %>% friedman_test(MRT ~ Alig |subj)
#res.Alig

# %%
res.aov <- anova_test(
  data = CF_LPPC_sum_RT2, dv = MRT, wid = subj,
  within = c(Cong, Alig)
)
get_anova_table(res.aov)
# Out:
#   Effect    DFn DFd F      p        p<.05 ges
# 1 Cong      1   30  39.309 6.58e-07 *     0.015
# 2 Alig      1   30  12.219 1.00e-03 *     0.009
# 3 Cong:Alig 1   30   3.258 8.10e-02       0.003

# %%
one.way <- CF_LPPC_sum_RT2 %>%
  group_by(Alig) %>%
  anova_test(dv = MRT, wid = subj, within = Cong) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way
# Out:
#   Alig          Effect DFn DFd F      p        p<.05 ges   p.adj
# 1 Alignment     Cong   1   31  34.602 1.72e-06 *     0.028 3.44e-06
# 2 MissAlignment Cong   1   31   3.793 6.10e-02       0.004 1.22e-01

# %%
one.way2 <- CF_LPPC_sum_RT2 %>%
  group_by(Cong) %>%
  anova_test(dv = MRT, wid = subj, within = Alig) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way2
# Out:
#   Cong        Effect DFn DFd F      p        p<.05 ges      p.adj
# 1 Congruent   Alig   1   31  21.862 5.43e-05 *     0.021000 0.0001086
# 2 InCongruent Alig   1   31   0.430 5.17e-01       0.000662 1.0000000
