# %% [markdown]
# # Composite Face: CZ

# %%
library(tidyverse)
library(ggpubr)
library(rstatix)
library(readxl)
library(dplyr)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.1     ✔ dplyr   1.0.6
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘rstatix’
#
#
# The following object is masked from ‘package:stats’:
#
#     filter

# %%
#install.packages('WRS2')
library(WRS2)
#conda install -c conda-forge r-wrs2

# %%
setwd("/Users/j.amanirad/Desktop/CompositeFace") 
CF_CZZ <- read_excel("CF_CZ.xlsx")
CF_CZZ
# Out:
#      subject sex    Face_1    Face_2    Face_Gender Congruency Block Trial
# 1    1       male   A_06_07_F R_06_03_F Female      0          1     1
# 2    1       male   A_03_08_F A_05_08_F Female      0          1     2
# 3    1       male   A_05_01_F A_03_08_F Female      1          1     3
# 4    1       male   A_11_13_M A_11_10_M Male        0          1     4
# 5    1       male   A_09_11_M R_09_10_M Male        0          1     5
# 6    1       male   A_09_11_M A_09_11_M Male        1          1     6
# 7    1       male   A_11_14_M A_09_14_M Male        0          1     7
# 8    1       male   A_12_09_M R_09_10_M Male        1          1     8
# 9    1       male   A_12_09_M R_11_13_M Male        1          1     9
# 10   1       male   A_01_02_F A_06_08_F Female      1          1     10
# 11   1       male   A_09_11_M R_09_10_M Male        0          1     11
# 12   1       male   A_11_14_M R_11_14_M Male        1          1     12
# 13   1       male   A_01_03_F A_02_03_F Female      0          1     13
# 14   1       male   A_10_13_M R_10_11_M Male        0          1     14
# 15   1       male   A_05_06_F A_05_06_F Female      1          1     15
# 16   1       male   A_01_04_F R_01_04_F Female      1          1     16
# 17   1       male   A_11_14_M R_11_14_M Male        1          1     17
# 18   1       male   A_12_14_M A_11_14_M Male        0          1     18
# 19   1       male   A_03_02_F R_03_01_F Female      0          1     19
# 20   1       male   A_05_08_F A_06_08_F Female      0          1     20
# 21   1       male   A_01_03_F A_05_07_F Female      1          1     21
# 22   1       male   A_12_15_M A_10_11_M Male        1          1     22
# 23   1       male   A_11_10_M A_14_11_M Male        1          1     23
# 24   1       male   A_02_06_F R_05_06_F Female      0          1     24
# 25   1       male   A_05_06_F R_06_05_F Female      1          1     25
# 26   1       male   A_09_10_M R_09_10_M Male        1          1     26
# 27   1       male   A_10_11_M A_10_12_M Male        0          1     27
# 28   1       male   A_01_03_F R_01_03_F Female      1          1     28
# 29   1       male   A_02_06_F R_05_06_F Female      0          1     29
# 30   1       male   A_03_01_F A_03_01_F Female      1          1     30
# ⋮    ⋮       ⋮      ⋮         ⋮         ⋮           ⋮          ⋮     ⋮
# 5731 36      female A_01_03_F A_05_06_F Female      1          4     131
# 5732 36      female A_05_08_F R_05_08_F Female      1          4     132
# 5733 36      female A_01_05_F A_01_02_F Female      0          4     133
# 5734 36      female A_14_12_M R_14_09_M Male        0          4     134
# 5735 36      female A_09_14_M R_09_14_M Male        1          4     135
# 5736 36      female A_12_10_M R_12_15_M Male        0          4     136
# 5737 36      female A_11_10_M R_11_10_M Male        1          4     137
# 5738 36      female A_12_10_M R_11_10_M Male        0          4     138
# 5739 36      female A_05_01_F R_03_02_F Female      1          4     139
# 5740 36      female A_03_01_F A_03_01_F Female      1          4     140
# 5741 36      female A_14_15_M R_14_12_M Male        0          4     141
# 5742 36      female A_09_14_M A_11_14_M Male        0          4     142
# 5743 36      female A_01_05_F R_01_05_F Female      1          4     143
# 5744 36      female A_09_11_M R_11_09_M Male        1          4     144
# 5745 36      female A_14_15_M R_14_15_M Male        1          4     145
# 5746 36      female A_05_08_F R_06_08_F Female      0          4     146
# 5747 36      female A_05_06_F A_05_06_F Female      1          4     147
# 5748 36      female A_09_12_M A_09_11_M Male        0          4     148
# 5749 36      female A_01_04_F R_02_04_F Female      0          4     149
# 5750 36      female A_01_04_F R_02_04_F Female      0          4     150
# 5751 36      female A_11_13_M A_11_13_M Male        1          4     151
# 5752 36      female A_12_10_M A_12_14_M Male        0          4     152
# 5753 36      female A_14_11_M A_14_09_M Male        0          4     153
# 5754 36      female A_02_06_F A_02_03_F Female      0          4     154
# 5755 36      female A_12_14_M A_11_14_M Male        0          4     155
# 5756 36      female A_06_05_F A_01_05_F Female      0          4     156
# 5757 36      female A_10_12_M A_10_12_M Male        1          4     157
# 5758 36      female A_03_04_F A_02_04_F Female      0          4     158
# 5759 36      female A_12_09_M R_14_09_M Male        0          4     159
# 5760 36      female A_05_06_F A_02_06_F Female      0          4     160
#      Alignment Condition Type                   Key_Resp Cor_Ans Accuracy
# 1    0         2         Misaligned Incongruent L        L       1
# 2    1         3         Aligned Incongruent    A        A       1
# 3    1         4         Aligned Congruent      L        A       0
# 4    1         2         Aligned Incongruent    L        L       1
# 5    0         2         Misaligned Incongruent L        L       1
# 6    1         1         Aligned Congruent      L        L       1
# 7    1         3         Aligned Incongruent    L        A       0
# 8    0         4         Misaligned Congruent   A        A       1
# 9    0         4         Misaligned Congruent   L        A       0
# 10   1         4         Aligned Congruent      A        A       1
# 11   0         2         Misaligned Incongruent L        L       1
# 12   0         1         Misaligned Congruent   L        L       1
# 13   1         3         Aligned Incongruent    A        A       1
# 14   0         2         Misaligned Incongruent L        L       1
# 15   1         1         Aligned Congruent      L        L       1
# 16   0         1         Misaligned Congruent   L        L       1
# 17   0         1         Misaligned Congruent   L        L       1
# 18   1         3         Aligned Incongruent    L        A       0
# 19   0         2         Misaligned Incongruent L        L       1
# 20   1         3         Aligned Incongruent    A        A       1
# 21   1         4         Aligned Congruent      L        A       0
# 22   1         4         Aligned Congruent      L        A       0
# 23   1         4         Aligned Congruent      L        A       0
# 24   0         3         Misaligned Incongruent A        A       1
# 25   0         4         Misaligned Congruent   A        A       1
# 26   0         1         Misaligned Congruent   L        L       1
# 27   1         2         Aligned Incongruent    L        L       1
# 28   0         1         Misaligned Congruent   L        L       1
# 29   0         3         Misaligned Incongruent A        A       1
# 30   1         1         Aligned Congruent      L        L       1
# ⋮    ⋮         ⋮         ⋮                      ⋮        ⋮       ⋮
# 5731 1         4         Aligned Congruent      A        A       1
# 5732 0         1         Misaligned Congruent   L        L       1
# 5733 1         2         Aligned Incongruent    L        L       1
# 5734 0         2         Misaligned Incongruent L        L       1
# 5735 0         1         Misaligned Congruent   L        L       1
# 5736 0         2         Misaligned Incongruent A        L       0
# 5737 0         1         Misaligned Congruent   L        L       1
# 5738 0         3         Misaligned Incongruent A        A       1
# 5739 0         4         Misaligned Congruent   A        A       1
# 5740 1         1         Aligned Congruent      A        L       0
# 5741 0         2         Misaligned Incongruent L        L       1
# 5742 1         3         Aligned Incongruent    A        A       1
# 5743 0         1         Misaligned Congruent   L        L       1
# 5744 0         4         Misaligned Congruent   A        A       1
# 5745 0         1         Misaligned Congruent   L        L       1
# 5746 0         3         Misaligned Incongruent L        A       0
# 5747 1         1         Aligned Congruent      L        L       1
# 5748 1         2         Aligned Incongruent    L        L       1
# 5749 0         3         Misaligned Incongruent A        A       1
# 5750 0         3         Misaligned Incongruent A        A       1
# 5751 1         1         Aligned Congruent      A        L       0
# 5752 1         2         Aligned Incongruent    A        L       0
# 5753 1         2         Aligned Incongruent    A        L       0
# 5754 1         2         Aligned Incongruent    L        L       1
# 5755 1         3         Aligned Incongruent    A        A       1
# 5756 1         3         Aligned Incongruent    A        A       1
# 5757 1         1         Aligned Congruent      L        L       1
# 5758 1         3         Aligned Incongruent    A        A       1
# 5759 0         3         Misaligned Incongruent A        A       1
# 5760 1         3         Aligned Incongruent    A        A       1
#      R_time              Trial-Start        Key-Resp-Start
# 1    0.5030478000000584  39.83840910000072  41.59145690000078
# 2    0.7539371999993818  42.59145690000078  44.59539410000016
# 3    0.8413750000001528  45.59539410000016  47.68676910000032
# 4    0.59985550000074    48.68676910000032  50.53662460000106
# 5    0.550741399999606   51.53662460000106  53.33736600000067
# 6    0.4725556000004872  54.33736600000067  56.05992160000116
# 7    0.8518003999999564  57.05992160000116  59.16172200000112
# 8    0.7523978999999599  60.16172200000112  62.16411990000108
# 9    0.7935836999997263  63.16411990000108  65.20770360000081
# 10   1.2720226000003094  66.20770360000081  68.72972620000112
# 11   0.7651189000000158  69.72972620000112  71.74484510000114
# 12   0.4940515999998752  72.74484510000114  74.48889670000102
# 13   0.536895600000389   75.48889670000102  77.27579230000141
# 14   0.5620074000000386  78.27579230000141  80.08779970000145
# 15   0.9321741999994628  81.08779970000145  83.26997390000092
# 16   0.7655333000004247  84.26997390000092  86.28550720000135
# 17   0.7423251000001982  87.28550720000135  89.27783230000155
# 18   0.6383864999999787  90.27783230000155  92.16621880000153
# 19   0.9078325000002223  93.16621880000153  95.32405130000176
# 20   0.8697962999996889  96.32405130000176  98.44384760000145
# 21   0.737350200000219   99.44384760000145  101.43119780000167
# 22   0.9311363999997411  102.43119780000167 104.61233420000141
# 23   0.7964173000002119  105.61233420000141 107.65875150000163
# 24   0.5881072000003769  108.65875150000163 110.49685870000201
# 25   1.1233858000006876  111.49685870000201 113.8702445000027
# 26   1.2385414999991553  114.8702445000027  117.35878600000186
# 27   0.43444999999992434 118.35878600000186 120.04323600000178
# 28   0.5933100000003833  121.04323600000178 122.88654600000217
# 29   0.5679219000005105  123.88654600000217 125.70446790000268
# 30   0.8972436999994897  126.70446790000268 128.85171160000218
# ⋮    ⋮                   ⋮                  ⋮
# 5731 0.5909531000008428  642.4696338000041  644.310586900005
# 5732 0.6964693000001716  645.310586900005   647.2570562000052
# 5733 0.5380509999988135  648.2570562000052  650.045107200004
# 5734 0.7952109999998356  651.045107200004   653.0903182000039
# 5735 0.668114000001151   654.0903182000039  656.0084322000051
# 5736 0.703497800000332   657.0084322000051  658.9619300000055
# 5737 0.6909007000005658  659.9619300000055  661.9028307000061
# 5738 0.8143406000010145  662.9028307000061  664.9671713000072
# 5739 0.6907819000000017  665.9671713000072  667.9079532000072
# 5740 0.5684336999995139  668.9079532000072  670.7263869000068
# 5741 0.6800811000004614  671.7263869000068  673.6564680000073
# 5742 0.586053999998694   674.6564680000073  676.492522000006
# 5743 0.7151908999996521  677.492522000006   679.4577129000057
# 5744 0.579933099999107   680.4577129000057  682.2876460000049
# 5745 0.7017421000011381  683.2876460000049  685.2393881000061
# 5746 1.303677199998856   686.2393881000061  688.793065300005
# 5747 1.3465604000004532  689.793065300005   692.3896257000055
# 5748 0.7216982999991159  693.3896257000055  695.3613240000046
# 5749 0.5877279999996972  696.3613240000046  698.1990520000044
# 5750 0.9614700000012817  699.1990520000044  701.4105220000057
# 5751 0.7000178999998752  702.4105220000057  704.3605399000056
# 5752 0.7340085000007093  705.3605399000056  707.3445484000064
# 5753 0.9984609999984968  708.3445484000064  710.5930094000049
# 5754 0.6765433000011398  711.5930094000049  713.5195527000061
# 5755 0.6965223999988666  714.5195527000061  716.466075100005
# 5756 0.6667582999991282  717.466075100005   719.3828334000042
# 5757 0.7602969000010489  720.3828334000042  722.3931303000053
# 5758 0.8002303999994183  723.3931303000053  725.4433607000047
# 5759 0.7346309000015026  726.4433607000047  728.4279916000063
# 5760 0.6392383000013069  729.4279916000063  731.3172299000076

# %%
CF_CZ <- data.frame(subj = as.numeric(CF_CZZ$subject),
                 #sex = CF_CZZ$'sex',
                 Trial = as.numeric(CF_CZZ$Trial),
                 #Cond = as.numeric(CF_CZZ$Condition),
                 #Type = CF_CZZ$'Type',
                 Cong = as.numeric(CF_CZZ$Congruency),
                 Alig = as.numeric(CF_CZZ$Alignment),
                 Key_Resp = CF_CZZ$'Key_Resp',
                 Cor_Ans = CF_CZZ$'Cor_Ans',
                 Acc = as.numeric(CF_CZZ$Accuracy),
                 RT = as.numeric(CF_CZZ$R_time)
)
CF_CZ <- CF_CZ %>% mutate(Cong = ifelse(Cong == "1", "Congruent", ifelse(Cong == "0", "InCongruent", 
                                                                             "NaN")))
CF_CZ <- CF_CZ %>% mutate(Alig = ifelse(Alig == "1", "Alignment", ifelse(Alig == "0", "MissAlignment", 
                                                                             "NaN")))
#CF_CZ<- CF_CZ[which(CF_CZ$sex == "female"),]

CF_CZ
# Out:
#      subj Trial Cong        Alig          Key_Resp Cor_Ans Acc RT
# 1    1     1    InCongruent MissAlignment L        L       1   0.5030478
# 2    1     2    InCongruent Alignment     A        A       1   0.7539372
# 3    1     3    Congruent   Alignment     L        A       0   0.8413750
# 4    1     4    InCongruent Alignment     L        L       1   0.5998555
# 5    1     5    InCongruent MissAlignment L        L       1   0.5507414
# 6    1     6    Congruent   Alignment     L        L       1   0.4725556
# 7    1     7    InCongruent Alignment     L        A       0   0.8518004
# 8    1     8    Congruent   MissAlignment A        A       1   0.7523979
# 9    1     9    Congruent   MissAlignment L        A       0   0.7935837
# 10   1    10    Congruent   Alignment     A        A       1   1.2720226
# 11   1    11    InCongruent MissAlignment L        L       1   0.7651189
# 12   1    12    Congruent   MissAlignment L        L       1   0.4940516
# 13   1    13    InCongruent Alignment     A        A       1   0.5368956
# 14   1    14    InCongruent MissAlignment L        L       1   0.5620074
# 15   1    15    Congruent   Alignment     L        L       1   0.9321742
# 16   1    16    Congruent   MissAlignment L        L       1   0.7655333
# 17   1    17    Congruent   MissAlignment L        L       1   0.7423251
# 18   1    18    InCongruent Alignment     L        A       0   0.6383865
# 19   1    19    InCongruent MissAlignment L        L       1   0.9078325
# 20   1    20    InCongruent Alignment     A        A       1   0.8697963
# 21   1    21    Congruent   Alignment     L        A       0   0.7373502
# 22   1    22    Congruent   Alignment     L        A       0   0.9311364
# 23   1    23    Congruent   Alignment     L        A       0   0.7964173
# 24   1    24    InCongruent MissAlignment A        A       1   0.5881072
# 25   1    25    Congruent   MissAlignment A        A       1   1.1233858
# 26   1    26    Congruent   MissAlignment L        L       1   1.2385415
# 27   1    27    InCongruent Alignment     L        L       1   0.4344500
# 28   1    28    Congruent   MissAlignment L        L       1   0.5933100
# 29   1    29    InCongruent MissAlignment A        A       1   0.5679219
# 30   1    30    Congruent   Alignment     L        L       1   0.8972437
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮        ⋮       ⋮   ⋮
# 5731 36   131   Congruent   Alignment     A        A       1   0.5909531
# 5732 36   132   Congruent   MissAlignment L        L       1   0.6964693
# 5733 36   133   InCongruent Alignment     L        L       1   0.5380510
# 5734 36   134   InCongruent MissAlignment L        L       1   0.7952110
# 5735 36   135   Congruent   MissAlignment L        L       1   0.6681140
# 5736 36   136   InCongruent MissAlignment A        L       0   0.7034978
# 5737 36   137   Congruent   MissAlignment L        L       1   0.6909007
# 5738 36   138   InCongruent MissAlignment A        A       1   0.8143406
# 5739 36   139   Congruent   MissAlignment A        A       1   0.6907819
# 5740 36   140   Congruent   Alignment     A        L       0   0.5684337
# 5741 36   141   InCongruent MissAlignment L        L       1   0.6800811
# 5742 36   142   InCongruent Alignment     A        A       1   0.5860540
# 5743 36   143   Congruent   MissAlignment L        L       1   0.7151909
# 5744 36   144   Congruent   MissAlignment A        A       1   0.5799331
# 5745 36   145   Congruent   MissAlignment L        L       1   0.7017421
# 5746 36   146   InCongruent MissAlignment L        A       0   1.3036772
# 5747 36   147   Congruent   Alignment     L        L       1   1.3465604
# 5748 36   148   InCongruent Alignment     L        L       1   0.7216983
# 5749 36   149   InCongruent MissAlignment A        A       1   0.5877280
# 5750 36   150   InCongruent MissAlignment A        A       1   0.9614700
# 5751 36   151   Congruent   Alignment     A        L       0   0.7000179
# 5752 36   152   InCongruent Alignment     A        L       0   0.7340085
# 5753 36   153   InCongruent Alignment     A        L       0   0.9984610
# 5754 36   154   InCongruent Alignment     L        L       1   0.6765433
# 5755 36   155   InCongruent Alignment     A        A       1   0.6965224
# 5756 36   156   InCongruent Alignment     A        A       1   0.6667583
# 5757 36   157   Congruent   Alignment     L        L       1   0.7602969
# 5758 36   158   InCongruent Alignment     A        A       1   0.8002304
# 5759 36   159   InCongruent MissAlignment A        A       1   0.7346309
# 5760 36   160   InCongruent Alignment     A        A       1   0.6392383

# %%
for(it in 1:length(CF_CZ$subj)){
  if(CF_CZ$subj[it] >= 10 & CF_CZ$subj[it]<= 27){
    if(CF_CZ$Key_Resp[it] == "A" & CF_CZ$Cor_Ans[it] == "A")
      CF_CZ$SDT[it] <- "Hit"
    else if(CF_CZ$Key_Resp[it] == "A" & CF_CZ$Cor_Ans[it] == "L")
      CF_CZ$SDT[it] <- "FalseAlarm"
    else if(CF_CZ$Key_Resp[it] == "L" & CF_CZ$Cor_Ans[it] == "A")
      CF_CZ$SDT[it] <- "Miss"
    else
      CF_CZ$SDT[it] <- "CorrReject"
  }
  else{
    if(CF_CZ$Key_Resp[it] == "L" & CF_CZ$Cor_Ans[it] == "L")
      CF_CZ$SDT[it] <- "Hit"
    else if(CF_CZ$Key_Resp[it] == "L" & CF_CZ$Cor_Ans[it] == "A")
      CF_CZ$SDT[it] <- "FalseAlarm"
    else if(CF_CZ$Key_Resp[it] == "A" & CF_CZ$Cor_Ans[it] == "L")
      CF_CZ$SDT[it] <- "Miss"
    else
      CF_CZ$SDT[it] <- "CorrReject"
  }
}
CF_CZ
# Out:
#      subj Trial Cong        Alig          Key_Resp Cor_Ans Acc RT
# 1    1     1    InCongruent MissAlignment L        L       1   0.5030478
# 2    1     2    InCongruent Alignment     A        A       1   0.7539372
# 3    1     3    Congruent   Alignment     L        A       0   0.8413750
# 4    1     4    InCongruent Alignment     L        L       1   0.5998555
# 5    1     5    InCongruent MissAlignment L        L       1   0.5507414
# 6    1     6    Congruent   Alignment     L        L       1   0.4725556
# 7    1     7    InCongruent Alignment     L        A       0   0.8518004
# 8    1     8    Congruent   MissAlignment A        A       1   0.7523979
# 9    1     9    Congruent   MissAlignment L        A       0   0.7935837
# 10   1    10    Congruent   Alignment     A        A       1   1.2720226
# 11   1    11    InCongruent MissAlignment L        L       1   0.7651189
# 12   1    12    Congruent   MissAlignment L        L       1   0.4940516
# 13   1    13    InCongruent Alignment     A        A       1   0.5368956
# 14   1    14    InCongruent MissAlignment L        L       1   0.5620074
# 15   1    15    Congruent   Alignment     L        L       1   0.9321742
# 16   1    16    Congruent   MissAlignment L        L       1   0.7655333
# 17   1    17    Congruent   MissAlignment L        L       1   0.7423251
# 18   1    18    InCongruent Alignment     L        A       0   0.6383865
# 19   1    19    InCongruent MissAlignment L        L       1   0.9078325
# 20   1    20    InCongruent Alignment     A        A       1   0.8697963
# 21   1    21    Congruent   Alignment     L        A       0   0.7373502
# 22   1    22    Congruent   Alignment     L        A       0   0.9311364
# 23   1    23    Congruent   Alignment     L        A       0   0.7964173
# 24   1    24    InCongruent MissAlignment A        A       1   0.5881072
# 25   1    25    Congruent   MissAlignment A        A       1   1.1233858
# 26   1    26    Congruent   MissAlignment L        L       1   1.2385415
# 27   1    27    InCongruent Alignment     L        L       1   0.4344500
# 28   1    28    Congruent   MissAlignment L        L       1   0.5933100
# 29   1    29    InCongruent MissAlignment A        A       1   0.5679219
# 30   1    30    Congruent   Alignment     L        L       1   0.8972437
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮        ⋮       ⋮   ⋮
# 5731 36   131   Congruent   Alignment     A        A       1   0.5909531
# 5732 36   132   Congruent   MissAlignment L        L       1   0.6964693
# 5733 36   133   InCongruent Alignment     L        L       1   0.5380510
# 5734 36   134   InCongruent MissAlignment L        L       1   0.7952110
# 5735 36   135   Congruent   MissAlignment L        L       1   0.6681140
# 5736 36   136   InCongruent MissAlignment A        L       0   0.7034978
# 5737 36   137   Congruent   MissAlignment L        L       1   0.6909007
# 5738 36   138   InCongruent MissAlignment A        A       1   0.8143406
# 5739 36   139   Congruent   MissAlignment A        A       1   0.6907819
# 5740 36   140   Congruent   Alignment     A        L       0   0.5684337
# 5741 36   141   InCongruent MissAlignment L        L       1   0.6800811
# 5742 36   142   InCongruent Alignment     A        A       1   0.5860540
# 5743 36   143   Congruent   MissAlignment L        L       1   0.7151909
# 5744 36   144   Congruent   MissAlignment A        A       1   0.5799331
# 5745 36   145   Congruent   MissAlignment L        L       1   0.7017421
# 5746 36   146   InCongruent MissAlignment L        A       0   1.3036772
# 5747 36   147   Congruent   Alignment     L        L       1   1.3465604
# 5748 36   148   InCongruent Alignment     L        L       1   0.7216983
# 5749 36   149   InCongruent MissAlignment A        A       1   0.5877280
# 5750 36   150   InCongruent MissAlignment A        A       1   0.9614700
# 5751 36   151   Congruent   Alignment     A        L       0   0.7000179
# 5752 36   152   InCongruent Alignment     A        L       0   0.7340085
# 5753 36   153   InCongruent Alignment     A        L       0   0.9984610
# 5754 36   154   InCongruent Alignment     L        L       1   0.6765433
# 5755 36   155   InCongruent Alignment     A        A       1   0.6965224
# 5756 36   156   InCongruent Alignment     A        A       1   0.6667583
# 5757 36   157   Congruent   Alignment     L        L       1   0.7602969
# 5758 36   158   InCongruent Alignment     A        A       1   0.8002304
# 5759 36   159   InCongruent MissAlignment A        A       1   0.7346309
# 5760 36   160   InCongruent Alignment     A        A       1   0.6392383
#      SDT
# 1    Hit
# 2    CorrReject
# 3    FalseAlarm
# 4    Hit
# 5    Hit
# 6    Hit
# 7    FalseAlarm
# 8    CorrReject
# 9    FalseAlarm
# 10   CorrReject
# 11   Hit
# 12   Hit
# 13   CorrReject
# 14   Hit
# 15   Hit
# 16   Hit
# 17   Hit
# 18   FalseAlarm
# 19   Hit
# 20   CorrReject
# 21   FalseAlarm
# 22   FalseAlarm
# 23   FalseAlarm
# 24   CorrReject
# 25   CorrReject
# 26   Hit
# 27   Hit
# 28   Hit
# 29   CorrReject
# 30   Hit
# ⋮    ⋮
# 5731 CorrReject
# 5732 Hit
# 5733 Hit
# 5734 Hit
# 5735 Hit
# 5736 Miss
# 5737 Hit
# 5738 CorrReject
# 5739 CorrReject
# 5740 Miss
# 5741 Hit
# 5742 CorrReject
# 5743 Hit
# 5744 CorrReject
# 5745 Hit
# 5746 FalseAlarm
# 5747 Hit
# 5748 Hit
# 5749 CorrReject
# 5750 CorrReject
# 5751 Miss
# 5752 Miss
# 5753 Miss
# 5754 Hit
# 5755 CorrReject
# 5756 CorrReject
# 5757 Hit
# 5758 CorrReject
# 5759 CorrReject
# 5760 CorrReject

# %%
CF_CZ <- subset (CF_CZ, select = - Key_Resp)
CF_CZ <- subset (CF_CZ, select = - Cor_Ans)
#CF_CZ <- subset (CF_CZ, select = - sex)
CF_CZ
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    InCongruent MissAlignment 1   0.5030478 Hit
# 2    1     2    InCongruent Alignment     1   0.7539372 CorrReject
# 3    1     3    Congruent   Alignment     0   0.8413750 FalseAlarm
# 4    1     4    InCongruent Alignment     1   0.5998555 Hit
# 5    1     5    InCongruent MissAlignment 1   0.5507414 Hit
# 6    1     6    Congruent   Alignment     1   0.4725556 Hit
# 7    1     7    InCongruent Alignment     0   0.8518004 FalseAlarm
# 8    1     8    Congruent   MissAlignment 1   0.7523979 CorrReject
# 9    1     9    Congruent   MissAlignment 0   0.7935837 FalseAlarm
# 10   1    10    Congruent   Alignment     1   1.2720226 CorrReject
# 11   1    11    InCongruent MissAlignment 1   0.7651189 Hit
# 12   1    12    Congruent   MissAlignment 1   0.4940516 Hit
# 13   1    13    InCongruent Alignment     1   0.5368956 CorrReject
# 14   1    14    InCongruent MissAlignment 1   0.5620074 Hit
# 15   1    15    Congruent   Alignment     1   0.9321742 Hit
# 16   1    16    Congruent   MissAlignment 1   0.7655333 Hit
# 17   1    17    Congruent   MissAlignment 1   0.7423251 Hit
# 18   1    18    InCongruent Alignment     0   0.6383865 FalseAlarm
# 19   1    19    InCongruent MissAlignment 1   0.9078325 Hit
# 20   1    20    InCongruent Alignment     1   0.8697963 CorrReject
# 21   1    21    Congruent   Alignment     0   0.7373502 FalseAlarm
# 22   1    22    Congruent   Alignment     0   0.9311364 FalseAlarm
# 23   1    23    Congruent   Alignment     0   0.7964173 FalseAlarm
# 24   1    24    InCongruent MissAlignment 1   0.5881072 CorrReject
# 25   1    25    Congruent   MissAlignment 1   1.1233858 CorrReject
# 26   1    26    Congruent   MissAlignment 1   1.2385415 Hit
# 27   1    27    InCongruent Alignment     1   0.4344500 Hit
# 28   1    28    Congruent   MissAlignment 1   0.5933100 Hit
# 29   1    29    InCongruent MissAlignment 1   0.5679219 CorrReject
# 30   1    30    Congruent   Alignment     1   0.8972437 Hit
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5731 36   131   Congruent   Alignment     1   0.5909531 CorrReject
# 5732 36   132   Congruent   MissAlignment 1   0.6964693 Hit
# 5733 36   133   InCongruent Alignment     1   0.5380510 Hit
# 5734 36   134   InCongruent MissAlignment 1   0.7952110 Hit
# 5735 36   135   Congruent   MissAlignment 1   0.6681140 Hit
# 5736 36   136   InCongruent MissAlignment 0   0.7034978 Miss
# 5737 36   137   Congruent   MissAlignment 1   0.6909007 Hit
# 5738 36   138   InCongruent MissAlignment 1   0.8143406 CorrReject
# 5739 36   139   Congruent   MissAlignment 1   0.6907819 CorrReject
# 5740 36   140   Congruent   Alignment     0   0.5684337 Miss
# 5741 36   141   InCongruent MissAlignment 1   0.6800811 Hit
# 5742 36   142   InCongruent Alignment     1   0.5860540 CorrReject
# 5743 36   143   Congruent   MissAlignment 1   0.7151909 Hit
# 5744 36   144   Congruent   MissAlignment 1   0.5799331 CorrReject
# 5745 36   145   Congruent   MissAlignment 1   0.7017421 Hit
# 5746 36   146   InCongruent MissAlignment 0   1.3036772 FalseAlarm
# 5747 36   147   Congruent   Alignment     1   1.3465604 Hit
# 5748 36   148   InCongruent Alignment     1   0.7216983 Hit
# 5749 36   149   InCongruent MissAlignment 1   0.5877280 CorrReject
# 5750 36   150   InCongruent MissAlignment 1   0.9614700 CorrReject
# 5751 36   151   Congruent   Alignment     0   0.7000179 Miss
# 5752 36   152   InCongruent Alignment     0   0.7340085 Miss
# 5753 36   153   InCongruent Alignment     0   0.9984610 Miss
# 5754 36   154   InCongruent Alignment     1   0.6765433 Hit
# 5755 36   155   InCongruent Alignment     1   0.6965224 CorrReject
# 5756 36   156   InCongruent Alignment     1   0.6667583 CorrReject
# 5757 36   157   Congruent   Alignment     1   0.7602969 Hit
# 5758 36   158   InCongruent Alignment     1   0.8002304 CorrReject
# 5759 36   159   InCongruent MissAlignment 1   0.7346309 CorrReject
# 5760 36   160   InCongruent Alignment     1   0.6392383 CorrReject

# %% [markdown]
# Since an accuracy above 57.5% across 160 trials is unlikely due to random behavior alone,
# according to a binomial test (p < 0.05), only participants who surpassed this threshold were
# included in the analyses.
# - binom.test(91,160,p=0.5)  ,  p_value = 0.09657
# - binom.test(92,160,p=0.5)  ,  p_value = 0.06868
# - binom.test(93,160,p=0.5)  ,  p_value = 0.04777
# - binom.test(94,160,p=0.5)  ,  p_value = 0.03247
#
# Therefore we have 92/160 = 0.575

# %%
meanAcc <- data.frame(subj = NaN, MACC = NaN)
meanAcc2 <- data.frame(subj = NaN, MACC = NaN)
for(i in 1:36){
  meanAcc$subj <- i 
  meanAcc$MACC <- mean(CF_CZ$Acc[CF_CZ$subj == i])
  meanAcc2 <- rbind(meanAcc2, meanAcc)
}
meanAcc2
# Out:
#    subj MACC
# 1  NaN      NaN
# 2    1  0.89375
# 3    2  0.83750
# 4    3  0.72500
# 5    4  0.82500
# 6    5  0.88125
# 7    6  0.90625
# 8    7  0.88750
# 9    8  0.83750
# 10   9  0.64375
# 11  10  0.54375
# 12  11  0.81250
# 13  12  0.93125
# 14  13  0.94375
# 15  14  0.80625
# 16  15  0.73750
# 17  16  0.85000
# 18  17  0.93750
# 19  18  0.65625
# 20  19  0.91250
# 21  20  0.95625
# 22  21  0.95625
# 23  22  0.96250
# 24  23  0.81875
# 25  24  0.94375
# 26  25  0.91875
# 27  26  0.93125
# 28  27  0.93750
# 29  28  0.96250
# 30  29  0.95625
# 31  30  0.95000
# 32  31  0.91250
# 33  32  0.82500
# 34  33  0.88750
# 35  34  0.88125
# 36  35  0.92500
# 37  36  0.90000

# %% [markdown]
# Therefore data from 1 participant (participant number = 10) was discarded because of chance performance = 0.54375.

# %%
CF_CZ<- CF_CZ[which(CF_CZ$subj != 10),]
CF_CZ
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    InCongruent MissAlignment 1   0.5030478 Hit
# 2    1     2    InCongruent Alignment     1   0.7539372 CorrReject
# 3    1     3    Congruent   Alignment     0   0.8413750 FalseAlarm
# 4    1     4    InCongruent Alignment     1   0.5998555 Hit
# 5    1     5    InCongruent MissAlignment 1   0.5507414 Hit
# 6    1     6    Congruent   Alignment     1   0.4725556 Hit
# 7    1     7    InCongruent Alignment     0   0.8518004 FalseAlarm
# 8    1     8    Congruent   MissAlignment 1   0.7523979 CorrReject
# 9    1     9    Congruent   MissAlignment 0   0.7935837 FalseAlarm
# 10   1    10    Congruent   Alignment     1   1.2720226 CorrReject
# 11   1    11    InCongruent MissAlignment 1   0.7651189 Hit
# 12   1    12    Congruent   MissAlignment 1   0.4940516 Hit
# 13   1    13    InCongruent Alignment     1   0.5368956 CorrReject
# 14   1    14    InCongruent MissAlignment 1   0.5620074 Hit
# 15   1    15    Congruent   Alignment     1   0.9321742 Hit
# 16   1    16    Congruent   MissAlignment 1   0.7655333 Hit
# 17   1    17    Congruent   MissAlignment 1   0.7423251 Hit
# 18   1    18    InCongruent Alignment     0   0.6383865 FalseAlarm
# 19   1    19    InCongruent MissAlignment 1   0.9078325 Hit
# 20   1    20    InCongruent Alignment     1   0.8697963 CorrReject
# 21   1    21    Congruent   Alignment     0   0.7373502 FalseAlarm
# 22   1    22    Congruent   Alignment     0   0.9311364 FalseAlarm
# 23   1    23    Congruent   Alignment     0   0.7964173 FalseAlarm
# 24   1    24    InCongruent MissAlignment 1   0.5881072 CorrReject
# 25   1    25    Congruent   MissAlignment 1   1.1233858 CorrReject
# 26   1    26    Congruent   MissAlignment 1   1.2385415 Hit
# 27   1    27    InCongruent Alignment     1   0.4344500 Hit
# 28   1    28    Congruent   MissAlignment 1   0.5933100 Hit
# 29   1    29    InCongruent MissAlignment 1   0.5679219 CorrReject
# 30   1    30    Congruent   Alignment     1   0.8972437 Hit
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5731 36   131   Congruent   Alignment     1   0.5909531 CorrReject
# 5732 36   132   Congruent   MissAlignment 1   0.6964693 Hit
# 5733 36   133   InCongruent Alignment     1   0.5380510 Hit
# 5734 36   134   InCongruent MissAlignment 1   0.7952110 Hit
# 5735 36   135   Congruent   MissAlignment 1   0.6681140 Hit
# 5736 36   136   InCongruent MissAlignment 0   0.7034978 Miss
# 5737 36   137   Congruent   MissAlignment 1   0.6909007 Hit
# 5738 36   138   InCongruent MissAlignment 1   0.8143406 CorrReject
# 5739 36   139   Congruent   MissAlignment 1   0.6907819 CorrReject
# 5740 36   140   Congruent   Alignment     0   0.5684337 Miss
# 5741 36   141   InCongruent MissAlignment 1   0.6800811 Hit
# 5742 36   142   InCongruent Alignment     1   0.5860540 CorrReject
# 5743 36   143   Congruent   MissAlignment 1   0.7151909 Hit
# 5744 36   144   Congruent   MissAlignment 1   0.5799331 CorrReject
# 5745 36   145   Congruent   MissAlignment 1   0.7017421 Hit
# 5746 36   146   InCongruent MissAlignment 0   1.3036772 FalseAlarm
# 5747 36   147   Congruent   Alignment     1   1.3465604 Hit
# 5748 36   148   InCongruent Alignment     1   0.7216983 Hit
# 5749 36   149   InCongruent MissAlignment 1   0.5877280 CorrReject
# 5750 36   150   InCongruent MissAlignment 1   0.9614700 CorrReject
# 5751 36   151   Congruent   Alignment     0   0.7000179 Miss
# 5752 36   152   InCongruent Alignment     0   0.7340085 Miss
# 5753 36   153   InCongruent Alignment     0   0.9984610 Miss
# 5754 36   154   InCongruent Alignment     1   0.6765433 Hit
# 5755 36   155   InCongruent Alignment     1   0.6965224 CorrReject
# 5756 36   156   InCongruent Alignment     1   0.6667583 CorrReject
# 5757 36   157   Congruent   Alignment     1   0.7602969 Hit
# 5758 36   158   InCongruent Alignment     1   0.8002304 CorrReject
# 5759 36   159   InCongruent MissAlignment 1   0.7346309 CorrReject
# 5760 36   160   InCongruent Alignment     1   0.6392383 CorrReject

# %%
CF_CZ[which(CF_CZ$RT>4),]
CF_CZ[which(CF_CZ$RT<0.2),]
mean(CF_CZ$RT[CF_CZ$subj == 1])
3*sd(CF_CZ$RT[CF_CZ$subj == 1])

CF_CZ[which(CF_CZ$subj ==1 & CF_CZ$RT> mean(CF_CZ$RT[CF_CZ$subj == 1])+3*sd(CF_CZ$RT[CF_CZ$subj == 1])),]
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 468   3   148   Congruent   Alignment     1   20.076446 CorrReject
# 553   4    73   Congruent   Alignment     0    4.728386 FalseAlarm
# 567   4    87   Congruent   MissAlignment 1    5.765587 Hit
# 580   4   100   InCongruent MissAlignment 0    5.489795 FalseAlarm
# 586   4   106   InCongruent Alignment     0    9.613673 FalseAlarm
# 590   4   110   InCongruent MissAlignment 1    6.441748 Hit
# 597   4   117   InCongruent Alignment     1    6.004217 Hit
# 611   4   131   Congruent   Alignment     0    4.110208 FalseAlarm
# 613   4   133   Congruent   MissAlignment 0    7.664220 FalseAlarm
# 619   4   139   Congruent   Alignment     1    5.749944 Hit
# 626   4   146   InCongruent Alignment     0    6.178616 FalseAlarm
# 628   4   148   InCongruent Alignment     0    4.575717 FalseAlarm
# 631   4   151   InCongruent MissAlignment 0    7.993577 FalseAlarm
# 1194  8    74   InCongruent MissAlignment 1    5.175448 Hit
# 2447 16    47   InCongruent MissAlignment 1    4.287241 CorrReject
# 2517 16   117   InCongruent MissAlignment 1    4.426853 Hit
# 2555 16   155   InCongruent MissAlignment 0    4.008132 Miss
# 4145 26   145   Congruent   MissAlignment 0    5.879045 FalseAlarm
# 5281 34     1   InCongruent Alignment     0    4.335079 Miss
# 5321 34    41   Congruent   MissAlignment 1    7.496154 Hit
#      subj Trial Cong Alig Acc RT SDT
# [1] 0.7242969
# [1] 0.6343641
#    subj Trial Cong        Alig          Acc RT       SDT
# 77 1    77    InCongruent MissAlignment 1   1.413050 CorrReject
# 97 1    97    InCongruent Alignment     1   1.444998 Hit

# %%
#j<-0
#for(i in 1: 5760){
#  if(CF_CZ$RT[i]>1)
#    j<-j+1
#}

#CF<- CF_CZZ[which(CF_CZZ$Acc == 1 & CF_CZZ$RT <= 1),]

#OUT <- CF_CZ %>% group_by(subj) %>% identify_outliers(RT)
#OUTT <- OUT[which(OUT$is.extreme == TRUE),]

#CF_CZ_no_outlier<- CF_CZ %>% 
#  anti_join(OUTT, by = "RT") 



OUT <- CF_CZ[which(CF_CZ$Acc ==1 & CF_CZ$RT>4),]

CF_CZ_n<- CF_CZ %>% 
  anti_join(OUT, by = "RT") 

#CF_CZ_no_outlier<- CF_CZ  



#CF_CZ_no_outlier[which(CF_CZ_no_outlier$RT>4),]

#CF_CZ_no_outlier <- CF_CZ
CF_CZ_n

OUT
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    InCongruent MissAlignment 1   0.5030478 Hit
# 2    1     2    InCongruent Alignment     1   0.7539372 CorrReject
# 3    1     3    Congruent   Alignment     0   0.8413750 FalseAlarm
# 4    1     4    InCongruent Alignment     1   0.5998555 Hit
# 5    1     5    InCongruent MissAlignment 1   0.5507414 Hit
# 6    1     6    Congruent   Alignment     1   0.4725556 Hit
# 7    1     7    InCongruent Alignment     0   0.8518004 FalseAlarm
# 8    1     8    Congruent   MissAlignment 1   0.7523979 CorrReject
# 9    1     9    Congruent   MissAlignment 0   0.7935837 FalseAlarm
# 10   1    10    Congruent   Alignment     1   1.2720226 CorrReject
# 11   1    11    InCongruent MissAlignment 1   0.7651189 Hit
# 12   1    12    Congruent   MissAlignment 1   0.4940516 Hit
# 13   1    13    InCongruent Alignment     1   0.5368956 CorrReject
# 14   1    14    InCongruent MissAlignment 1   0.5620074 Hit
# 15   1    15    Congruent   Alignment     1   0.9321742 Hit
# 16   1    16    Congruent   MissAlignment 1   0.7655333 Hit
# 17   1    17    Congruent   MissAlignment 1   0.7423251 Hit
# 18   1    18    InCongruent Alignment     0   0.6383865 FalseAlarm
# 19   1    19    InCongruent MissAlignment 1   0.9078325 Hit
# 20   1    20    InCongruent Alignment     1   0.8697963 CorrReject
# 21   1    21    Congruent   Alignment     0   0.7373502 FalseAlarm
# 22   1    22    Congruent   Alignment     0   0.9311364 FalseAlarm
# 23   1    23    Congruent   Alignment     0   0.7964173 FalseAlarm
# 24   1    24    InCongruent MissAlignment 1   0.5881072 CorrReject
# 25   1    25    Congruent   MissAlignment 1   1.1233858 CorrReject
# 26   1    26    Congruent   MissAlignment 1   1.2385415 Hit
# 27   1    27    InCongruent Alignment     1   0.4344500 Hit
# 28   1    28    Congruent   MissAlignment 1   0.5933100 Hit
# 29   1    29    InCongruent MissAlignment 1   0.5679219 CorrReject
# 30   1    30    Congruent   Alignment     1   0.8972437 Hit
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5562 36   131   Congruent   Alignment     1   0.5909531 CorrReject
# 5563 36   132   Congruent   MissAlignment 1   0.6964693 Hit
# 5564 36   133   InCongruent Alignment     1   0.5380510 Hit
# 5565 36   134   InCongruent MissAlignment 1   0.7952110 Hit
# 5566 36   135   Congruent   MissAlignment 1   0.6681140 Hit
# 5567 36   136   InCongruent MissAlignment 0   0.7034978 Miss
# 5568 36   137   Congruent   MissAlignment 1   0.6909007 Hit
# 5569 36   138   InCongruent MissAlignment 1   0.8143406 CorrReject
# 5570 36   139   Congruent   MissAlignment 1   0.6907819 CorrReject
# 5571 36   140   Congruent   Alignment     0   0.5684337 Miss
# 5572 36   141   InCongruent MissAlignment 1   0.6800811 Hit
# 5573 36   142   InCongruent Alignment     1   0.5860540 CorrReject
# 5574 36   143   Congruent   MissAlignment 1   0.7151909 Hit
# 5575 36   144   Congruent   MissAlignment 1   0.5799331 CorrReject
# 5576 36   145   Congruent   MissAlignment 1   0.7017421 Hit
# 5577 36   146   InCongruent MissAlignment 0   1.3036772 FalseAlarm
# 5578 36   147   Congruent   Alignment     1   1.3465604 Hit
# 5579 36   148   InCongruent Alignment     1   0.7216983 Hit
# 5580 36   149   InCongruent MissAlignment 1   0.5877280 CorrReject
# 5581 36   150   InCongruent MissAlignment 1   0.9614700 CorrReject
# 5582 36   151   Congruent   Alignment     0   0.7000179 Miss
# 5583 36   152   InCongruent Alignment     0   0.7340085 Miss
# 5584 36   153   InCongruent Alignment     0   0.9984610 Miss
# 5585 36   154   InCongruent Alignment     1   0.6765433 Hit
# 5586 36   155   InCongruent Alignment     1   0.6965224 CorrReject
# 5587 36   156   InCongruent Alignment     1   0.6667583 CorrReject
# 5588 36   157   Congruent   Alignment     1   0.7602969 Hit
# 5589 36   158   InCongruent Alignment     1   0.8002304 CorrReject
# 5590 36   159   InCongruent MissAlignment 1   0.7346309 CorrReject
# 5591 36   160   InCongruent Alignment     1   0.6392383 CorrReject
#      subj Trial Cong        Alig          Acc RT        SDT
# 468   3   148   Congruent   Alignment     1   20.076446 CorrReject
# 567   4    87   Congruent   MissAlignment 1    5.765587 Hit
# 590   4   110   InCongruent MissAlignment 1    6.441748 Hit
# 597   4   117   InCongruent Alignment     1    6.004217 Hit
# 619   4   139   Congruent   Alignment     1    5.749944 Hit
# 1194  8    74   InCongruent MissAlignment 1    5.175448 Hit
# 2447 16    47   InCongruent MissAlignment 1    4.287241 CorrReject
# 2517 16   117   InCongruent MissAlignment 1    4.426853 Hit
# 5321 34    41   Congruent   MissAlignment 1    7.496154 Hit

# %%
for(i in 1:36)
    if(i != 10)
    {
        OUT <- CF_CZ_n[which(CF_CZ_n$subj == i & (CF_CZ_n$RT > mean(CF_CZ_n$RT[CF_CZ_n$subj == i]) + 
                         3 * sd(CF_CZ_n$RT[CF_CZ_n$subj == i]) | 
                                                  CF_CZ_n$RT < mean(CF_CZ_n$RT[CF_CZ_n$subj == i]) - 
                         3 * sd(CF_CZ_n$RT[CF_CZ_n$subj == i]))),]
        CF_CZ_no_outlier<- CF_CZ_n %>% anti_join(OUT, by = "RT") 
        CF_CZ_n <- CF_CZ_no_outlier
    }
OUT
CF_CZ_no_outlier
# Out:
#      subj Trial Cong        Alig          Acc RT       SDT
# 5345 36    14   InCongruent MissAlignment 0   1.174387 FalseAlarm
# 5477 36   146   InCongruent MissAlignment 0   1.303677 FalseAlarm
# 5478 36   147   Congruent   Alignment     1   1.346560 Hit
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    InCongruent MissAlignment 1   0.5030478 Hit
# 2    1     2    InCongruent Alignment     1   0.7539372 CorrReject
# 3    1     3    Congruent   Alignment     0   0.8413750 FalseAlarm
# 4    1     4    InCongruent Alignment     1   0.5998555 Hit
# 5    1     5    InCongruent MissAlignment 1   0.5507414 Hit
# 6    1     6    Congruent   Alignment     1   0.4725556 Hit
# 7    1     7    InCongruent Alignment     0   0.8518004 FalseAlarm
# 8    1     8    Congruent   MissAlignment 1   0.7523979 CorrReject
# 9    1     9    Congruent   MissAlignment 0   0.7935837 FalseAlarm
# 10   1    10    Congruent   Alignment     1   1.2720226 CorrReject
# 11   1    11    InCongruent MissAlignment 1   0.7651189 Hit
# 12   1    12    Congruent   MissAlignment 1   0.4940516 Hit
# 13   1    13    InCongruent Alignment     1   0.5368956 CorrReject
# 14   1    14    InCongruent MissAlignment 1   0.5620074 Hit
# 15   1    15    Congruent   Alignment     1   0.9321742 Hit
# 16   1    16    Congruent   MissAlignment 1   0.7655333 Hit
# 17   1    17    Congruent   MissAlignment 1   0.7423251 Hit
# 18   1    18    InCongruent Alignment     0   0.6383865 FalseAlarm
# 19   1    19    InCongruent MissAlignment 1   0.9078325 Hit
# 20   1    20    InCongruent Alignment     1   0.8697963 CorrReject
# 21   1    21    Congruent   Alignment     0   0.7373502 FalseAlarm
# 22   1    22    Congruent   Alignment     0   0.9311364 FalseAlarm
# 23   1    23    Congruent   Alignment     0   0.7964173 FalseAlarm
# 24   1    24    InCongruent MissAlignment 1   0.5881072 CorrReject
# 25   1    25    Congruent   MissAlignment 1   1.1233858 CorrReject
# 26   1    26    Congruent   MissAlignment 1   1.2385415 Hit
# 27   1    27    InCongruent Alignment     1   0.4344500 Hit
# 28   1    28    Congruent   MissAlignment 1   0.5933100 Hit
# 29   1    29    InCongruent MissAlignment 1   0.5679219 CorrReject
# 30   1    30    Congruent   Alignment     1   0.8972437 Hit
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5459 36   129   Congruent   MissAlignment 1   0.6263605 CorrReject
# 5460 36   130   Congruent   Alignment     1   0.6179345 Hit
# 5461 36   131   Congruent   Alignment     1   0.5909531 CorrReject
# 5462 36   132   Congruent   MissAlignment 1   0.6964693 Hit
# 5463 36   133   InCongruent Alignment     1   0.5380510 Hit
# 5464 36   134   InCongruent MissAlignment 1   0.7952110 Hit
# 5465 36   135   Congruent   MissAlignment 1   0.6681140 Hit
# 5466 36   136   InCongruent MissAlignment 0   0.7034978 Miss
# 5467 36   137   Congruent   MissAlignment 1   0.6909007 Hit
# 5468 36   138   InCongruent MissAlignment 1   0.8143406 CorrReject
# 5469 36   139   Congruent   MissAlignment 1   0.6907819 CorrReject
# 5470 36   140   Congruent   Alignment     0   0.5684337 Miss
# 5471 36   141   InCongruent MissAlignment 1   0.6800811 Hit
# 5472 36   142   InCongruent Alignment     1   0.5860540 CorrReject
# 5473 36   143   Congruent   MissAlignment 1   0.7151909 Hit
# 5474 36   144   Congruent   MissAlignment 1   0.5799331 CorrReject
# 5475 36   145   Congruent   MissAlignment 1   0.7017421 Hit
# 5476 36   148   InCongruent Alignment     1   0.7216983 Hit
# 5477 36   149   InCongruent MissAlignment 1   0.5877280 CorrReject
# 5478 36   150   InCongruent MissAlignment 1   0.9614700 CorrReject
# 5479 36   151   Congruent   Alignment     0   0.7000179 Miss
# 5480 36   152   InCongruent Alignment     0   0.7340085 Miss
# 5481 36   153   InCongruent Alignment     0   0.9984610 Miss
# 5482 36   154   InCongruent Alignment     1   0.6765433 Hit
# 5483 36   155   InCongruent Alignment     1   0.6965224 CorrReject
# 5484 36   156   InCongruent Alignment     1   0.6667583 CorrReject
# 5485 36   157   Congruent   Alignment     1   0.7602969 Hit
# 5486 36   158   InCongruent Alignment     1   0.8002304 CorrReject
# 5487 36   159   InCongruent MissAlignment 1   0.7346309 CorrReject
# 5488 36   160   InCongruent Alignment     1   0.6392383 CorrReject

# %%
boxplot(CF_CZ_no_outlier$RT[CF_CZ_no_outlier$Alig == "MissAlignment" & CF_CZ_no_outlier$Acc == 1], 
        CF_CZ_no_outlier$RT[CF_CZ_no_outlier$Alig == "Alignment" & CF_CZ_no_outlier$Acc == 1])

ggdensity(CF_CZ$RT[CF_CZ$Alig == "MissAlignment" & CF_CZ$Acc == 1], rug = TRUE, fill = "lightgray")
ggdensity(CF_CZ_no_outlier$RT[CF_CZ_no_outlier$Alig == "MissAlignment" & CF_CZ_no_outlier$Acc == 1], rug = TRUE, fill = "lightgray")
# Out:
# plot without title
# plot without title
# plot without title

# %%
CF_CZ_sum <- data.frame(subj = 1,
                       # Cond = NaN,
                        
                        Cong = NaN,
                        Alig = NaN,
                        Acc = NaN,
                        MRT = NaN,
                        SDT = NaN,
                        NumbersOf = NaN,
                        HitRate = NaN,
                        FalseAlarmRate = NaN,
                        dPrime = NaN,
                        bias = NaN)

CF_CZ_sum2 <- data.frame(subj = NaN,
                      #  Cond = NaN,
                        
                        Cong = NaN,
                        Alig = NaN,
                        Acc = NaN,
                        MRT = NaN,
                        SDT = NaN,
                        NumbersOf = NaN,
                        HitRate = NaN,
                        FalseAlarmRate = NaN,
                        dPrime = NaN,
                        bias = NaN)

# %%
max(1,3)
# Out:
# [1] 3

# %%
iter <- 2
for(s in 1:36)
  if(s != 10)
  for(c in c("Congruent", "InCongruent"))
    for(a in c("Alignment", "MissAlignment")){
      for(condition in 1:4){
        CF_CZ_sum$subj <- s
        CF_CZ_sum$Cong <- c
          CF_CZ_sum$Alig <- a
        if(condition == 1){
          CF_CZ_sum$SDT <- "Hit"
          #CF_CZ_sum$Cond <- "Same"
          CF_CZ_sum$NumbersOf <- length(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
                                                               CF_CZ_no_outlier$Cong == c & 
                                                               CF_CZ_no_outlier$Alig == a & 
                                                               (CF_CZ_no_outlier$SDT == "Hit")])
          CF_CZ_sum$Acc <- mean(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
                                                        CF_CZ_no_outlier$Cong == c & 
                                                        CF_CZ_no_outlier$Alig == a & 
                                                        (CF_CZ_no_outlier$SDT == "Hit" | CF_CZ_no_outlier$SDT == "Miss")])
          CF_CZ_sum$MRT <- mean(CF_CZ_no_outlier$RT[CF_CZ_no_outlier$subj == s & 
                                                        CF_CZ_no_outlier$Cong == c & 
                                                        CF_CZ_no_outlier$Alig == a & 
                                                        (CF_CZ_no_outlier$SDT == "Hit")])
          iter <- iter + 1
        }
        else if(condition == 2){
          CF_CZ_sum$SDT <- "Miss"
       #   CF_CZ_sum$Cond <- "Same"
          CF_CZ_sum$NumbersOf <- length(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
                                                               CF_CZ_no_outlier$Cong == c & 
                                                               CF_CZ_no_outlier$Alig == a & 
                                                               (CF_CZ_no_outlier$SDT == "Miss")])
            CF_CZ_sum$Acc <- NaN
          #CF_CZ_sum$Acc <- mean(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
           #                                             CF_CZ_no_outlier$Cong == c & 
           #                                             CF_CZ_no_outlier$Alig == a & 
            #                                            (CF_CZ_no_outlier$SDT == "Miss")])
          CF_CZ_sum$MRT <- mean(CF_CZ_no_outlier$RT[CF_CZ_no_outlier$subj == s & 
                                                      CF_CZ_no_outlier$Cong == c & 
                                                      CF_CZ_no_outlier$Alig == a & 
                                                      (CF_CZ_no_outlier$SDT == "Miss")])
          CF_CZ_sum2$HitRate[iter - 1] <- CF_CZ_sum2$NumbersOf[iter -1]/(CF_CZ_sum2$NumbersOf[iter -1] + CF_CZ_sum$NumbersOf)
          Hitrate <- CF_CZ_sum2$HitRate[iter - 1]
          iter <- iter + 1
        }
        else if(condition == 3){
          CF_CZ_sum$SDT <- "FalseAlarm"
      #    CF_CZ_sum$Cond <- "Different"
          CF_CZ_sum$NumbersOf <- length(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
                                                               CF_CZ_no_outlier$Cong == c & 
                                                               CF_CZ_no_outlier$Alig == a & 
                                                               (CF_CZ_no_outlier$SDT == "FalseAlarm")])
            CF_CZ_sum$Acc <- NaN
            
        #  CF_CZ_sum$Acc <- mean(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
         #                                              CF_CZ_no_outlier$Cong == c & 
          #                                             CF_CZ_no_outlier$Alig == a & 
           #                                            (CF_CZ_no_outlier$SDT == "FalseAlarm")])
          CF_CZ_sum$MRT <- mean(CF_CZ_no_outlier$RT[CF_CZ_no_outlier$subj == s & 
                                                      CF_CZ_no_outlier$Cong == c & 
                                                      CF_CZ_no_outlier$Alig == a & 
                                                      (CF_CZ_no_outlier$SDT == "FalseAlarm")])
          iter <- iter + 1
        }
        else if(condition == 4){
          CF_CZ_sum$SDT <- "CorrReject"
     #     CF_CZ_sum$Cond <- "Different"
          CF_CZ_sum$NumbersOf <- length(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
                                                               CF_CZ_no_outlier$Cong == c & 
                                                               CF_CZ_no_outlier$Alig == a & 
                                                               (CF_CZ_no_outlier$SDT == "CorrReject")])
          CF_CZ_sum$Acc <- mean(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
                                                       CF_CZ_no_outlier$Cong == c & 
                                                       CF_CZ_no_outlier$Alig == a & 
                                                       (CF_CZ_no_outlier$SDT == "CorrReject" | CF_CZ_no_outlier$SDT == "FalseAlarm")])
          CF_CZ_sum$MRT <- mean(CF_CZ_no_outlier$RT[CF_CZ_no_outlier$subj == s & 
                                                      CF_CZ_no_outlier$Cong == c & 
                                                      CF_CZ_no_outlier$Alig == a & 
                                                      (CF_CZ_no_outlier$SDT == "CorrReject")])
          CF_CZ_sum2$FalseAlarmRate[iter - 3] <- CF_CZ_sum2$NumbersOf[iter -1]/(CF_CZ_sum2$NumbersOf[iter -1] + CF_CZ_sum$NumbersOf)
          Falsealarmrate <- CF_CZ_sum2$FalseAlarmRate[iter - 3]
          iter <- iter + 1
        }
        CF_CZ_sum2 <- rbind(CF_CZ_sum2,CF_CZ_sum)
      }
      le<- length(CF_CZ_no_outlier$Acc[CF_CZ_no_outlier$subj == s & 
                                                        CF_CZ_no_outlier$Cong == c & 
                                                        CF_CZ_no_outlier$Alig == a ])
      if(Hitrate == 1)
          qnorm_hit <- qnorm((le-0.5)/le)
      else if(Hitrate == 0)
          qnorm_hit <- qnorm((0.5)/le)
      else 
          qnorm_hit <- qnorm(Hitrate)
      if(Falsealarmrate == 1)
          qnorm_fa <- qnorm((le-0.5)/le)
      else if(Falsealarmrate == 0)
          qnorm_fa <- qnorm((0.5)/le)
      else 
          qnorm_fa <- qnorm(Falsealarmrate)
      #CF_CZ_sum2$dPrime[iter - 4] <- pnorm((qnorm_hit - qnorm_fa)/sqrt(2))
      CF_CZ_sum2$bias[iter - 4] <- -0.5 * (qnorm_hit + qnorm_fa)
      CF_CZ_sum2$dPrime[iter - 4] <- 0.5 + sign(Hitrate - Falsealarmrate) * 
          (((Hitrate - Falsealarmrate)^2 + abs(Hitrate - Falsealarmrate)) / 
          (4 * max(Hitrate , Falsealarmrate) - 4 * Hitrate * Falsealarmrate))
    }

# %%
CF_CZ_sum2 <- CF_CZ_sum2[-c(1),]
CF_CZ_sum2
# Out:
#     subj Cong        Alig          Acc       MRT       SDT        NumbersOf
# 2   1    Congruent   Alignment     1.0000000 0.6370460 Hit        20
# 3   1    Congruent   Alignment           NaN       NaN Miss        0
# 4   1    Congruent   Alignment           NaN 0.8442827 FalseAlarm  5
# 5   1    Congruent   Alignment     0.7500000 0.8970654 CorrReject 15
# 6   1    Congruent   MissAlignment 0.9500000 0.6738286 Hit        19
# 7   1    Congruent   MissAlignment       NaN 0.7303272 Miss        1
# 8   1    Congruent   MissAlignment       NaN 0.5821567 FalseAlarm  3
# 9   1    Congruent   MissAlignment 0.8500000 0.7617110 CorrReject 17
# 10  1    InCongruent Alignment     0.9473684 0.6431473 Hit        18
# 11  1    InCongruent Alignment           NaN 0.9211915 Miss        1
# 12  1    InCongruent Alignment           NaN 0.6484769 FalseAlarm  4
# 13  1    InCongruent Alignment     0.8000000 0.7579221 CorrReject 16
# 14  1    InCongruent MissAlignment 1.0000000 0.6307566 Hit        20
# 15  1    InCongruent MissAlignment       NaN       NaN Miss        0
# 16  1    InCongruent MissAlignment       NaN 0.6366129 FalseAlarm  3
# 17  1    InCongruent MissAlignment 0.8421053 0.7899398 CorrReject 16
# 18  2    Congruent   Alignment     1.0000000 0.5395925 Hit        19
# 19  2    Congruent   Alignment           NaN       NaN Miss        0
# 20  2    Congruent   Alignment           NaN 0.5107259 FalseAlarm  4
# 21  2    Congruent   Alignment     0.7894737 0.7959934 CorrReject 15
# 22  2    Congruent   MissAlignment 0.6500000 0.6091076 Hit        13
# 23  2    Congruent   MissAlignment       NaN 0.9302448 Miss        7
# 24  2    Congruent   MissAlignment       NaN 0.5980075 FalseAlarm  1
# 25  2    Congruent   MissAlignment 0.9500000 0.7204148 CorrReject 19
# 26  2    InCongruent Alignment     0.9000000 0.6032914 Hit        18
# 27  2    InCongruent Alignment           NaN 0.6247627 Miss        2
# 28  2    InCongruent Alignment           NaN 0.7208486 FalseAlarm  7
# 29  2    InCongruent Alignment     0.6500000 0.8640764 CorrReject 13
# 30  2    InCongruent MissAlignment 0.8000000 0.6101801 Hit        16
# 31  2    InCongruent MissAlignment       NaN 1.0161234 Miss        4
# ⋮   ⋮    ⋮           ⋮             ⋮         ⋮         ⋮          ⋮
# 532 35   Congruent   Alignment           NaN 0.6859548 FalseAlarm  2
# 533 35   Congruent   Alignment     0.9000000 0.6849316 CorrReject 18
# 534 35   Congruent   MissAlignment 0.8500000 0.6861341 Hit        17
# 535 35   Congruent   MissAlignment       NaN 0.6540058 Miss        3
# 536 35   Congruent   MissAlignment       NaN 0.6403480 FalseAlarm  1
# 537 35   Congruent   MissAlignment 0.9473684 0.6734505 CorrReject 18
# 538 35   InCongruent Alignment     1.0000000 0.5429320 Hit        20
# 539 35   InCongruent Alignment           NaN       NaN Miss        0
# 540 35   InCongruent Alignment           NaN 0.6142539 FalseAlarm  2
# 541 35   InCongruent Alignment     0.9000000 0.6057684 CorrReject 18
# 542 35   InCongruent MissAlignment 0.8500000 0.6620291 Hit        17
# 543 35   InCongruent MissAlignment       NaN 0.8271516 Miss        3
# 544 35   InCongruent MissAlignment       NaN       NaN FalseAlarm  0
# 545 35   InCongruent MissAlignment 1.0000000 0.6313352 CorrReject 19
# 546 36   Congruent   Alignment     0.8947368 0.6889444 Hit        17
# 547 36   Congruent   Alignment           NaN 0.6342258 Miss        2
# 548 36   Congruent   Alignment           NaN       NaN FalseAlarm  0
# 549 36   Congruent   Alignment     1.0000000 0.6043763 CorrReject 20
# 550 36   Congruent   MissAlignment 1.0000000 0.7101865 Hit        20
# 551 36   Congruent   MissAlignment       NaN       NaN Miss        0
# 552 36   Congruent   MissAlignment       NaN       NaN FalseAlarm  0
# 553 36   Congruent   MissAlignment 1.0000000 0.6676848 CorrReject 20
# 554 36   InCongruent Alignment     0.7000000 0.6751984 Hit        14
# 555 36   InCongruent Alignment           NaN 0.8347082 Miss        6
# 556 36   InCongruent Alignment           NaN 0.6788513 FalseAlarm  1
# 557 36   InCongruent Alignment     0.9500000 0.6744899 CorrReject 19
# 558 36   InCongruent MissAlignment 0.8000000 0.7089077 Hit        16
# 559 36   InCongruent MissAlignment       NaN 0.5854120 Miss        4
# 560 36   InCongruent MissAlignment       NaN 0.6428392 FalseAlarm  1
# 561 36   InCongruent MissAlignment 0.9444444 0.7194512 CorrReject 17
#     HitRate   FalseAlarmRate dPrime    bias
# 2   1.0000000 0.2500000      0.9375000 -0.7834565
# 3         NaN       NaN            NaN        NaN
# 4         NaN       NaN            NaN        NaN
# 5         NaN       NaN            NaN        NaN
# 6   0.9500000 0.1500000      0.9458204 -0.3042101
# 7         NaN       NaN            NaN        NaN
# 8         NaN       NaN            NaN        NaN
# 9         NaN       NaN            NaN        NaN
# 10  0.9473684 0.2000000      0.9307749 -0.3891175
# 11        NaN       NaN            NaN        NaN
# 12        NaN       NaN            NaN        NaN
# 13        NaN       NaN            NaN        NaN
# 14  1.0000000 0.1578947      0.9605263 -0.6142289
# 15        NaN       NaN            NaN        NaN
# 16        NaN       NaN            NaN        NaN
# 17        NaN       NaN            NaN        NaN
# 18  1.0000000 0.2105263      0.9473684 -0.7084616
# 19        NaN       NaN            NaN        NaN
# 20        NaN       NaN            NaN        NaN
# 21        NaN       NaN            NaN        NaN
# 22  0.6500000 0.0500000      0.8886640  0.6297666
# 23        NaN       NaN            NaN        NaN
# 24        NaN       NaN            NaN        NaN
# 25        NaN       NaN            NaN        NaN
# 26  0.9000000 0.3500000      0.8643162 -0.4481155
# 27        NaN       NaN            NaN        NaN
# 28        NaN       NaN            NaN        NaN
# 29        NaN       NaN            NaN        NaN
# 30  0.8000000 0.0500000      0.9317434  0.4016162
# 31        NaN       NaN            NaN        NaN
# ⋮   ⋮         ⋮              ⋮         ⋮
# 532       NaN        NaN           NaN           NaN
# 533       NaN        NaN           NaN           NaN
# 534 0.8500000 0.05263158     0.9449368  2.917114e-01
# 535       NaN        NaN           NaN           NaN
# 536       NaN        NaN           NaN           NaN
# 537       NaN        NaN           NaN           NaN
# 538 1.0000000 0.10000000     0.9750000 -4.799256e-01
# 539       NaN        NaN           NaN           NaN
# 540       NaN        NaN           NaN           NaN
# 541       NaN        NaN           NaN           NaN
# 542 0.8500000 0.00000000     0.9625000  5.975862e-01
# 543       NaN        NaN           NaN           NaN
# 544       NaN        NaN           NaN           NaN
# 545       NaN        NaN           NaN           NaN
# 546 0.8947368 0.00000000     0.9736842  4.897432e-01
# 547       NaN        NaN           NaN           NaN
# 548       NaN        NaN           NaN           NaN
# 549       NaN        NaN           NaN           NaN
# 550 1.0000000 0.00000000     1.0000000 -8.881784e-16
# 551       NaN        NaN           NaN           NaN
# 552       NaN        NaN           NaN           NaN
# 553       NaN        NaN           NaN           NaN
# 554 0.7000000 0.05000000     0.9031955  5.602266e-01
# 555       NaN        NaN           NaN           NaN
# 556       NaN        NaN           NaN           NaN
# 557       NaN        NaN           NaN           NaN
# 558 0.8000000 0.05555556     0.9296977  3.757988e-01
# 559       NaN        NaN           NaN           NaN
# 560       NaN        NaN           NaN           NaN
# 561       NaN        NaN           NaN           NaN

# %%
CF_CZ_sum_dprime <- CF_CZ_sum2[which(CF_CZ_sum2$dPrime != "NaN"),]
#CF_CZ_sum_dprime <- CF_CZ_sum2[which(CF_CZ_sum2$dPrime != "NaN" & CF_CZ_sum2$dPrime != "Inf"),]

# %%
CF_CZ_sum_dprime
# Out:
#     subj Cong        Alig          Acc       MRT       SDT NumbersOf HitRate
# 2   1    Congruent   Alignment     1.0000000 0.6370460 Hit 20        1.0000000
# 6   1    Congruent   MissAlignment 0.9500000 0.6738286 Hit 19        0.9500000
# 10  1    InCongruent Alignment     0.9473684 0.6431473 Hit 18        0.9473684
# 14  1    InCongruent MissAlignment 1.0000000 0.6307566 Hit 20        1.0000000
# 18  2    Congruent   Alignment     1.0000000 0.5395925 Hit 19        1.0000000
# 22  2    Congruent   MissAlignment 0.6500000 0.6091076 Hit 13        0.6500000
# 26  2    InCongruent Alignment     0.9000000 0.6032914 Hit 18        0.9000000
# 30  2    InCongruent MissAlignment 0.8000000 0.6101801 Hit 16        0.8000000
# 34  3    Congruent   Alignment     0.6500000 0.9801260 Hit 13        0.6500000
# 38  3    Congruent   MissAlignment 0.7000000 1.1304159 Hit 14        0.7000000
# 42  3    InCongruent Alignment     0.5789474 1.1147169 Hit 11        0.5789474
# 46  3    InCongruent MissAlignment 0.5000000 1.1028651 Hit 10        0.5000000
# 50  4    Congruent   Alignment     0.9473684 1.4017708 Hit 18        0.9473684
# 54  4    Congruent   MissAlignment 0.9473684 1.1752195 Hit 18        0.9473684
# 58  4    InCongruent Alignment     0.7368421 0.9848006 Hit 14        0.7368421
# 62  4    InCongruent MissAlignment 0.7894737 1.2825394 Hit 15        0.7894737
# 66  5    Congruent   Alignment     0.9500000 0.5325168 Hit 19        0.9500000
# 70  5    Congruent   MissAlignment 0.9000000 0.5931956 Hit 18        0.9000000
# 74  5    InCongruent Alignment     0.7500000 0.5778854 Hit 15        0.7500000
# 78  5    InCongruent MissAlignment 0.7500000 0.5847910 Hit 15        0.7500000
# 82  6    Congruent   Alignment     1.0000000 0.5730339 Hit 20        1.0000000
# 86  6    Congruent   MissAlignment 0.8500000 0.7022417 Hit 17        0.8500000
# 90  6    InCongruent Alignment     0.9500000 0.6077550 Hit 19        0.9500000
# 94  6    InCongruent MissAlignment 0.8947368 0.6852643 Hit 17        0.8947368
# 98  7    Congruent   Alignment     0.9500000 0.7493642 Hit 19        0.9500000
# 102 7    Congruent   MissAlignment 0.8000000 0.7000447 Hit 16        0.8000000
# 106 7    InCongruent Alignment     0.7894737 0.7135296 Hit 15        0.7894737
# 110 7    InCongruent MissAlignment 0.8000000 0.7311379 Hit 16        0.8000000
# 114 8    Congruent   Alignment     1.0000000 0.6723414 Hit 20        1.0000000
# 118 8    Congruent   MissAlignment 0.9000000 0.7837298 Hit 18        0.9000000
# ⋮   ⋮    ⋮           ⋮             ⋮         ⋮         ⋮   ⋮         ⋮
# 442 29   InCongruent Alignment     0.9000000 0.6168183 Hit 18        0.9000000
# 446 29   InCongruent MissAlignment 1.0000000 0.6219847 Hit 20        1.0000000
# 450 30   Congruent   Alignment     1.0000000 0.4651588 Hit 19        1.0000000
# 454 30   Congruent   MissAlignment 0.9000000 0.5397204 Hit 18        0.9000000
# 458 30   InCongruent Alignment     0.9500000 0.4993035 Hit 19        0.9500000
# 462 30   InCongruent MissAlignment 1.0000000 0.5375054 Hit 20        1.0000000
# 466 31   Congruent   Alignment     0.8500000 0.5896924 Hit 17        0.8500000
# 470 31   Congruent   MissAlignment 0.9473684 0.6497630 Hit 18        0.9473684
# 474 31   InCongruent Alignment     0.9500000 0.6950666 Hit 19        0.9500000
# 478 31   InCongruent MissAlignment 0.9444444 0.6835966 Hit 17        0.9444444
# 482 32   Congruent   Alignment     0.9000000 0.5720790 Hit 18        0.9000000
# 486 32   Congruent   MissAlignment 0.7000000 0.6534673 Hit 14        0.7000000
# 490 32   InCongruent Alignment     0.8947368 0.6283932 Hit 17        0.8947368
# 494 32   InCongruent MissAlignment 0.9500000 0.5830074 Hit 19        0.9500000
# 498 33   Congruent   Alignment     1.0000000 0.6551042 Hit 20        1.0000000
# 502 33   Congruent   MissAlignment 0.9500000 0.7953750 Hit 19        0.9500000
# 506 33   InCongruent Alignment     1.0000000 0.7019923 Hit 19        1.0000000
# 510 33   InCongruent MissAlignment 0.8421053 0.6934426 Hit 16        0.8421053
# 514 34   Congruent   Alignment     0.9500000 0.5659886 Hit 19        0.9500000
# 518 34   Congruent   MissAlignment 1.0000000 0.7126294 Hit 19        1.0000000
# 522 34   InCongruent Alignment     0.8947368 0.6119678 Hit 17        0.8947368
# 526 34   InCongruent MissAlignment 0.9000000 0.7084854 Hit 18        0.9000000
# 530 35   Congruent   Alignment     1.0000000 0.5089334 Hit 20        1.0000000
# 534 35   Congruent   MissAlignment 0.8500000 0.6861341 Hit 17        0.8500000
# 538 35   InCongruent Alignment     1.0000000 0.5429320 Hit 20        1.0000000
# 542 35   InCongruent MissAlignment 0.8500000 0.6620291 Hit 17        0.8500000
# 546 36   Congruent   Alignment     0.8947368 0.6889444 Hit 17        0.8947368
# 550 36   Congruent   MissAlignment 1.0000000 0.7101865 Hit 20        1.0000000
# 554 36   InCongruent Alignment     0.7000000 0.6751984 Hit 14        0.7000000
# 558 36   InCongruent MissAlignment 0.8000000 0.7089077 Hit 16        0.8000000
#     FalseAlarmRate dPrime    bias
# 2   0.25000000     0.9375000 -0.7834565
# 6   0.15000000     0.9458204 -0.3042101
# 10  0.20000000     0.9307749 -0.3891175
# 14  0.15789474     0.9605263 -0.6142289
# 18  0.21052632     0.9473684 -0.7084616
# 22  0.05000000     0.8886640  0.6297666
# 26  0.35000000     0.8643162 -0.4481155
# 30  0.05000000     0.9317434  0.4016162
# 34  0.05263158     0.8873960  0.6172679
# 38  0.05263158     0.9020363  0.5477279
# 42  0.30000000     0.7200786  0.1625996
# 46  0.20000000     0.7437500  0.4208106
# 50  0.15000000     0.9449368 -0.2917114
# 54  0.10526316     0.9575163 -0.1838684
# 58  0.11111111     0.8882884  0.2935002
# 62  0.31578947     0.8230769 -0.1625454
# 66  0.00000000     0.9875000  0.2883330
# 70  0.00000000     0.9750000  0.4799256
# 74  0.10526316     0.8950593  0.2888149
# 78  0.15789474     0.8731497  0.1643291
# 82  0.20000000     0.9500000 -0.6998907
# 86  0.00000000     0.9625000  0.5975862
# 90  0.10000000     0.9597953 -0.1816510
# 94  0.15000000     0.9271285 -0.1078431
# 98  0.00000000     0.9875000  0.2933761
# 102 0.00000000     0.9500000  0.6949923
# 106 0.10526316     0.9078431  0.2237616
# 110 0.10000000     0.9131944  0.2199652
# 114 0.15789474     0.9605263 -0.6142289
# 118 0.26315789     0.8929720 -0.3239558
# ⋮   ⋮              ⋮         ⋮
# 442 0.05263158     0.9589912  1.691523e-01
# 446 0.00000000     1.0000000 -8.881784e-16
# 450 0.05000000     0.9875000 -2.933761e-01
# 454 0.00000000     0.9750000  4.799256e-01
# 458 0.10000000     0.9597953 -1.816510e-01
# 462 0.10000000     0.9750000 -4.799256e-01
# 466 0.15000000     0.9117647  0.000000e+00
# 470 0.05000000     0.9729551  1.249868e-02
# 474 0.00000000     0.9875000  2.933761e-01
# 478 0.15789474     0.9417113 -2.950354e-01
# 482 0.20000000     0.9131944 -2.199652e-01
# 486 0.21052632     0.8298120  1.400979e-01
# 490 0.30000000     0.8785825 -3.638595e-01
# 494 0.15000000     0.9458204 -3.042101e-01
# 498 0.15789474     0.9605263 -6.142289e-01
# 502 0.21052632     0.9287650 -4.201286e-01
# 506 0.26315789     0.9342105 -7.939398e-01
# 510 0.00000000     0.9605263  6.142289e-01
# 514 0.05000000     0.9736842  5.551115e-16
# 518 0.05000000     0.9875000 -2.933761e-01
# 522 0.40000000     0.8443756 -4.993862e-01
# 526 0.15000000     0.9289216 -1.225591e-01
# 530 0.10000000     0.9750000 -4.799256e-01
# 534 0.05263158     0.9449368  2.917114e-01
# 538 0.10000000     0.9750000 -4.799256e-01
# 542 0.00000000     0.9625000  5.975862e-01
# 546 0.00000000     0.9736842  4.897432e-01
# 550 0.00000000     1.0000000 -8.881784e-16
# 554 0.05000000     0.9031955  5.602266e-01
# 558 0.05555556     0.9296977  3.757988e-01

# %%
# #install.packages("writexl")
# library("writexl")
# write_xlsx(CF_CZ_sum_dprime,"/Users/j.amanirad/Desktop/CompositeFace/CF_CZ_sum_dprime.xlsx")

# %%
save(CF_CZ_sum_dprime,file="CF_CZ_sum_dprime.Rda")

# %%
CF_CZ_sum_dprime %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(dPrime, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean  sd
# 1 Congruent   Alignment     dPrime   35 0.964 0.029
# 2 Congruent   MissAlignment dPrime   35 0.938 0.049
# 3 InCongruent Alignment     dPrime   35 0.894 0.127
# 4 InCongruent MissAlignment dPrime   35 0.897 0.142

# %%
CF_CZ_sum_dprime[which(CF_CZ_sum_dprime$dPrime<=0.6),]
# Out:
#     subj Cong        Alig          Acc       MRT       SDT NumbersOf HitRate
# 138  9   InCongruent Alignment     0.5789474 0.5573038 Hit 11        0.5789474
# 142  9   InCongruent MissAlignment 0.6500000 0.6148598 Hit 13        0.6500000
# 266 18   InCongruent Alignment     0.8000000 0.7552564 Hit 16        0.8000000
# 270 18   InCongruent MissAlignment 0.6315789 0.9124987 Hit 12        0.6315789
#     FalseAlarmRate dPrime    bias
# 138 0.5263158      0.5505051 -0.1326066
# 142 0.8500000      0.2983193 -0.7108769
# 266 0.8500000      0.4227941 -0.9390273
# 270 0.6315789      0.5000000 -0.3360381

# %%
dd <- CF_CZ_sum_dprime[which(CF_CZ_sum_dprime$dPrime<=0.6),]

#qnorm(0.65) - qnorm(0.85)

CF_CZ_sum_dprime2<- CF_CZ_sum_dprime %>% 
  anti_join(dd, by = "dPrime") 
CF_CZ_sum_dprime2[which(CF_CZ_sum_dprime2$dPrime<=0.6),]
# Out:
#      subj Cong Alig Acc MRT SDT NumbersOf HitRate FalseAlarmRate dPrime bias

# %%
CF_CZ_sum_dprime2 %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(dPrime, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean  sd
# 1 Congruent   Alignment     dPrime   35 0.964 0.029
# 2 Congruent   MissAlignment dPrime   35 0.938 0.049
# 3 InCongruent Alignment     dPrime   33 0.919 0.077
# 4 InCongruent MissAlignment dPrime   33 0.927 0.065

# %%
ggdensity(CF_CZ_sum_dprime2$dPrime[CF_CZ_sum_dprime2$Cong == "InCongruent" & 
                                            CF_CZ_sum_dprime2$Alig == "Alignment" ], rug = TRUE, fill = "lightgray")
# Out:
# plot without title

# %%
ggdensity(CF_CZ_sum_dprime2, x = "dPrime",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
CF_CZ_sum_dprime2 %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(dPrime, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean  sd
# 1 Congruent   Alignment     dPrime   35 0.964 0.029
# 2 Congruent   MissAlignment dPrime   35 0.938 0.049
# 3 InCongruent Alignment     dPrime   33 0.919 0.077
# 4 InCongruent MissAlignment dPrime   33 0.927 0.065

# %%
CF_CZ_sum_dprime2 %>% group_by(Cong, Alig) %>% shapiro_test(dPrime)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     dPrime   0.9229603 0.0173666851
# 2 Congruent   MissAlignment dPrime   0.8732773 0.0008154245
# 3 InCongruent Alignment     dPrime   0.8291637 0.0001223633
# 4 InCongruent MissAlignment dPrime   0.8462152 0.0002813245

# %%
ggqqplot(CF_CZ_sum_dprime2, "dPrime", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_CZ_sum_dprime2, x = "Alig", y = "dPrime",
  color = "Cong", palette = "jco", 
    #outlier.shape = NA, 
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
CF_CZ_sum_dprime2 %>%
  group_by(Cong, Alig) %>%
  identify_outliers(dPrime)
# Out:
#   Cong        Alig          subj Acc       MRT       SDT NumbersOf HitRate
# 1 InCongruent Alignment      3   0.5789474 1.1147169 Hit 11        0.5789474
# 2 InCongruent Alignment     15   0.7894737 0.9686159 Hit 15        0.7894737
# 3 InCongruent MissAlignment  3   0.5000000 1.1028651 Hit 10        0.5000000
# 4 InCongruent MissAlignment  4   0.7894737 1.2825394 Hit 15        0.7894737
# 5 InCongruent MissAlignment  8   0.8333333 0.6782125 Hit 15        0.8333333
# 6 InCongruent MissAlignment 14   0.6000000 0.8714843 Hit 12        0.6000000
# 7 InCongruent MissAlignment 15   0.8000000 1.0099216 Hit 16        0.8000000
#   FalseAlarmRate dPrime    bias       is.outlier is.extreme
# 1 0.3000000      0.7200786  0.1625996 TRUE       FALSE
# 2 0.5789474      0.6916667 -0.5018989 TRUE       FALSE
# 3 0.2000000      0.7437500  0.4208106 TRUE       FALSE
# 4 0.3157895      0.8230769 -0.1625454 TRUE       FALSE
# 5 0.4000000      0.8105556 -0.3570372 TRUE       FALSE
# 6 0.2000000      0.7916667  0.2941371 TRUE       FALSE
# 7 0.3500000      0.8137019 -0.2281504 TRUE       FALSE

# %%
dd <- CF_CZ_sum_dprime2 %>%
  group_by(Cong, Alig) %>%
  identify_outliers(dPrime)

#dd <- dd[which(dd$is.extreme == TRUE),]

#qnorm(0.65) - qnorm(0.85)

CF_CZ_sum_dprime3<- CF_CZ_sum_dprime2 %>% 
  anti_join(dd, by = "dPrime") 

CF_CZ_sum_dprime3 %>%
  group_by(Cong, Alig) %>%
  identify_outliers(dPrime)

bxp <- ggboxplot(
  CF_CZ_sum_dprime3, x = "Alig", y = "dPrime",
  color = "Cong", palette = "jco", 
  #facet.by = "group", short.panel.labs = FALSE
) 
bxp
# Out:
#   Cong        Alig      subj Acc MRT     SDT NumbersOf HitRate FalseAlarmRate
# 1 InCongruent Alignment 16   0.8 1.18961 Hit 16        0.8     0.45
#   dPrime    bias       is.outlier is.extreme
# 1 0.7684659 -0.3579799 TRUE       FALSE
# plot without title

# %%
CF_CZ_sum_dprime3 %>% group_by(Cong, Alig) %>% shapiro_test(dPrime)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     dPrime   0.9229603 0.0173666851
# 2 Congruent   MissAlignment dPrime   0.8732773 0.0008154245
# 3 InCongruent Alignment     dPrime   0.8898249 0.0040545380
# 4 InCongruent MissAlignment dPrime   0.9299899 0.0616142283

# %%
ggqqplot(CF_CZ_sum_dprime3, "dPrime", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
save(CF_CZ_sum_dprime3,file="CF_CZ_sum_dprime3.Rda")

# %%
#t2way(dPrime ~ Cong*Alig, data = CF_CZ_sum_dprime)
#bwtrim(dPrime ~ Cong*Alig, id = subj, data = CF_CZ_sum_dprime3)

# %%
#res.Cong <- CF_CZ_sum_dprime3 %>% group_by(Alig) %>% friedman_test(dPrime ~ Cong |subj)
#res.Cong

# %%
#res.Alig <- CF_CZ_sum_dprime %>% group_by(Cong) %>% friedman_test(dPrime ~ Alig |subj)
#res.Alig

# %%
#CF_CZ_sum_dprime %>%
 # group_by(Cong, Alig) %>%
  #identify_outliers(dPrime)

# %%
#OUT <- CF_CZ_sum_dprime %>%
 # group_by(Cong, Alig) %>%
 # identify_outliers(dPrime)
#OUTT <- OUT[which(OUT$is.extreme == TRUE | OUT$is.extreme == FALSE ),]

#CF_CZ_sum_dprime2<- CF_CZ_sum_dprime %>% 
 # anti_join(OUTT, by = "dPrime")

# %%
#CF_CZ_sum_dprime2

# %%
#CF_CZ_sum_dprime3 %>%
 # group_by(Cong, Alig) %>%
  #identify_outliers(dPrime)

# %%
#OUT <- CF_CZ_sum_dprime3 %>%
 # group_by(Cong, Alig) %>%
  #identify_outliers(dPrime)
#OUTT <- OUT[which(OUT$is.extreme == TRUE | OUT$is.extreme == FALSE ),]

#CF_CZ_sum_dprime4<- CF_CZ_sum_dprime3 %>% 
 # anti_join(OUTT, by = "dPrime")

# %%
#ggdensity(CF_CZ_sum_dprime4$dPrime, rug = TRUE, fill = "lightgray")

# %%
#CF_CZ_sum_dprime4 %>% group_by(Cong, Alig) %>% shapiro_test(dPrime)

# %%
#ggqqplot(CF_CZ_sum_dprime4, "dPrime", ggtheme = theme_bw()) +
#  facet_grid(Cong ~ Alig, labeller = "label_both")

# %%
#bxp <- ggboxplot(
 # CF_CZ_sum_dprime2, x = "Alig", y = "dPrime",
  #color = "Cong", palette = "jco",
 # facet.by = "Alig", short.panel.labs = FALSE
#) 
#bxp

# %%
res.aov <- anova_test(
  data = CF_CZ_sum_dprime3, dv = dPrime, wid = subj,
  within = c(Cong, Alig)
)
get_anova_table(res.aov)
# Out:
#   Effect    DFn DFd F      p     p<.05 ges
# 1 Cong      1   27   4.611 0.041 *     0.042
# 2 Alig      1   27   0.451 0.508       0.003
# 3 Cong:Alig 1   27  12.629 0.001 *     0.051

# %%
one.way <- CF_CZ_sum_dprime3 %>%
  group_by(Cong) %>%
  anova_test(dv = dPrime, wid = subj, within = Alig) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way
# Out:
#   Cong        Effect DFn DFd F      p     p<.05 ges   p.adj
# 1 Congruent   Alig   1   34  12.258 0.001 *     0.099 0.002
# 2 InCongruent Alig   1   27   2.801 0.106       0.025 0.212

# %%
one.way2 <- CF_CZ_sum_dprime3 %>%
  group_by(Alig) %>%
  anova_test(dv = dPrime, wid = subj, within = Cong) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way2
# Out:
#   Alig          Effect DFn DFd F      p        p<.05 ges      p.adj
# 1 Alignment     Cong   1   30  15.483 0.000457 *     0.163000 0.000914
# 2 MissAlignment Cong   1   27   0.040 0.843000       0.000508 1.000000

# %% [markdown]
# # Bias

# %%
#CF_CZ_sum_bias <- CF_CZ_sum2[which(CF_CZ_sum2$bias != "NaN"),]
#CF_CZ_sum_bias
CF_CZ_sum_bias <- CF_CZ_sum_dprime2

# %%
CF_CZ_sum_bias %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(bias, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean   sd
# 1 Congruent   Alignment     bias     35 -0.218 0.376
# 2 Congruent   MissAlignment bias     35  0.114 0.486
# 3 InCongruent Alignment     bias     33 -0.153 0.351
# 4 InCongruent MissAlignment bias     33  0.113 0.415

# %%
ggdensity(CF_CZ_sum_bias, x = "bias",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_CZ_sum_bias, x = "Alig", y = "bias",
  color = "Cong", palette = "jco", outlier.shape = NA, 
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
CF_CZ_sum_bias %>% group_by(Cong, Alig) %>% shapiro_test(bias)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     bias     0.9573109 0.1896795
# 2 Congruent   MissAlignment bias     0.9816678 0.8120301
# 3 InCongruent Alignment     bias     0.9462405 0.1033057
# 4 InCongruent MissAlignment bias     0.9722508 0.5448040

# %%
ggqqplot(CF_CZ_sum_bias, "bias", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
save(CF_CZ_sum_bias,file="CF_CZ_sum_bias.Rda")

# %%
CF_CZ_sum_bias %>%
  group_by(Cong, Alig) %>%
  identify_outliers(bias)
# Out:
#      Cong Alig subj Acc MRT SDT NumbersOf HitRate FalseAlarmRate dPrime bias
#      is.outlier is.extreme

# %%
res.aov <- anova_test(
  data = CF_CZ_sum_bias, dv = bias, wid = subj,
  within = c(Cong, Alig)
)
get_anova_table(res.aov)
# Out:
#   Effect    DFn DFd F      p        p<.05 ges
# 1 Cong      1   32   0.005 0.946000       0.000022
# 2 Alig      1   32  17.011 0.000247 *     0.134000
# 3 Cong:Alig 1   32   0.657 0.424000       0.003000

# %%
# comparisons for Alig variable
CF_CZ_sum_bias %>%
  pairwise_t_test(
    bias ~ Alig, paired = TRUE, 
    p.adjust.method = "bonferroni"
    )
# Out:
#   .y.  group1    group2        n1 n2 statistic df p        p.adj
# 1 bias Alignment MissAlignment 68 68 -4.770243 67 1.03e-05 1.03e-05
#   p.adj.signif
# 1 ****

# %%
bxp <- ggboxplot(
  CF_CZ_sum_bias, x = "Alig", y = "bias",
  #color = "Cong", palette = "jco", outlier.shape = NA, 
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %% [markdown]
# # RT

# %%
CF_CZ_no_outlier[which(CF_CZ_no_outlier$Acc == 1),]

#CF_CZ_sum_dprime2[which(CF_CZ_sum_dprime2$MRT != "NaN"),]

#CF_CZ_sum_RT <- CF_CZ_sum2[which(CF_CZ_sum2$MRT != "NaN"),]
# Out:
#      subj Trial Cong        Alig          Acc RT        SDT
# 1    1     1    InCongruent MissAlignment 1   0.5030478 Hit
# 2    1     2    InCongruent Alignment     1   0.7539372 CorrReject
# 4    1     4    InCongruent Alignment     1   0.5998555 Hit
# 5    1     5    InCongruent MissAlignment 1   0.5507414 Hit
# 6    1     6    Congruent   Alignment     1   0.4725556 Hit
# 8    1     8    Congruent   MissAlignment 1   0.7523979 CorrReject
# 10   1    10    Congruent   Alignment     1   1.2720226 CorrReject
# 11   1    11    InCongruent MissAlignment 1   0.7651189 Hit
# 12   1    12    Congruent   MissAlignment 1   0.4940516 Hit
# 13   1    13    InCongruent Alignment     1   0.5368956 CorrReject
# 14   1    14    InCongruent MissAlignment 1   0.5620074 Hit
# 15   1    15    Congruent   Alignment     1   0.9321742 Hit
# 16   1    16    Congruent   MissAlignment 1   0.7655333 Hit
# 17   1    17    Congruent   MissAlignment 1   0.7423251 Hit
# 19   1    19    InCongruent MissAlignment 1   0.9078325 Hit
# 20   1    20    InCongruent Alignment     1   0.8697963 CorrReject
# 24   1    24    InCongruent MissAlignment 1   0.5881072 CorrReject
# 25   1    25    Congruent   MissAlignment 1   1.1233858 CorrReject
# 26   1    26    Congruent   MissAlignment 1   1.2385415 Hit
# 27   1    27    InCongruent Alignment     1   0.4344500 Hit
# 28   1    28    Congruent   MissAlignment 1   0.5933100 Hit
# 29   1    29    InCongruent MissAlignment 1   0.5679219 CorrReject
# 30   1    30    Congruent   Alignment     1   0.8972437 Hit
# 31   1    31    Congruent   MissAlignment 1   0.8035363 CorrReject
# 32   1    32    Congruent   MissAlignment 1   0.7859809 CorrReject
# 33   1    33    InCongruent Alignment     1   0.8099571 Hit
# 34   1    34    InCongruent MissAlignment 1   0.7284586 CorrReject
# 35   1    35    InCongruent Alignment     1   0.8900910 Hit
# 36   1    36    InCongruent MissAlignment 1   0.9571814 CorrReject
# 37   1    37    Congruent   Alignment     1   0.7261790 Hit
# ⋮    ⋮    ⋮     ⋮           ⋮             ⋮   ⋮         ⋮
# 5454 36   124   Congruent   Alignment     1   0.5939220 CorrReject
# 5455 36   125   Congruent   MissAlignment 1   0.8566358 CorrReject
# 5456 36   126   InCongruent MissAlignment 1   0.7420882 Hit
# 5457 36   127   Congruent   MissAlignment 1   0.9272966 CorrReject
# 5458 36   128   Congruent   Alignment     1   0.5614718 CorrReject
# 5459 36   129   Congruent   MissAlignment 1   0.6263605 CorrReject
# 5460 36   130   Congruent   Alignment     1   0.6179345 Hit
# 5461 36   131   Congruent   Alignment     1   0.5909531 CorrReject
# 5462 36   132   Congruent   MissAlignment 1   0.6964693 Hit
# 5463 36   133   InCongruent Alignment     1   0.5380510 Hit
# 5464 36   134   InCongruent MissAlignment 1   0.7952110 Hit
# 5465 36   135   Congruent   MissAlignment 1   0.6681140 Hit
# 5467 36   137   Congruent   MissAlignment 1   0.6909007 Hit
# 5468 36   138   InCongruent MissAlignment 1   0.8143406 CorrReject
# 5469 36   139   Congruent   MissAlignment 1   0.6907819 CorrReject
# 5471 36   141   InCongruent MissAlignment 1   0.6800811 Hit
# 5472 36   142   InCongruent Alignment     1   0.5860540 CorrReject
# 5473 36   143   Congruent   MissAlignment 1   0.7151909 Hit
# 5474 36   144   Congruent   MissAlignment 1   0.5799331 CorrReject
# 5475 36   145   Congruent   MissAlignment 1   0.7017421 Hit
# 5476 36   148   InCongruent Alignment     1   0.7216983 Hit
# 5477 36   149   InCongruent MissAlignment 1   0.5877280 CorrReject
# 5478 36   150   InCongruent MissAlignment 1   0.9614700 CorrReject
# 5482 36   154   InCongruent Alignment     1   0.6765433 Hit
# 5483 36   155   InCongruent Alignment     1   0.6965224 CorrReject
# 5484 36   156   InCongruent Alignment     1   0.6667583 CorrReject
# 5485 36   157   Congruent   Alignment     1   0.7602969 Hit
# 5486 36   158   InCongruent Alignment     1   0.8002304 CorrReject
# 5487 36   159   InCongruent MissAlignment 1   0.7346309 CorrReject
# 5488 36   160   InCongruent Alignment     1   0.6392383 CorrReject

# %%
CF_CZ_sum <- data.frame(subj = 1,
                       # Cond = NaN,
                        Cong = NaN,
                        Alig = NaN,
                        MRT = NaN
                        )

CF_CZ_sum2 <- data.frame(subj = NaN,
                      #  Cond = NaN,
                        Cong = NaN,
                        Alig = NaN,
                        MRT = NaN
                        )

# %%
iter <- 2
for(s in 1:36)
  if(s != 10)
  for(c in c("Congruent", "InCongruent"))
    for(a in c("Alignment", "MissAlignment")){
        CF_CZ_sum$subj <- s
        CF_CZ_sum$Cong <- c
        CF_CZ_sum$Alig <- a
        CF_CZ_sum$MRT <- mean(CF_CZ_no_outlier$RT[CF_CZ_no_outlier$subj == s & 
                                                        CF_CZ_no_outlier$Cong == c & 
                                                        CF_CZ_no_outlier$Alig == a  
                                                        ])
        iter <- iter + 1
        
        
        CF_CZ_sum2 <- rbind(CF_CZ_sum2,CF_CZ_sum)

    }

# %%
CF_CZ_sum_RT <- CF_CZ_sum2

CF_CZ_sum_RT <- CF_CZ_sum_RT[-c(1),]

# %%
CF_CZ_sum_RT
# Out:
#     subj Cong        Alig          MRT
# 2   1    Congruent   Alignment     0.7604579
# 3   1    Congruent   MissAlignment 0.7057157
# 4   1    InCongruent Alignment     0.6979104
# 5   1    InCongruent MissAlignment 0.6965130
# 6   2    Congruent   Alignment     0.6377648
# 7   2    Congruent   MissAlignment 0.7179001
# 8   2    InCongruent Alignment     0.7096926
# 9   2    InCongruent MissAlignment 0.7450624
# 10  3    Congruent   Alignment     0.9861372
# 11  3    Congruent   MissAlignment 1.0302258
# 12  3    InCongruent Alignment     1.1893151
# 13  3    InCongruent MissAlignment 1.0214554
# 14  4    Congruent   Alignment     1.4775591
# 15  4    Congruent   MissAlignment 1.2088155
# 16  4    InCongruent Alignment     1.2196368
# 17  4    InCongruent MissAlignment 1.3650315
# 18  5    Congruent   Alignment     0.5520120
# 19  5    Congruent   MissAlignment 0.5741810
# 20  5    InCongruent Alignment     0.5942507
# 21  5    InCongruent MissAlignment 0.5692342
# 22  6    Congruent   Alignment     0.7693006
# 23  6    Congruent   MissAlignment 0.7631276
# 24  6    InCongruent Alignment     0.6966254
# 25  6    InCongruent MissAlignment 0.8058689
# 26  7    Congruent   Alignment     0.7102731
# 27  7    Congruent   MissAlignment 0.7510553
# 28  7    InCongruent Alignment     0.7314403
# 29  7    InCongruent MissAlignment 0.6998078
# 30  8    Congruent   Alignment     0.9026594
# 31  8    Congruent   MissAlignment 0.8839121
# ⋮   ⋮    ⋮           ⋮             ⋮
# 112 29   InCongruent Alignment     0.6309746
# 113 29   InCongruent MissAlignment 0.6403586
# 114 30   Congruent   Alignment     0.5025697
# 115 30   Congruent   MissAlignment 0.5621819
# 116 30   InCongruent Alignment     0.5611977
# 117 30   InCongruent MissAlignment 0.5706609
# 118 31   Congruent   Alignment     0.6240932
# 119 31   Congruent   MissAlignment 0.6821199
# 120 31   InCongruent Alignment     0.6768583
# 121 31   InCongruent MissAlignment 0.7163094
# 122 32   Congruent   Alignment     0.6749392
# 123 32   Congruent   MissAlignment 0.7278998
# 124 32   InCongruent Alignment     0.7264832
# 125 32   InCongruent MissAlignment 0.6976658
# 126 33   Congruent   Alignment     0.6658261
# 127 33   Congruent   MissAlignment 0.7428063
# 128 33   InCongruent Alignment     0.7323106
# 129 33   InCongruent MissAlignment 0.7323257
# 130 34   Congruent   Alignment     0.6844796
# 131 34   Congruent   MissAlignment 0.7411301
# 132 34   InCongruent Alignment     0.6945990
# 133 34   InCongruent MissAlignment 0.7151014
# 134 35   Congruent   Alignment     0.5969836
# 135 35   Congruent   MissAlignment 0.6766347
# 136 35   InCongruent Alignment     0.5747745
# 137 35   InCongruent MissAlignment 0.6597774
# 138 36   Congruent   Alignment     0.6427700
# 139 36   Congruent   MissAlignment 0.6889357
# 140 36   InCongruent Alignment     0.6988797
# 141 36   InCongruent MissAlignment 0.6988863

# %%
CF_CZ_sum_dprime$MRT <- CF_CZ_sum_RT$MRT

# %%
#install.packages("writexl")
library("writexl")
write_xlsx(CF_CZ_sum_dprime,"/Users/j.amanirad/Desktop/CompositeFace/CF_CZ_sum_dprime.xlsx")

# %%
CF_CZ_sum_RT %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(MRT, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean  sd
# 1 Congruent   Alignment     MRT      35 0.755 0.219
# 2 Congruent   MissAlignment MRT      35 0.787 0.200
# 3 InCongruent Alignment     MRT      35 0.785 0.210
# 4 InCongruent MissAlignment MRT      35 0.805 0.220

# %%
ggdensity(CF_CZ_sum_RT, x = "MRT",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
CF_CZ_sum_RT %>%
  group_by(Cong, Alig) %>%
  identify_outliers(MRT)
# Out:
#   Cong        Alig          subj MRT      is.outlier is.extreme
# 1 Congruent   Alignment      4   1.477559 TRUE       FALSE
# 2 Congruent   Alignment     16   1.398513 TRUE       FALSE
# 3 Congruent   MissAlignment 16   1.455354 TRUE       FALSE
# 4 InCongruent Alignment     16   1.407029 TRUE       FALSE
# 5 InCongruent MissAlignment  4   1.365031 TRUE       FALSE
# 6 InCongruent MissAlignment 16   1.484843 TRUE       FALSE

# %%
CF_CZ_sum_RT %>% group_by(Cong, Alig) %>% shapiro_test(MRT)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     MRT      0.8439863 0.0001689267
# 2 Congruent   MissAlignment MRT      0.8946422 0.0028469246
# 3 InCongruent Alignment     MRT      0.9025608 0.0046366541
# 4 InCongruent MissAlignment MRT      0.8772900 0.0010240610

# %%
ggqqplot(CF_CZ_sum_RT, "MRT", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_CZ_sum_RT, x = "Alig", y = "MRT",
  color = "Cong", palette = "jco",
 # facet.by = "Alig", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
dd <- CF_CZ_sum_RT %>%
  group_by(Cong, Alig) %>%
  identify_outliers(MRT)

#dd <- dd[which(dd$is.extreme == TRUE),]

#qnorm(0.65) - qnorm(0.85)

CF_CZ_sum_RT2<- CF_CZ_sum_RT %>% 
  anti_join(dd, by = "MRT") 

CF_CZ_sum_RT2 %>%
  group_by(Cong, Alig) %>%
  identify_outliers(MRT)

bxp <- ggboxplot(
  CF_CZ_sum_RT2, x = "Alig", y = "MRT",
  color = "Cong", palette = "jco", 
  #facet.by = "group", short.panel.labs = FALSE
) 
bxp
# Out:
#   Cong        Alig          subj MRT      is.outlier is.extreme
# 1 InCongruent MissAlignment 24   1.184951 TRUE       FALSE
# plot without title

# %%
CF_CZ_sum_RT2 %>%
  group_by(Cong, Alig) %>%
  get_summary_stats(MRT, type = "mean_sd")
# Out:
#   Cong        Alig          variable n  mean  sd
# 1 Congruent   Alignment     MRT      33 0.713 0.142
# 2 Congruent   MissAlignment MRT      34 0.767 0.165
# 3 InCongruent Alignment     MRT      34 0.767 0.183
# 4 InCongruent MissAlignment MRT      33 0.768 0.161

# %%
ggdensity(CF_CZ_sum_RT2, x = "MRT",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = "Alig")
# Out:
# plot without title

# %%
CF_CZ_sum_RT2 %>% group_by(Cong, Alig) %>% shapiro_test(MRT)
# Out:
#   Cong        Alig          variable statistic p
# 1 Congruent   Alignment     MRT      0.9596578 0.25278688
# 2 Congruent   MissAlignment MRT      0.9416446 0.06901682
# 3 InCongruent Alignment     MRT      0.9227302 0.01931212
# 4 InCongruent MissAlignment MRT      0.9407198 0.07128862

# %%
ggqqplot(CF_CZ_sum_RT2, "MRT", ggtheme = theme_bw()) +
  facet_grid(Cong ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
save(CF_CZ_sum_RT2,file="CF_CZ_sum_RT2.Rda")

# %%
#t2way(dPrime ~ Cong*Alig, data = CF_CZ_sum_dprime)
#bwtrim(MRT ~ Cong*Alig, id = subj, data = CF_CZ_sum_RT)

# %%
#res.Co <- CF_CZ_sum_RT %>% group_by(Alig) %>% friedman_test(MRT ~ Cong |subj)
#res.Co

# %%
#res.Alig <- CF_CZ_sum_RT %>% group_by(Cong) %>% friedman_test(MRT ~ Alig |subj)
#res.Alig

# %%
res.aov <- anova_test(
  data = CF_CZ_sum_RT2, dv = MRT, wid = subj,
  within = c(Cong, Alig)
)
get_anova_table(res.aov)
# Out:
#   Effect    DFn DFd F      p        p<.05 ges
# 1 Cong      1   32  20.030 9.06e-05 *     0.008
# 2 Alig      1   32  15.105 4.81e-04 *     0.008
# 3 Cong:Alig 1   32   5.178 3.00e-02 *     0.002

# %%
one.way <- CF_CZ_sum_RT2 %>%
  group_by(Alig) %>%
  anova_test(dv = MRT, wid = subj, within = Cong) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way
# Out:
#   Alig          Effect DFn DFd F      p        p<.05 ges   p.adj
# 1 Alignment     Cong   1   32  16.570 0.000287 *     0.017 0.000574
# 2 MissAlignment Cong   1   32   4.507 0.042000 *     0.002 0.084000

# %%
one.way2 <- CF_CZ_sum_RT2 %>%
  group_by(Cong) %>%
  anova_test(dv = MRT, wid = subj, within = Alig) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
one.way2
# Out:
#   Cong        Effect DFn DFd F      p        p<.05 ges   p.adj
# 1 Congruent   Alig   1   32  32.603 2.52e-06 *     0.020 5.04e-06
# 2 InCongruent Alig   1   32   1.771 1.93e-01       0.002 3.86e-01
