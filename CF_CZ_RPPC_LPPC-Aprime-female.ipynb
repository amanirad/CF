# %% [markdown]
# # Composite Face: CZ_RPPC_LPPC_female

# %%
library(tidyverse)
library(ggpubr)
library(rstatix)
library(readxl)
library(dplyr)
setwd("/Users/j.amanirad/Desktop/CompositeFace")

# %%
#install.packages('WRS2')
library(WRS2)
#conda install -c conda-forge r-wrs2

# %%
load("CF_RPPC_female_dprime2.Rda")
load("CF_CZ_female_dprime2.Rda")
load("CF_LPPC_female_dprime2.Rda")

# %%
CF_CZ_female_dprime2
CF_RPPC_female_dprime2
CF_LPPC_female_dprime2
# Out:
#    subj Cong        Alig          Acc       MRT       SDT NumbersOf HitRate
# 1  19   Congruent   Alignment     1.0000000 0.7849932 Hit 19        1.0000000
# 2  19   Congruent   MissAlignment 0.9500000 0.8151910 Hit 19        0.9500000
# 3  19   InCongruent Alignment     0.8500000 0.9307214 Hit 17        0.8500000
# 4  19   InCongruent MissAlignment 1.0000000 0.9004288 Hit 20        1.0000000
# 5  20   Congruent   Alignment     1.0000000 0.5790370 Hit 20        1.0000000
# 6  20   Congruent   MissAlignment 0.9473684 0.6029169 Hit 18        0.9473684
# 7  20   InCongruent Alignment     0.9500000 0.6143512 Hit 19        0.9500000
# 8  20   InCongruent MissAlignment 0.9500000 0.6340836 Hit 19        0.9500000
# 9  21   Congruent   Alignment     1.0000000 0.4460446 Hit 20        1.0000000
# 10 21   Congruent   MissAlignment 0.8947368 0.4532856 Hit 17        0.8947368
# 11 21   InCongruent Alignment     1.0000000 0.4609552 Hit 20        1.0000000
# 12 21   InCongruent MissAlignment 0.9000000 0.4712704 Hit 18        0.9000000
# 13 22   Congruent   Alignment     1.0000000 0.6811108 Hit 20        1.0000000
# 14 22   Congruent   MissAlignment 0.9473684 0.7372810 Hit 18        0.9473684
# 15 22   InCongruent Alignment     1.0000000 0.7887514 Hit 20        1.0000000
# 16 22   InCongruent MissAlignment 0.9473684 0.7529951 Hit 18        0.9473684
# 17 23   Congruent   Alignment     0.8421053 0.8851699 Hit 16        0.8421053
# 18 23   Congruent   MissAlignment 0.6000000 1.0350229 Hit 12        0.6000000
# 19 23   InCongruent Alignment     0.7500000 0.8160524 Hit 15        0.7500000
# 20 24   Congruent   Alignment     1.0000000 1.0251602 Hit 20        1.0000000
# 21 24   Congruent   MissAlignment 0.8947368 1.0892948 Hit 17        0.8947368
# 22 24   InCongruent Alignment     1.0000000 1.0620158 Hit 20        1.0000000
# 23 24   InCongruent MissAlignment 1.0000000 1.2673149 Hit 18        1.0000000
# 24 25   Congruent   Alignment     1.0000000 0.6066546 Hit 20        1.0000000
# 25 25   Congruent   MissAlignment 0.9000000 0.6723962 Hit 18        0.9000000
# 26 25   InCongruent Alignment     0.9473684 0.7083654 Hit 18        0.9473684
# 27 25   InCongruent MissAlignment 1.0000000 0.6297208 Hit 19        1.0000000
# 28 26   Congruent   Alignment     0.9500000 0.9479996 Hit 19        0.9500000
# 29 26   Congruent   MissAlignment 0.9500000 0.7667514 Hit 19        0.9500000
# 30 26   InCongruent Alignment     1.0000000 1.0649274 Hit 20        1.0000000
# ⋮  ⋮    ⋮           ⋮             ⋮         ⋮         ⋮   ⋮         ⋮
# 39 28   InCongruent MissAlignment 0.9500000 0.5349247 Hit 19        0.9500000
# 40 29   Congruent   Alignment     1.0000000 0.5636175 Hit 20        1.0000000
# 41 29   Congruent   MissAlignment 1.0000000 0.6173737 Hit 18        1.0000000
# 42 29   InCongruent Alignment     0.9000000 0.6168183 Hit 18        0.9000000
# 43 29   InCongruent MissAlignment 1.0000000 0.6219847 Hit 20        1.0000000
# 44 30   Congruent   Alignment     1.0000000 0.4651588 Hit 19        1.0000000
# 45 30   Congruent   MissAlignment 0.9000000 0.5397204 Hit 18        0.9000000
# 46 30   InCongruent Alignment     0.9500000 0.4993035 Hit 19        0.9500000
# 47 30   InCongruent MissAlignment 1.0000000 0.5375054 Hit 20        1.0000000
# 48 31   Congruent   MissAlignment 0.9473684 0.6497630 Hit 18        0.9473684
# 49 31   InCongruent Alignment     0.9500000 0.6950666 Hit 19        0.9500000
# 50 31   InCongruent MissAlignment 0.9444444 0.6835966 Hit 17        0.9444444
# 51 32   InCongruent Alignment     0.8947368 0.6283932 Hit 17        0.8947368
# 52 32   InCongruent MissAlignment 0.9500000 0.5830074 Hit 19        0.9500000
# 53 33   Congruent   Alignment     1.0000000 0.6551042 Hit 20        1.0000000
# 54 33   Congruent   MissAlignment 0.9500000 0.7953750 Hit 19        0.9500000
# 55 33   InCongruent Alignment     1.0000000 0.7019923 Hit 19        1.0000000
# 56 33   InCongruent MissAlignment 0.8421053 0.6934426 Hit 16        0.8421053
# 57 34   Congruent   Alignment     0.9500000 0.5659886 Hit 19        0.9500000
# 58 34   Congruent   MissAlignment 1.0000000 0.7126294 Hit 19        1.0000000
# 59 34   InCongruent Alignment     0.8947368 0.6119678 Hit 17        0.8947368
# 60 34   InCongruent MissAlignment 0.9000000 0.7084854 Hit 18        0.9000000
# 61 35   Congruent   Alignment     1.0000000 0.5089334 Hit 20        1.0000000
# 62 35   Congruent   MissAlignment 0.8500000 0.6861341 Hit 17        0.8500000
# 63 35   InCongruent Alignment     1.0000000 0.5429320 Hit 20        1.0000000
# 64 35   InCongruent MissAlignment 0.8500000 0.6620291 Hit 17        0.8500000
# 65 36   Congruent   Alignment     0.8947368 0.6889444 Hit 17        0.8947368
# 66 36   Congruent   MissAlignment 1.0000000 0.7101865 Hit 20        1.0000000
# 67 36   InCongruent Alignment     0.7000000 0.6751984 Hit 14        0.7000000
# 68 36   InCongruent MissAlignment 0.8000000 0.7089077 Hit 16        0.8000000
#    FalseAlarmRate dPrime    bias
# 1  0.00000000     1.0000000  0.000000e+00
# 2  0.05000000     0.9736842  5.551115e-16
# 3  0.20000000     0.8943015 -9.740608e-02
# 4  0.20000000     0.9500000 -6.998907e-01
# 5  0.00000000     1.0000000 -8.881784e-16
# 6  0.20000000     0.9307749 -3.891175e-01
# 7  0.00000000     0.9875000  2.933761e-01
# 8  0.00000000     0.9875000  2.933761e-01
# 9  0.05000000     0.9875000 -2.982746e-01
# 10 0.10000000     0.9428191  1.471602e-02
# 11 0.00000000     1.0000000 -8.881784e-16
# 12 0.00000000     0.9750000  4.799256e-01
# 13 0.00000000     1.0000000 -8.881784e-16
# 14 0.00000000     0.9868421  3.058748e-01
# 15 0.05263158     0.9868421 -3.058748e-01
# 16 0.00000000     0.9868421  3.058748e-01
# 17 0.05000000     0.9436050  3.208528e-01
# 18 0.00000000     0.9000000  9.940278e-01
# 19 0.15000000     0.8764706  1.809718e-01
# 20 0.05263158     0.9868421 -3.058748e-01
# 21 0.05000000     0.9583286  1.963671e-01
# 22 0.10526316     0.9736842 -4.897432e-01
# 23 0.00000000     1.0000000  0.000000e+00
# 24 0.15000000     0.9625000 -6.024847e-01
# 25 0.00000000     0.9750000  4.750271e-01
# 26 0.10000000     0.9589912 -1.691523e-01
# 27 0.15000000     0.9625000 -5.975862e-01
# 28 0.05000000     0.9736842  5.551115e-16
# 29 0.11111111     0.9566977 -2.121066e-01
# 30 0.10000000     0.9750000 -4.799256e-01
# ⋮  ⋮              ⋮         ⋮
# 39 0.05000000     0.9736842  5.551115e-16
# 40 0.00000000     1.0000000 -6.661338e-16
# 41 0.10000000     0.9750000 -4.699840e-01
# 42 0.05263158     0.9589912  1.691523e-01
# 43 0.00000000     1.0000000 -8.881784e-16
# 44 0.05000000     0.9875000 -2.933761e-01
# 45 0.00000000     0.9750000  4.799256e-01
# 46 0.10000000     0.9597953 -1.816510e-01
# 47 0.10000000     0.9750000 -4.799256e-01
# 48 0.05000000     0.9729551  1.249868e-02
# 49 0.00000000     0.9875000  2.933761e-01
# 50 0.15789474     0.9417113 -2.950354e-01
# 51 0.30000000     0.8785825 -3.638595e-01
# 52 0.15000000     0.9458204 -3.042101e-01
# 53 0.15789474     0.9605263 -6.142289e-01
# 54 0.21052632     0.9287650 -4.201286e-01
# 55 0.26315789     0.9342105 -7.939398e-01
# 56 0.00000000     0.9605263  6.142289e-01
# 57 0.05000000     0.9736842  5.551115e-16
# 58 0.05000000     0.9875000 -2.933761e-01
# 59 0.40000000     0.8443756 -4.993862e-01
# 60 0.15000000     0.9289216 -1.225591e-01
# 61 0.10000000     0.9750000 -4.799256e-01
# 62 0.05263158     0.9449368  2.917114e-01
# 63 0.10000000     0.9750000 -4.799256e-01
# 64 0.00000000     0.9625000  5.975862e-01
# 65 0.00000000     0.9736842  4.897432e-01
# 66 0.00000000     1.0000000 -8.881784e-16
# 67 0.05000000     0.9031955  5.602266e-01
# 68 0.05555556     0.9296977  3.757988e-01
#    subj Cong        Alig          Acc       MRT       SDT NumbersOf HitRate
# 1  19   Congruent   Alignment     1.0000000 0.6950884 Hit 20        1.0000000
# 2  19   Congruent   MissAlignment 0.9500000 0.8844856 Hit 19        0.9500000
# 3  19   InCongruent Alignment     1.0000000 0.9557520 Hit 20        1.0000000
# 4  19   InCongruent MissAlignment 1.0000000 1.0295367 Hit 20        1.0000000
# 5  20   Congruent   Alignment     0.9473684 0.5052560 Hit 18        0.9473684
# 6  20   Congruent   MissAlignment 1.0000000 0.6388566 Hit 20        1.0000000
# 7  20   InCongruent Alignment     0.9500000 0.5533852 Hit 19        0.9500000
# 8  20   InCongruent MissAlignment 0.8947368 0.5745613 Hit 17        0.8947368
# 9  21   Congruent   Alignment     1.0000000 0.4807577 Hit 20        1.0000000
# 10 21   Congruent   MissAlignment 1.0000000 0.5053129 Hit 20        1.0000000
# 11 21   InCongruent Alignment     0.9473684 0.5378751 Hit 18        0.9473684
# 12 21   InCongruent MissAlignment 1.0000000 0.5273198 Hit 20        1.0000000
# 13 22   Congruent   Alignment     1.0000000 0.6505359 Hit 20        1.0000000
# 14 22   Congruent   MissAlignment 0.9500000 0.7768870 Hit 19        0.9500000
# 15 22   InCongruent Alignment     0.9500000 0.6703611 Hit 19        0.9500000
# 16 22   InCongruent MissAlignment 1.0000000 0.8663355 Hit 20        1.0000000
# 17 23   Congruent   Alignment     0.9000000 1.0804954 Hit 18        0.9000000
# 18 23   InCongruent Alignment     0.6842105 1.2410155 Hit 13        0.6842105
# 19 24   Congruent   Alignment     1.0000000 0.9365407 Hit 19        1.0000000
# 20 24   Congruent   MissAlignment 0.9000000 1.0476425 Hit 18        0.9000000
# 21 24   InCongruent Alignment     0.9473684 1.0019168 Hit 18        0.9473684
# 22 24   InCongruent MissAlignment 0.7894737 0.9014376 Hit 15        0.7894737
# 23 25   Congruent   Alignment     1.0000000 0.6605161 Hit 20        1.0000000
# 24 25   Congruent   MissAlignment 0.9444444 0.6736366 Hit 17        0.9444444
# 25 25   InCongruent Alignment     0.9000000 0.6561704 Hit 18        0.9000000
# 26 25   InCongruent MissAlignment 0.9473684 0.6201552 Hit 18        0.9473684
# 27 26   Congruent   Alignment     1.0000000 0.8295263 Hit 20        1.0000000
# 28 26   Congruent   MissAlignment 0.9500000 1.0447785 Hit 19        0.9500000
# 29 26   InCongruent Alignment     0.8888889 0.8537149 Hit 16        0.8888889
# 30 26   InCongruent MissAlignment 0.9000000 0.8562756 Hit 18        0.9000000
# ⋮  ⋮    ⋮           ⋮             ⋮         ⋮         ⋮   ⋮         ⋮
# 41 29   InCongruent Alignment     0.8500000 0.7024886 Hit 17        0.8500000
# 42 29   InCongruent MissAlignment 0.9500000 0.6551287 Hit 19        0.9500000
# 43 30   Congruent   Alignment     1.0000000 0.5174688 Hit 20        1.0000000
# 44 30   Congruent   MissAlignment 0.9000000 0.5172002 Hit 18        0.9000000
# 45 30   InCongruent Alignment     0.9500000 0.5515208 Hit 19        0.9500000
# 46 30   InCongruent MissAlignment 0.8500000 0.5171511 Hit 17        0.8500000
# 47 31   Congruent   Alignment     1.0000000 0.5102685 Hit 20        1.0000000
# 48 31   Congruent   MissAlignment 0.9500000 0.5414328 Hit 19        0.9500000
# 49 31   InCongruent Alignment     0.9000000 0.5297764 Hit 18        0.9000000
# 50 31   InCongruent MissAlignment 0.9500000 0.5711761 Hit 19        0.9500000
# 51 32   Congruent   Alignment     1.0000000 0.6200003 Hit 20        1.0000000
# 52 32   Congruent   MissAlignment 0.9500000 0.6275718 Hit 19        0.9500000
# 53 32   InCongruent Alignment     0.9000000 0.7010587 Hit 18        0.9000000
# 54 32   InCongruent MissAlignment 0.8947368 0.7250000 Hit 17        0.8947368
# 55 33   Congruent   Alignment     0.8500000 0.5698607 Hit 17        0.8500000
# 56 33   Congruent   MissAlignment 0.7000000 0.6154968 Hit 14        0.7000000
# 57 33   InCongruent Alignment     0.8500000 0.6081657 Hit 17        0.8500000
# 58 33   InCongruent MissAlignment 0.8500000 0.6027416 Hit 17        0.8500000
# 59 34   Congruent   Alignment     1.0000000 0.5890851 Hit 20        1.0000000
# 60 34   Congruent   MissAlignment 1.0000000 0.6782475 Hit 19        1.0000000
# 61 34   InCongruent Alignment     0.7894737 0.7401963 Hit 15        0.7894737
# 62 34   InCongruent MissAlignment 0.8421053 0.6653947 Hit 16        0.8421053
# 63 35   Congruent   Alignment     1.0000000 0.5000790 Hit 20        1.0000000
# 64 35   Congruent   MissAlignment 1.0000000 0.5733711 Hit 20        1.0000000
# 65 35   InCongruent Alignment     1.0000000 0.4991427 Hit 18        1.0000000
# 66 35   InCongruent MissAlignment 0.8500000 0.5864044 Hit 17        0.8500000
# 67 36   Congruent   Alignment     1.0000000 0.6318742 Hit 20        1.0000000
# 68 36   Congruent   MissAlignment 0.8947368 0.6122100 Hit 17        0.8947368
# 69 36   InCongruent Alignment     0.7500000 0.6672326 Hit 15        0.7500000
# 70 36   InCongruent MissAlignment 0.8421053 0.7068353 Hit 16        0.8421053
#    FalseAlarmRate dPrime    bias
# 1  0.10526316     0.9736842 -4.897432e-01
# 2  0.10000000     0.9597953 -1.816510e-01
# 3  0.26315789     0.9342105 -7.989829e-01
# 4  0.11111111     0.9722222 -5.004396e-01
# 5  0.05263158     0.9722222  2.220446e-16
# 6  0.00000000     1.0000000 -8.881784e-16
# 7  0.05263158     0.9729551 -1.249868e-02
# 8  0.00000000     0.9736842  4.897432e-01
# 9  0.00000000     1.0000000 -6.661338e-16
# 10 0.15000000     0.9625000 -6.024847e-01
# 11 0.05000000     0.9729551  1.249868e-02
# 12 0.20000000     0.9500000 -6.998907e-01
# 13 0.10000000     0.9750000 -4.799256e-01
# 14 0.05263158     0.9729551 -1.249868e-02
# 15 0.15000000     0.9458204 -3.042101e-01
# 16 0.00000000     1.0000000 -8.881784e-16
# 17 0.10000000     0.9444444  0.000000e+00
# 18 0.26315789     0.7967033  7.706717e-02
# 19 0.10000000     0.9750000 -4.750271e-01
# 20 0.00000000     0.9750000  4.750271e-01
# 21 0.00000000     0.9868421  3.058748e-01
# 22 0.10000000     0.9098538  2.384776e-01
# 23 0.10000000     0.9750000 -4.799256e-01
# 24 0.00000000     0.9861111  3.089542e-01
# 25 0.30000000     0.8809524 -3.785755e-01
# 26 0.10000000     0.9589912 -1.691523e-01
# 27 0.05555556     0.9861111 -3.141504e-01
# 28 0.15000000     0.9458204 -3.042101e-01
# 29 0.31578947     0.8705859 -3.705673e-01
# 30 0.20000000     0.9131944 -2.199652e-01
# ⋮  ⋮              ⋮         ⋮
# 41 0.15789474     0.9090291 -1.664271e-02
# 42 0.05882353     0.9712389 -4.006358e-02
# 43 0.00000000     1.0000000 -8.881784e-16
# 44 0.15789474     0.9264529 -1.392018e-01
# 45 0.05000000     0.9736842  5.551115e-16
# 46 0.10000000     0.9289216  1.225591e-01
# 47 0.15000000     0.9625000 -6.024847e-01
# 48 0.00000000     0.9875000  2.933761e-01
# 49 0.10000000     0.9444444  0.000000e+00
# 50 0.15789474     0.9436050 -3.208528e-01
# 51 0.15000000     0.9625000 -6.024847e-01
# 52 0.10526316     0.9583286 -1.963671e-01
# 53 0.25000000     0.8972222 -3.035309e-01
# 54 0.05263158     0.9575163  1.838684e-01
# 55 0.05000000     0.9458204  3.042101e-01
# 56 0.00000000     0.9250000  8.585011e-01
# 57 0.10000000     0.9289216  1.225591e-01
# 58 0.10526316     0.9271285  1.078431e-01
# 59 0.10000000     0.9750000 -4.799256e-01
# 60 0.00000000     1.0000000 -6.661338e-16
# 61 0.00000000     0.9473684  7.135047e-01
# 62 0.00000000     0.9605263  6.039896e-01
# 63 0.05000000     0.9875000 -2.982746e-01
# 64 0.05000000     0.9875000 -2.982746e-01
# 65 0.00000000     1.0000000  0.000000e+00
# 66 0.05000000     0.9458204  3.042101e-01
# 67 0.00000000     1.0000000 -8.881784e-16
# 68 0.05000000     0.9583286  1.963671e-01
# 69 0.10000000     0.8972222  3.035309e-01
# 70 0.05000000     0.9436050  3.208528e-01
#    subj Cong        Alig          Acc       MRT       SDT NumbersOf HitRate
# 1  19   Congruent   Alignment     1.0000000 0.7051917 Hit 20        1.0000000
# 2  19   Congruent   MissAlignment 1.0000000 0.7680895 Hit 20        1.0000000
# 3  19   InCongruent Alignment     0.9000000 0.8660095 Hit 18        0.9000000
# 4  19   InCongruent MissAlignment 1.0000000 0.8560690 Hit 19        1.0000000
# 5  20   Congruent   Alignment     1.0000000 0.5172117 Hit 20        1.0000000
# 6  20   Congruent   MissAlignment 0.9500000 0.6054839 Hit 19        0.9500000
# 7  20   InCongruent Alignment     0.9000000 0.5732484 Hit 18        0.9000000
# 8  20   InCongruent MissAlignment 1.0000000 0.5406231 Hit 19        1.0000000
# 9  21   Congruent   Alignment     1.0000000 0.4704586 Hit 20        1.0000000
# 10 21   Congruent   MissAlignment 0.9500000 0.4999499 Hit 19        0.9500000
# 11 21   InCongruent Alignment     1.0000000 0.4926813 Hit 19        1.0000000
# 12 21   InCongruent MissAlignment 1.0000000 0.4734755 Hit 20        1.0000000
# 13 22   Congruent   Alignment     1.0000000 0.6825023 Hit 20        1.0000000
# 14 22   Congruent   MissAlignment 1.0000000 0.7505330 Hit 19        1.0000000
# 15 22   InCongruent Alignment     0.9473684 0.7098779 Hit 18        0.9473684
# 16 22   InCongruent MissAlignment 0.9000000 0.7253731 Hit 18        0.9000000
# 17 23   Congruent   Alignment     0.9500000 0.7236385 Hit 19        0.9500000
# 18 23   InCongruent Alignment     0.7894737 0.7562886 Hit 15        0.7894737
# 19 23   InCongruent MissAlignment 0.7368421 0.9188082 Hit 14        0.7368421
# 20 24   Congruent   Alignment     0.9473684 0.8115077 Hit 18        0.9473684
# 21 24   Congruent   MissAlignment 1.0000000 0.8827494 Hit 19        1.0000000
# 22 24   InCongruent Alignment     0.8421053 0.8172979 Hit 16        0.8421053
# 23 24   InCongruent MissAlignment 1.0000000 0.8924817 Hit 19        1.0000000
# 24 25   Congruent   Alignment     0.9500000 0.6455697 Hit 19        0.9500000
# 25 25   Congruent   MissAlignment 0.9500000 0.8426718 Hit 19        0.9500000
# 26 25   InCongruent Alignment     0.9000000 0.7613155 Hit 18        0.9000000
# 27 25   InCongruent MissAlignment 0.9473684 0.6940593 Hit 18        0.9473684
# 28 26   Congruent   Alignment     0.9500000 0.8566306 Hit 19        0.9500000
# 29 26   Congruent   MissAlignment 0.9500000 0.8887891 Hit 19        0.9500000
# 30 26   InCongruent Alignment     0.9473684 1.0035966 Hit 18        0.9473684
# ⋮  ⋮    ⋮           ⋮             ⋮         ⋮         ⋮   ⋮         ⋮
# 41 29   InCongruent Alignment     0.9444444 0.7489858 Hit 17        0.9444444
# 42 29   InCongruent MissAlignment 0.9473684 0.7275354 Hit 18        0.9473684
# 43 30   Congruent   Alignment     1.0000000 0.5034887 Hit 20        1.0000000
# 44 30   Congruent   MissAlignment 1.0000000 0.5343914 Hit 20        1.0000000
# 45 30   InCongruent Alignment     1.0000000 0.5531455 Hit 20        1.0000000
# 46 30   InCongruent MissAlignment 0.9500000 0.5589545 Hit 19        0.9500000
# 47 31   Congruent   Alignment     0.9500000 0.4860119 Hit 19        0.9500000
# 48 31   Congruent   MissAlignment 0.9000000 0.4834507 Hit 18        0.9000000
# 49 31   InCongruent Alignment     0.9000000 0.5339250 Hit 18        0.9000000
# 50 31   InCongruent MissAlignment 0.8947368 0.5661962 Hit 17        0.8947368
# 51 32   Congruent   Alignment     1.0000000 0.6528953 Hit 20        1.0000000
# 52 32   Congruent   MissAlignment 1.0000000 0.7380030 Hit 19        1.0000000
# 53 32   InCongruent Alignment     0.8947368 0.7499736 Hit 17        0.8947368
# 54 32   InCongruent MissAlignment 0.9500000 0.8001234 Hit 19        0.9500000
# 55 33   Congruent   Alignment     1.0000000 0.6296572 Hit 20        1.0000000
# 56 33   Congruent   MissAlignment 0.8947368 0.6474264 Hit 17        0.8947368
# 57 33   InCongruent Alignment     1.0000000 0.6767898 Hit 20        1.0000000
# 58 33   InCongruent MissAlignment 0.8421053 0.6155200 Hit 16        0.8421053
# 59 34   Congruent   Alignment     1.0000000 0.5877669 Hit 20        1.0000000
# 60 34   Congruent   MissAlignment 0.9500000 0.7002336 Hit 19        0.9500000
# 61 34   InCongruent Alignment     0.8500000 0.6837920 Hit 17        0.8500000
# 62 34   InCongruent MissAlignment 0.7500000 0.6830697 Hit 15        0.7500000
# 63 35   Congruent   Alignment     1.0000000 0.4794247 Hit 19        1.0000000
# 64 35   Congruent   MissAlignment 0.9000000 0.6012651 Hit 18        0.9000000
# 65 35   InCongruent Alignment     1.0000000 0.4896043 Hit 20        1.0000000
# 66 35   InCongruent MissAlignment 1.0000000 0.6188222 Hit 20        1.0000000
# 67 36   Congruent   Alignment     0.9000000 0.6475334 Hit 18        0.9000000
# 68 36   Congruent   MissAlignment 0.9500000 0.6680381 Hit 19        0.9500000
# 69 36   InCongruent Alignment     0.5789474 0.6139592 Hit 11        0.5789474
# 70 36   InCongruent MissAlignment 0.9000000 0.7077158 Hit 18        0.9000000
#    FalseAlarmRate dPrime    bias
# 1  0.05000000     0.9875000 -2.982746e-01
# 2  0.10000000     0.9750000 -4.799256e-01
# 3  0.15000000     0.9289216 -1.225591e-01
# 4  0.20000000     0.9500000 -6.949923e-01
# 5  0.00000000     1.0000000 -8.881784e-16
# 6  0.00000000     0.9875000  2.933761e-01
# 7  0.00000000     0.9750000  4.799256e-01
# 8  0.05000000     0.9875000 -2.933761e-01
# 9  0.05000000     0.9875000 -2.982746e-01
# 10 0.00000000     0.9875000  2.982746e-01
# 11 0.05000000     0.9875000 -2.933761e-01
# 12 0.10000000     0.9750000 -4.799256e-01
# 13 0.00000000     1.0000000 -6.661338e-16
# 14 0.10000000     0.9750000 -4.750271e-01
# 15 0.00000000     0.9868421  3.058748e-01
# 16 0.00000000     0.9750000  4.799256e-01
# 17 0.05000000     0.9736842  5.551115e-16
# 18 0.20000000     0.8708772  1.851243e-02
# 19 0.05000000     0.9137836  5.056068e-01
# 20 0.05000000     0.9729551  1.249868e-02
# 21 0.00000000     1.0000000 -6.661338e-16
# 22 0.05000000     0.9436050  3.208528e-01
# 23 0.00000000     1.0000000 -6.661338e-16
# 24 0.20000000     0.9317434 -4.016162e-01
# 25 0.05263158     0.9729551 -1.249868e-02
# 26 0.15789474     0.9264529 -1.392018e-01
# 27 0.25000000     0.9164839 -4.726833e-01
# 28 0.15789474     0.9436050 -3.208528e-01
# 29 0.05263158     0.9729551 -1.249868e-02
# 30 0.20000000     0.9307749 -3.891175e-01
# ⋮  ⋮              ⋮         ⋮
# 41 0.05000000     0.9721448  2.581740e-02
# 42 0.05000000     0.9729551  1.249868e-02
# 43 0.10000000     0.9750000 -4.799256e-01
# 44 0.15789474     0.9605263 -6.142289e-01
# 45 0.00000000     1.0000000 -6.661338e-16
# 46 0.05000000     0.9736842  5.551115e-16
# 47 0.10000000     0.9597953 -1.816510e-01
# 48 0.10000000     0.9444444  0.000000e+00
# 49 0.10000000     0.9444444  0.000000e+00
# 50 0.05263158     0.9575163  1.838684e-01
# 51 0.10000000     0.9750000 -4.799256e-01
# 52 0.10526316     0.9736842 -4.847000e-01
# 53 0.31578947     0.8733032 -3.863069e-01
# 54 0.22222222     0.9254490 -4.400720e-01
# 55 0.00000000     1.0000000 -6.661338e-16
# 56 0.10000000     0.9428191  1.471602e-02
# 57 0.15789474     0.9605263 -6.142289e-01
# 58 0.05263158     0.9427083  3.083541e-01
# 59 0.00000000     1.0000000 -8.881784e-16
# 60 0.00000000     0.9875000  2.933761e-01
# 61 0.05263158     0.9449368  2.917114e-01
# 62 0.05000000     0.9175439  4.851819e-01
# 63 0.20000000     0.9500000 -6.949923e-01
# 64 0.00000000     0.9750000  4.750271e-01
# 65 0.10000000     0.9750000 -4.799256e-01
# 66 0.05000000     0.9875000 -2.982746e-01
# 67 0.00000000     0.9750000  4.799256e-01
# 68 0.00000000     0.9875000  2.982746e-01
# 69 0.00000000     0.8947368  1.016202e+00
# 70 0.05000000     0.9597953  1.816510e-01

# %%
# Qz_C_A <- quantile(CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "Congruent" & CF_CZ_sum_dprime$Alig == "Alignment"],
#                probs=c(.25, .75), na.rm = FALSE)
# Qz_C_MA <- quantile(CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "Congruent" & CF_CZ_sum_dprime$Alig == "MissAlignment"],
#                probs=c(.25, .75), na.rm = FALSE)
# Qz_IC_A <- quantile(CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "InCongruent" & CF_CZ_sum_dprime$Alig == "Alignment"],
#                probs=c(.25, .75), na.rm = FALSE)
# Qz_IC_MA <- quantile(CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "InCongruent" & CF_CZ_sum_dprime$Alig == "MissAlignment"],
#                probs=c(.25, .75), na.rm = FALSE)
# Qr_C_A <- quantile(CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "Congruent" & CF_RPPC_sum_dprime$Alig == "Alignment"],
#                probs=c(.25, .75), na.rm = FALSE)
# Qr_C_MA <- quantile(CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "Congruent" & CF_RPPC_sum_dprime$Alig == "MissAlignment"],
#                probs=c(.25, .75), na.rm = FALSE)
# Qr_IC_A <- quantile(CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "InCongruent" & CF_RPPC_sum_dprime$Alig == "Alignment"],
#                probs=c(.25, .75), na.rm = FALSE)
# Qr_IC_MA <- quantile(CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "InCongruent" & CF_RPPC_sum_dprime$Alig == "MissAlignment"],
#                probs=c(.25, .75), na.rm = FALSE)

# iqrz_C_A <- IQR(CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "Congruent" & CF_CZ_sum_dprime$Alig == "Alignment"])
# iqrz_C_MA <- IQR(CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "Congruent" & CF_CZ_sum_dprime$Alig == "MissAlignment"])
# iqrz_IC_A <- IQR(CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "InCongruent" & CF_CZ_sum_dprime$Alig == "Alignment"])
# iqrz_IC_MA <- IQR(CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "InCongruent" & CF_CZ_sum_dprime$Alig == "MissAlignment"])


# iqrr_C_A <- IQR(CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "Congruent" & CF_RPPC_sum_dprime$Alig == "Alignment"])
# iqrr_C_MA <- IQR(CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "Congruent" & CF_RPPC_sum_dprime$Alig == "MissAlignment"])
# iqrr_IC_A <- IQR(CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "InCongruent" & CF_RPPC_sum_dprime$Alig == "Alignment"])
# iqrr_IC_MA <- IQR(CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "InCongruent" & CF_RPPC_sum_dprime$Alig == "MissAlignment"])


# upz_C_A <-  Qz_C_A[2]+1.5*iqrz_C_A # Upper Range  
# lowz_C_A <- Qz_C_A[1]-1.5*iqrz_C_A # Lower Range
# upz_C_MA <-  Qz_C_MA[2]+1.5*iqrz_C_MA # Upper Range  
# lowz_C_MA <- Qz_C_MA[1]-1.5*iqrz_C_MA # Lower Range
# upz_IC_A <-  Qz_IC_A[2]+1.5*iqrz_IC_A # Upper Range  
# lowz_IC_A <- Qz_IC_A[1]-1.5*iqrz_IC_A # Lower Range
# upz_IC_MA <-  Qz_IC_MA[2]+1.5*iqrz_IC_MA # Upper Range  
# lowz_IC_MA <- Qz_IC_MA[1]-1.5*iqrz_IC_MA # Lower Range

# upr_C_A <-  Qr_C_A[2]+1.5*iqrr_C_A # Upper Range  
# lowr_C_A <- Qr_C_A[1]-1.5*iqrr_C_A # Lower Range
# upr_C_MA <-  Qr_C_MA[2]+1.5*iqrr_C_MA # Upper Range  
# lowr_C_MA <- Qr_C_MA[1]-1.5*iqrr_C_MA # Lower Range
# upr_IC_A <-  Qr_IC_A[2]+1.5*iqrr_IC_A # Upper Range  
# lowr_IC_A <- Qr_IC_A[1]-1.5*iqrr_IC_A # Lower Range
# upr_IC_MA <-  Qr_IC_MA[2]+1.5*iqrr_IC_MA # Upper Range  
# lowr_IC_MA <- Qr_IC_MA[1]-1.5*iqrr_IC_MA # Lower Range

# %%
# CF_CZ_sum_dprime_out<- subset(CF_CZ_sum_dprime, 
#                               CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "Congruent" & 
#                                                       CF_CZ_sum_dprime$Alig == "Alignment"] >
#                               (Qz_C_A[1] - 1.5*iqrz_C_A) &
#                               CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "Congruent" & 
#                                                       CF_CZ_sum_dprime$Alig == "Alignment"] <
#                               (Qz_C_A[2]+1.5*iqrz_C_A) &
#                               CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "Congruent" & 
#                                                       CF_CZ_sum_dprime$Alig == "MissAlignment"] >
#                               (Qz_C_MA[1] - 1.5*iqrz_C_MA) &
#                               CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "Congruent" & 
#                                                       CF_CZ_sum_dprime$Alig == "MissAlignment"] <
#                               (Qz_C_MA[2]+1.5*iqrz_C_MA) &
#                               CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "InCongruent" & 
#                                                       CF_CZ_sum_dprime$Alig == "Alignment"] >
#                               (Qz_IC_A[1] - 1.5*iqrz_IC_A) &
#                               CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "InCongruent" & 
#                                                       CF_CZ_sum_dprime$Alig == "Alignment"] <
#                               (Qz_IC_A[2]+1.5*iqrz_IC_A) &
#                               CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "InCongruent" & 
#                                                       CF_CZ_sum_dprime$Alig == "MissAlignment"] >
#                               (Qz_IC_MA[1] - 1.5*iqrz_IC_MA) &
#                               CF_CZ_sum_dprime$dPrime[CF_CZ_sum_dprime$Cong == "InCongruent" & 
#                                                       CF_CZ_sum_dprime$Alig == "MissAlignment"] <
#                               (Qz_IC_MA[2]+1.5*iqrz_IC_MA)
#                              )
# CF_CZ_sum_dprime_out

# CF_RPPC_sum_dprime_out<- subset(CF_RPPC_sum_dprime, 
#                               CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "Congruent" & 
#                                                       CF_RPPC_sum_dprime$Alig == "Alignment"] >
#                               (Qr_C_A[1] - 1.5*iqrr_C_A) &
#                               CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "Congruent" & 
#                                                       CF_RPPC_sum_dprime$Alig == "Alignment"] <
#                               (Qr_C_A[2]+1.5*iqrr_C_A) &
#                               CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "Congruent" & 
#                                                       CF_RPPC_sum_dprime$Alig == "MissAlignment"] >
#                               (Qr_C_MA[1] - 1.5*iqrr_C_MA) &
#                               CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "Congruent" & 
#                                                       CF_RPPC_sum_dprime$Alig == "MissAlignment"] <
#                               (Qr_C_MA[2]+1.5*iqrr_C_MA) &
#                               CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "InCongruent" & 
#                                                       CF_RPPC_sum_dprime$Alig == "Alignment"] >
#                               (Qr_IC_A[1] - 1.5*iqrr_IC_A) &
#                               CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "InCongruent" & 
#                                                       CF_RPPC_sum_dprime$Alig == "Alignment"] <
#                               (Qr_IC_A[2]+1.5*iqrr_IC_A) &
#                               CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "InCongruent" & 
#                                                       CF_RPPC_sum_dprime$Alig == "MissAlignment"] >
#                               (Qr_IC_MA[1] - 1.5*iqrr_IC_MA) &
#                               CF_RPPC_sum_dprime$dPrime[CF_RPPC_sum_dprime$Cong == "InCongruent" & 
#                                                       CF_RPPC_sum_dprime$Alig == "MissAlignment"] <
#                               (Qr_IC_MA[2]+1.5*iqrr_IC_MA)
#                              )
# CF_RPPC_sum_dprime_out

# %%
CF_CZ_female_dprime_out <- CF_CZ_female_dprime2
CF_RPPC_female_dprime_out <- CF_RPPC_female_dprime2
CF_LPPC_female_dprime_out <- CF_LPPC_female_dprime2

# %%
CF_CZ_female_dprime_out$group <- "CZ"
CF_RPPC_female_dprime_out$group <- "RPPC"
CF_LPPC_female_dprime_out$group <- "LPPC"

# %%
CF <- rbind(CF_CZ_female_dprime_out,CF_RPPC_female_dprime_out, CF_LPPC_female_dprime_out)

# %%
CF
# Out:
#     subj Cong        Alig          Acc       MRT       SDT NumbersOf HitRate
# 1   19   Congruent   Alignment     1.0000000 0.7849932 Hit 19        1.0000000
# 2   19   Congruent   MissAlignment 0.9500000 0.8151910 Hit 19        0.9500000
# 3   19   InCongruent Alignment     0.8500000 0.9307214 Hit 17        0.8500000
# 4   19   InCongruent MissAlignment 1.0000000 0.9004288 Hit 20        1.0000000
# 5   20   Congruent   Alignment     1.0000000 0.5790370 Hit 20        1.0000000
# 6   20   Congruent   MissAlignment 0.9473684 0.6029169 Hit 18        0.9473684
# 7   20   InCongruent Alignment     0.9500000 0.6143512 Hit 19        0.9500000
# 8   20   InCongruent MissAlignment 0.9500000 0.6340836 Hit 19        0.9500000
# 9   21   Congruent   Alignment     1.0000000 0.4460446 Hit 20        1.0000000
# 10  21   Congruent   MissAlignment 0.8947368 0.4532856 Hit 17        0.8947368
# 11  21   InCongruent Alignment     1.0000000 0.4609552 Hit 20        1.0000000
# 12  21   InCongruent MissAlignment 0.9000000 0.4712704 Hit 18        0.9000000
# 13  22   Congruent   Alignment     1.0000000 0.6811108 Hit 20        1.0000000
# 14  22   Congruent   MissAlignment 0.9473684 0.7372810 Hit 18        0.9473684
# 15  22   InCongruent Alignment     1.0000000 0.7887514 Hit 20        1.0000000
# 16  22   InCongruent MissAlignment 0.9473684 0.7529951 Hit 18        0.9473684
# 17  23   Congruent   Alignment     0.8421053 0.8851699 Hit 16        0.8421053
# 18  23   Congruent   MissAlignment 0.6000000 1.0350229 Hit 12        0.6000000
# 19  23   InCongruent Alignment     0.7500000 0.8160524 Hit 15        0.7500000
# 20  24   Congruent   Alignment     1.0000000 1.0251602 Hit 20        1.0000000
# 21  24   Congruent   MissAlignment 0.8947368 1.0892948 Hit 17        0.8947368
# 22  24   InCongruent Alignment     1.0000000 1.0620158 Hit 20        1.0000000
# 23  24   InCongruent MissAlignment 1.0000000 1.2673149 Hit 18        1.0000000
# 24  25   Congruent   Alignment     1.0000000 0.6066546 Hit 20        1.0000000
# 25  25   Congruent   MissAlignment 0.9000000 0.6723962 Hit 18        0.9000000
# 26  25   InCongruent Alignment     0.9473684 0.7083654 Hit 18        0.9473684
# 27  25   InCongruent MissAlignment 1.0000000 0.6297208 Hit 19        1.0000000
# 28  26   Congruent   Alignment     0.9500000 0.9479996 Hit 19        0.9500000
# 29  26   Congruent   MissAlignment 0.9500000 0.7667514 Hit 19        0.9500000
# 30  26   InCongruent Alignment     1.0000000 1.0649274 Hit 20        1.0000000
# ⋮   ⋮    ⋮           ⋮             ⋮         ⋮         ⋮   ⋮         ⋮
# 179 29   InCongruent Alignment     0.9444444 0.7489858 Hit 17        0.9444444
# 180 29   InCongruent MissAlignment 0.9473684 0.7275354 Hit 18        0.9473684
# 181 30   Congruent   Alignment     1.0000000 0.5034887 Hit 20        1.0000000
# 182 30   Congruent   MissAlignment 1.0000000 0.5343914 Hit 20        1.0000000
# 183 30   InCongruent Alignment     1.0000000 0.5531455 Hit 20        1.0000000
# 184 30   InCongruent MissAlignment 0.9500000 0.5589545 Hit 19        0.9500000
# 185 31   Congruent   Alignment     0.9500000 0.4860119 Hit 19        0.9500000
# 186 31   Congruent   MissAlignment 0.9000000 0.4834507 Hit 18        0.9000000
# 187 31   InCongruent Alignment     0.9000000 0.5339250 Hit 18        0.9000000
# 188 31   InCongruent MissAlignment 0.8947368 0.5661962 Hit 17        0.8947368
# 189 32   Congruent   Alignment     1.0000000 0.6528953 Hit 20        1.0000000
# 190 32   Congruent   MissAlignment 1.0000000 0.7380030 Hit 19        1.0000000
# 191 32   InCongruent Alignment     0.8947368 0.7499736 Hit 17        0.8947368
# 192 32   InCongruent MissAlignment 0.9500000 0.8001234 Hit 19        0.9500000
# 193 33   Congruent   Alignment     1.0000000 0.6296572 Hit 20        1.0000000
# 194 33   Congruent   MissAlignment 0.8947368 0.6474264 Hit 17        0.8947368
# 195 33   InCongruent Alignment     1.0000000 0.6767898 Hit 20        1.0000000
# 196 33   InCongruent MissAlignment 0.8421053 0.6155200 Hit 16        0.8421053
# 197 34   Congruent   Alignment     1.0000000 0.5877669 Hit 20        1.0000000
# 198 34   Congruent   MissAlignment 0.9500000 0.7002336 Hit 19        0.9500000
# 199 34   InCongruent Alignment     0.8500000 0.6837920 Hit 17        0.8500000
# 200 34   InCongruent MissAlignment 0.7500000 0.6830697 Hit 15        0.7500000
# 201 35   Congruent   Alignment     1.0000000 0.4794247 Hit 19        1.0000000
# 202 35   Congruent   MissAlignment 0.9000000 0.6012651 Hit 18        0.9000000
# 203 35   InCongruent Alignment     1.0000000 0.4896043 Hit 20        1.0000000
# 204 35   InCongruent MissAlignment 1.0000000 0.6188222 Hit 20        1.0000000
# 205 36   Congruent   Alignment     0.9000000 0.6475334 Hit 18        0.9000000
# 206 36   Congruent   MissAlignment 0.9500000 0.6680381 Hit 19        0.9500000
# 207 36   InCongruent Alignment     0.5789474 0.6139592 Hit 11        0.5789474
# 208 36   InCongruent MissAlignment 0.9000000 0.7077158 Hit 18        0.9000000
#     FalseAlarmRate dPrime    bias          group
# 1   0.00000000     1.0000000  0.000000e+00 CZ
# 2   0.05000000     0.9736842  5.551115e-16 CZ
# 3   0.20000000     0.8943015 -9.740608e-02 CZ
# 4   0.20000000     0.9500000 -6.998907e-01 CZ
# 5   0.00000000     1.0000000 -8.881784e-16 CZ
# 6   0.20000000     0.9307749 -3.891175e-01 CZ
# 7   0.00000000     0.9875000  2.933761e-01 CZ
# 8   0.00000000     0.9875000  2.933761e-01 CZ
# 9   0.05000000     0.9875000 -2.982746e-01 CZ
# 10  0.10000000     0.9428191  1.471602e-02 CZ
# 11  0.00000000     1.0000000 -8.881784e-16 CZ
# 12  0.00000000     0.9750000  4.799256e-01 CZ
# 13  0.00000000     1.0000000 -8.881784e-16 CZ
# 14  0.00000000     0.9868421  3.058748e-01 CZ
# 15  0.05263158     0.9868421 -3.058748e-01 CZ
# 16  0.00000000     0.9868421  3.058748e-01 CZ
# 17  0.05000000     0.9436050  3.208528e-01 CZ
# 18  0.00000000     0.9000000  9.940278e-01 CZ
# 19  0.15000000     0.8764706  1.809718e-01 CZ
# 20  0.05263158     0.9868421 -3.058748e-01 CZ
# 21  0.05000000     0.9583286  1.963671e-01 CZ
# 22  0.10526316     0.9736842 -4.897432e-01 CZ
# 23  0.00000000     1.0000000  0.000000e+00 CZ
# 24  0.15000000     0.9625000 -6.024847e-01 CZ
# 25  0.00000000     0.9750000  4.750271e-01 CZ
# 26  0.10000000     0.9589912 -1.691523e-01 CZ
# 27  0.15000000     0.9625000 -5.975862e-01 CZ
# 28  0.05000000     0.9736842  5.551115e-16 CZ
# 29  0.11111111     0.9566977 -2.121066e-01 CZ
# 30  0.10000000     0.9750000 -4.799256e-01 CZ
# ⋮   ⋮              ⋮         ⋮             ⋮
# 179 0.05000000     0.9721448  2.581740e-02 LPPC
# 180 0.05000000     0.9729551  1.249868e-02 LPPC
# 181 0.10000000     0.9750000 -4.799256e-01 LPPC
# 182 0.15789474     0.9605263 -6.142289e-01 LPPC
# 183 0.00000000     1.0000000 -6.661338e-16 LPPC
# 184 0.05000000     0.9736842  5.551115e-16 LPPC
# 185 0.10000000     0.9597953 -1.816510e-01 LPPC
# 186 0.10000000     0.9444444  0.000000e+00 LPPC
# 187 0.10000000     0.9444444  0.000000e+00 LPPC
# 188 0.05263158     0.9575163  1.838684e-01 LPPC
# 189 0.10000000     0.9750000 -4.799256e-01 LPPC
# 190 0.10526316     0.9736842 -4.847000e-01 LPPC
# 191 0.31578947     0.8733032 -3.863069e-01 LPPC
# 192 0.22222222     0.9254490 -4.400720e-01 LPPC
# 193 0.00000000     1.0000000 -6.661338e-16 LPPC
# 194 0.10000000     0.9428191  1.471602e-02 LPPC
# 195 0.15789474     0.9605263 -6.142289e-01 LPPC
# 196 0.05263158     0.9427083  3.083541e-01 LPPC
# 197 0.00000000     1.0000000 -8.881784e-16 LPPC
# 198 0.00000000     0.9875000  2.933761e-01 LPPC
# 199 0.05263158     0.9449368  2.917114e-01 LPPC
# 200 0.05000000     0.9175439  4.851819e-01 LPPC
# 201 0.20000000     0.9500000 -6.949923e-01 LPPC
# 202 0.00000000     0.9750000  4.750271e-01 LPPC
# 203 0.10000000     0.9750000 -4.799256e-01 LPPC
# 204 0.05000000     0.9875000 -2.982746e-01 LPPC
# 205 0.00000000     0.9750000  4.799256e-01 LPPC
# 206 0.00000000     0.9875000  2.982746e-01 LPPC
# 207 0.00000000     0.8947368  1.016202e+00 LPPC
# 208 0.05000000     0.9597953  1.816510e-01 LPPC

# %%
CF %>%
  group_by(Cong, Alig, group) %>%
  get_summary_stats(dPrime, type = "mean_sd")
# Out:
#    Cong        Alig          group variable n  mean  sd
# 1  Congruent   Alignment     CZ    dPrime   16 0.980 0.017
# 2  Congruent   Alignment     LPPC  dPrime   18 0.978 0.021
# 3  Congruent   Alignment     RPPC  dPrime   18 0.976 0.018
# 4  Congruent   MissAlignment CZ    dPrime   17 0.963 0.026
# 5  Congruent   MissAlignment LPPC  dPrime   16 0.975 0.017
# 6  Congruent   MissAlignment RPPC  dPrime   17 0.971 0.024
# 7  InCongruent Alignment     CZ    dPrime   18 0.946 0.047
# 8  InCongruent Alignment     LPPC  dPrime   18 0.945 0.041
# 9  InCongruent Alignment     RPPC  dPrime   18 0.934 0.052
# 10 InCongruent MissAlignment CZ    dPrime   17 0.966 0.022
# 11 InCongruent MissAlignment LPPC  dPrime   18 0.951 0.036
# 12 InCongruent MissAlignment RPPC  dPrime   17 0.955 0.026

# %%
#iqr <- CF %>% group_by(group) %>% IQR(dPrime)

# %%
CF %>%
  group_by(Cong, Alig, group) %>%
  identify_outliers(dPrime)

bxp <- ggboxplot(
  CF, x = "Alig", y = "dPrime",
  color = "Cong", palette = "jco", 
  facet.by = "group", short.panel.labs = FALSE
) 
bxp
# Out:
#   Cong      Alig          group subj Acc       MRT       SDT NumbersOf
# 1 Congruent MissAlignment LPPC  33   0.8947368 0.6474264 Hit 17
#   HitRate   FalseAlarmRate dPrime    bias       is.outlier is.extreme
# 1 0.8947368 0.1            0.9428191 0.01471602 TRUE       FALSE
# plot without title

# %%
# dd <- CF %>%
#   group_by(Cong, Alig, group) %>%
#   identify_outliers(dPrime)

# #dd <- dd[which(dd$is.extreme == TRUE),]

# #qnorm(0.65) - qnorm(0.85)

# CF2<- CF %>% 
#   anti_join(dd, by = "dPrime") 

# CF2 %>%
#   group_by(Cong, Alig) %>%
#   identify_outliers(dPrime)

# bxp <- ggboxplot(
#   CF2, x = "Alig", y = "dPrime",
#   color = "Cong", palette = "jco", 
#   facet.by = "group", short.panel.labs = FALSE
# ) 
# bxp

# %%
# dd <- CF2 %>%
#   group_by(Cong, Alig, group) %>%
#   identify_outliers(dPrime)

# #dd <- dd[which(dd$is.extreme == TRUE),]

# #qnorm(0.65) - qnorm(0.85)

# CF3<- CF2 %>% 
#   anti_join(dd, by = "dPrime") 

# CF3 %>%
#   group_by(Cong, Alig) %>%
#   identify_outliers(dPrime)

# bxp <- ggboxplot(
#   CF3, x = "Alig", y = "dPrime",
#   color = "Cong", palette = "jco", 
#   facet.by = "group", short.panel.labs = FALSE
# ) 
# bxp

# %%
# dd <- CF3 %>%
#   group_by(Cong, Alig, group) %>%
#   identify_outliers(dPrime)

# #dd <- dd[which(dd$is.extreme == TRUE),]

# #qnorm(0.65) - qnorm(0.85)

# CF4<- CF3 %>% 
#   anti_join(dd, by = "dPrime") 

# CF4 %>%
#   group_by(Cong, Alig) %>%
#   identify_outliers(dPrime)

# bxp <- ggboxplot(
#   CF4, x = "Alig", y = "dPrime",
#   color = "Cong", palette = "jco", 
#   facet.by = "group", short.panel.labs = FALSE
# ) 
# bxp

# %%
ggdensity(CF, x = "dPrime",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = c("Alig", "group"))
# Out:
# plot without title

# %%
CF %>%
  group_by(Cong, Alig, group) %>%
  get_summary_stats(dPrime, type = "mean_sd")
# Out:
#    Cong        Alig          group variable n  mean  sd
# 1  Congruent   Alignment     CZ    dPrime   16 0.980 0.017
# 2  Congruent   Alignment     LPPC  dPrime   18 0.978 0.021
# 3  Congruent   Alignment     RPPC  dPrime   18 0.976 0.018
# 4  Congruent   MissAlignment CZ    dPrime   17 0.963 0.026
# 5  Congruent   MissAlignment LPPC  dPrime   16 0.975 0.017
# 6  Congruent   MissAlignment RPPC  dPrime   17 0.971 0.024
# 7  InCongruent Alignment     CZ    dPrime   18 0.946 0.047
# 8  InCongruent Alignment     LPPC  dPrime   18 0.945 0.041
# 9  InCongruent Alignment     RPPC  dPrime   18 0.934 0.052
# 10 InCongruent MissAlignment CZ    dPrime   17 0.966 0.022
# 11 InCongruent MissAlignment LPPC  dPrime   18 0.951 0.036
# 12 InCongruent MissAlignment RPPC  dPrime   17 0.955 0.026

# %%
CF %>% group_by(Cong, Alig, group) %>% shapiro_test(dPrime)
# Out:
#    Cong        Alig          group variable statistic p
# 1  Congruent   Alignment     CZ    dPrime   0.9178407 0.15570139
# 2  Congruent   Alignment     LPPC  dPrime   0.8852076 0.03196888
# 3  Congruent   Alignment     RPPC  dPrime   0.9180529 0.11940429
# 4  Congruent   MissAlignment CZ    dPrime   0.9179155 0.13615624
# 5  Congruent   MissAlignment LPPC  dPrime   0.9265750 0.21504391
# 6  Congruent   MissAlignment RPPC  dPrime   0.9192268 0.14329350
# 7  InCongruent Alignment     CZ    dPrime   0.8760057 0.02237699
# 8  InCongruent Alignment     LPPC  dPrime   0.9376207 0.26374220
# 9  InCongruent Alignment     RPPC  dPrime   0.9258319 0.16395507
# 10 InCongruent MissAlignment CZ    dPrime   0.9549922 0.54004727
# 11 InCongruent MissAlignment LPPC  dPrime   0.9321942 0.21219875
# 12 InCongruent MissAlignment RPPC  dPrime   0.9614070 0.65806271

# %%
ggqqplot(CF, "dPrime", ggtheme = theme_bw()) +
  facet_grid(Cong + group ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF, x = "Alig", y = "dPrime",
  color = "Cong", palette = "jco", 
    #outlier.shape = NA, 
  facet.by = "group", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
#t2way(dPrime ~ Cong*Alig, data = CF_CZ_sum_dprime)
#bwtrim(dPrime ~ Cong*Alig*group, id = subj, data = CF4)

# %%
# #install.packages("ARTool")
# library(car)
# library(ARTool)

# CF$Cong <- factor(CF$Cong)
# CF$Alig <- factor(CF$Alig)
# CF$subj <- factor(CF$subj)
# CF$group <- factor(CF$group)

# m <- art(dPrime ~ Cong + Error(subj), data=CF)
# summary(m)

# %%
# anova(m)

# %%
#res.Cong <- CF %>% group_by(Alig) %>% friedman_test(dPrime ~ Cong |subj)
#res.Cong

# %%
#res.Alig <- CF_CZ_sum_dprime2 %>% group_by(Cong) %>% friedman_test(dPrime ~ Alig |subj)
#res.Alig

# %%
#CF_CZ_sum_dprime %>%
 # group_by(Cong, Alig) %>%
  #identify_outliers(dPrime)

# %%
#OUT <- CF_CZ_sum_dprime %>%
 # group_by(Cong, Alig) %>%
 # identify_outliers(dPrime)
#OUTT <- OUT[which(OUT$is.extreme == TRUE | OUT$is.extreme == FALSE ),]

#CF_CZ_sum_dprime2<- CF_CZ_sum_dprime %>% 
 # anti_join(OUTT, by = "dPrime")

# %%
#CF_CZ_sum_dprime2

# %%
#CF_CZ_sum_dprime3 %>%
 # group_by(Cong, Alig) %>%
  #identify_outliers(dPrime)

# %%
#OUT <- CF_CZ_sum_dprime3 %>%
 # group_by(Cong, Alig) %>%
  #identify_outliers(dPrime)
#OUTT <- OUT[which(OUT$is.extreme == TRUE | OUT$is.extreme == FALSE ),]

#CF_CZ_sum_dprime4<- CF_CZ_sum_dprime3 %>% 
 # anti_join(OUTT, by = "dPrime")

# %%
#ggdensity(CF_CZ_sum_dprime4$dPrime, rug = TRUE, fill = "lightgray")

# %%
#CF_CZ_sum_dprime4 %>% group_by(Cong, Alig) %>% shapiro_test(dPrime)

# %%
#ggqqplot(CF_CZ_sum_dprime4, "dPrime", ggtheme = theme_bw()) +
#  facet_grid(Cong ~ Alig, labeller = "label_both")

# %%
#bxp <- ggboxplot(
 # CF_CZ_sum_dprime2, x = "Alig", y = "dPrime",
  #color = "Cong", palette = "jco",
 # facet.by = "Alig", short.panel.labs = FALSE
#) 
#bxp

# %%
res.aov <- anova_test(
  data = CF, dv = dPrime, wid = subj,
  within = c(Cong, Alig, group)
)
get_anova_table(res.aov)
# Out:
#   Effect          DFn  DFd   F         p     p<.05 ges
# 1 Cong            1.00 13.00 10.842000 0.006 *     1.24e-01
# 2 Alig            1.00 13.00  0.067000 0.800       4.04e-04
# 3 group           2.00 26.00  1.236000 0.307       1.00e-02
# 4 Cong:Alig       1.00 13.00 10.653000 0.006 *     3.10e-02
# 5 Cong:group      1.38 17.95  1.265000 0.292       1.00e-02
# 6 Alig:group      2.00 26.00  0.000152 1.000       1.48e-06
# 7 Cong:Alig:group 1.36 17.64  1.787000 0.200       1.20e-02

# %%
two.way <- CF %>%
  group_by(group) %>%
  anova_test(dv = dPrime, wid = subj, within = c(Cong,Alig)) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
two.way
# Out:
#   group Effect    DFn DFd F      p        p<.05 ges      p.adj
# 1 CZ    Cong      1   14   2.244 0.156000       0.061000 1.000000
# 2 CZ    Alig      1   14   0.017 0.898000       0.000216 1.000000
# 3 CZ    Cong:Alig 1   14  15.833 0.001000 *     0.087000 0.009000
# 4 LPPC  Cong      1   15   9.860 0.007000 *     0.140000 0.063000
# 5 LPPC  Alig      1   15   0.013 0.910000       0.000146 1.000000
# 6 LPPC  Cong:Alig 1   15   0.895 0.359000       0.006000 1.000000
# 7 RPPC  Cong      1   16  20.451 0.000347 *     0.186000 0.003123
# 8 RPPC  Alig      1   16   0.140 0.713000       0.002000 1.000000
# 9 RPPC  Cong:Alig 1   16   2.724 0.118000       0.031000 1.000000

# %%
two.way2 <- CF %>%
  group_by(Cong) %>%
  anova_test(dv = dPrime, wid = subj, within = c(Alig, group)) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
two.way2
# Out:
#   Cong        Effect     DFn DFd F     p     p<.05 ges   p.adj
# 1 Congruent   Alig       1   13  6.267 0.026 *     0.073 0.156
# 2 Congruent   group      2   26  0.484 0.622       0.008 1.000
# 3 Congruent   Alig:group 2   26  1.044 0.366       0.024 1.000
# 4 InCongruent Alig       1   16  3.308 0.088       0.023 0.528
# 5 InCongruent group      2   32  0.932 0.404       0.014 1.000
# 6 InCongruent Alig:group 2   32  0.644 0.532       0.006 1.000

# %%
two.way3 <- CF %>%
  group_by(Alig) %>%
  anova_test(dv = dPrime, wid = subj, within = c(Cong, group)) %>%
  get_anova_table() %>%
  adjust_pvalue(method = "bonferroni")
two.way3
# Out:
#   Alig          Effect     DFn DFd F      p        p<.05 ges   p.adj
# 1 Alignment     Cong       1   15  17.179 0.000864 *     0.199 0.005184
# 2 Alignment     group      2   30   0.862 0.433000       0.009 1.000000
# 3 Alignment     Cong:group 2   30   0.640 0.534000       0.006 1.000000
# 4 MissAlignment Cong       1   14   4.456 0.053000       0.054 0.318000
# 5 MissAlignment group      2   28   0.450 0.642000       0.008 1.000000
# 6 MissAlignment Cong:group 2   28   1.764 0.190000       0.027 1.000000

# %% [markdown]
# # Bias

# %%
load("CF_CZ_female_bias.Rda")
load("CF_RPPC_female_bias2.Rda")
load("CF_LPPC_female_bias.Rda")

# %%
CF_CZ_female_bias_out <- CF_CZ_female_bias
CF_RPPC_female_bias_out <- CF_RPPC_female_bias2
CF_LPPC_female_bias_out <- CF_LPPC_female_bias

# %%
CF_CZ_female_bias_out$group <- "CZ"
CF_RPPC_female_bias_out$group <- "RPPC"
CF_LPPC_female_bias_out$group <- "LPPC"
CF_bias <- rbind(CF_CZ_female_bias_out,CF_RPPC_female_bias_out, CF_LPPC_female_bias_out)

# %%
CF_bias
# Out:
#     subj Cong        Alig          Acc       MRT       SDT NumbersOf HitRate
# 1   19   Congruent   Alignment     1.0000000 0.7849932 Hit 19        1.0000000
# 2   19   Congruent   MissAlignment 0.9500000 0.8151910 Hit 19        0.9500000
# 3   19   InCongruent Alignment     0.8500000 0.9307214 Hit 17        0.8500000
# 4   19   InCongruent MissAlignment 1.0000000 0.9004288 Hit 20        1.0000000
# 5   20   Congruent   Alignment     1.0000000 0.5790370 Hit 20        1.0000000
# 6   20   Congruent   MissAlignment 0.9473684 0.6029169 Hit 18        0.9473684
# 7   20   InCongruent Alignment     0.9500000 0.6143512 Hit 19        0.9500000
# 8   20   InCongruent MissAlignment 0.9500000 0.6340836 Hit 19        0.9500000
# 9   21   Congruent   Alignment     1.0000000 0.4460446 Hit 20        1.0000000
# 10  21   Congruent   MissAlignment 0.8947368 0.4532856 Hit 17        0.8947368
# 11  21   InCongruent Alignment     1.0000000 0.4609552 Hit 20        1.0000000
# 12  21   InCongruent MissAlignment 0.9000000 0.4712704 Hit 18        0.9000000
# 13  22   Congruent   Alignment     1.0000000 0.6811108 Hit 20        1.0000000
# 14  22   Congruent   MissAlignment 0.9473684 0.7372810 Hit 18        0.9473684
# 15  22   InCongruent Alignment     1.0000000 0.7887514 Hit 20        1.0000000
# 16  22   InCongruent MissAlignment 0.9473684 0.7529951 Hit 18        0.9473684
# 17  23   Congruent   Alignment     0.8421053 0.8851699 Hit 16        0.8421053
# 18  23   Congruent   MissAlignment 0.6000000 1.0350229 Hit 12        0.6000000
# 19  23   InCongruent Alignment     0.7500000 0.8160524 Hit 15        0.7500000
# 20  24   Congruent   Alignment     1.0000000 1.0251602 Hit 20        1.0000000
# 21  24   Congruent   MissAlignment 0.8947368 1.0892948 Hit 17        0.8947368
# 22  24   InCongruent Alignment     1.0000000 1.0620158 Hit 20        1.0000000
# 23  24   InCongruent MissAlignment 1.0000000 1.2673149 Hit 18        1.0000000
# 24  25   Congruent   Alignment     1.0000000 0.6066546 Hit 20        1.0000000
# 25  25   Congruent   MissAlignment 0.9000000 0.6723962 Hit 18        0.9000000
# 26  25   InCongruent Alignment     0.9473684 0.7083654 Hit 18        0.9473684
# 27  25   InCongruent MissAlignment 1.0000000 0.6297208 Hit 19        1.0000000
# 28  26   Congruent   Alignment     0.9500000 0.9479996 Hit 19        0.9500000
# 29  26   Congruent   MissAlignment 0.9500000 0.7667514 Hit 19        0.9500000
# 30  26   InCongruent Alignment     1.0000000 1.0649274 Hit 20        1.0000000
# ⋮   ⋮    ⋮           ⋮             ⋮         ⋮         ⋮   ⋮         ⋮
# 178 29   InCongruent Alignment     0.9444444 0.7489858 Hit 17        0.9444444
# 179 29   InCongruent MissAlignment 0.9473684 0.7275354 Hit 18        0.9473684
# 180 30   Congruent   Alignment     1.0000000 0.5034887 Hit 20        1.0000000
# 181 30   Congruent   MissAlignment 1.0000000 0.5343914 Hit 20        1.0000000
# 182 30   InCongruent Alignment     1.0000000 0.5531455 Hit 20        1.0000000
# 183 30   InCongruent MissAlignment 0.9500000 0.5589545 Hit 19        0.9500000
# 184 31   Congruent   Alignment     0.9500000 0.4860119 Hit 19        0.9500000
# 185 31   Congruent   MissAlignment 0.9000000 0.4834507 Hit 18        0.9000000
# 186 31   InCongruent Alignment     0.9000000 0.5339250 Hit 18        0.9000000
# 187 31   InCongruent MissAlignment 0.8947368 0.5661962 Hit 17        0.8947368
# 188 32   Congruent   Alignment     1.0000000 0.6528953 Hit 20        1.0000000
# 189 32   Congruent   MissAlignment 1.0000000 0.7380030 Hit 19        1.0000000
# 190 32   InCongruent Alignment     0.8947368 0.7499736 Hit 17        0.8947368
# 191 32   InCongruent MissAlignment 0.9500000 0.8001234 Hit 19        0.9500000
# 192 33   Congruent   Alignment     1.0000000 0.6296572 Hit 20        1.0000000
# 193 33   Congruent   MissAlignment 0.8947368 0.6474264 Hit 17        0.8947368
# 194 33   InCongruent Alignment     1.0000000 0.6767898 Hit 20        1.0000000
# 195 33   InCongruent MissAlignment 0.8421053 0.6155200 Hit 16        0.8421053
# 196 34   Congruent   Alignment     1.0000000 0.5877669 Hit 20        1.0000000
# 197 34   Congruent   MissAlignment 0.9500000 0.7002336 Hit 19        0.9500000
# 198 34   InCongruent Alignment     0.8500000 0.6837920 Hit 17        0.8500000
# 199 34   InCongruent MissAlignment 0.7500000 0.6830697 Hit 15        0.7500000
# 200 35   Congruent   Alignment     1.0000000 0.4794247 Hit 19        1.0000000
# 201 35   Congruent   MissAlignment 0.9000000 0.6012651 Hit 18        0.9000000
# 202 35   InCongruent Alignment     1.0000000 0.4896043 Hit 20        1.0000000
# 203 35   InCongruent MissAlignment 1.0000000 0.6188222 Hit 20        1.0000000
# 204 36   Congruent   Alignment     0.9000000 0.6475334 Hit 18        0.9000000
# 205 36   Congruent   MissAlignment 0.9500000 0.6680381 Hit 19        0.9500000
# 206 36   InCongruent Alignment     0.5789474 0.6139592 Hit 11        0.5789474
# 207 36   InCongruent MissAlignment 0.9000000 0.7077158 Hit 18        0.9000000
#     FalseAlarmRate dPrime    bias          group
# 1   0.00000000     1.0000000  0.000000e+00 CZ
# 2   0.05000000     0.9736842  5.551115e-16 CZ
# 3   0.20000000     0.8943015 -9.740608e-02 CZ
# 4   0.20000000     0.9500000 -6.998907e-01 CZ
# 5   0.00000000     1.0000000 -8.881784e-16 CZ
# 6   0.20000000     0.9307749 -3.891175e-01 CZ
# 7   0.00000000     0.9875000  2.933761e-01 CZ
# 8   0.00000000     0.9875000  2.933761e-01 CZ
# 9   0.05000000     0.9875000 -2.982746e-01 CZ
# 10  0.10000000     0.9428191  1.471602e-02 CZ
# 11  0.00000000     1.0000000 -8.881784e-16 CZ
# 12  0.00000000     0.9750000  4.799256e-01 CZ
# 13  0.00000000     1.0000000 -8.881784e-16 CZ
# 14  0.00000000     0.9868421  3.058748e-01 CZ
# 15  0.05263158     0.9868421 -3.058748e-01 CZ
# 16  0.00000000     0.9868421  3.058748e-01 CZ
# 17  0.05000000     0.9436050  3.208528e-01 CZ
# 18  0.00000000     0.9000000  9.940278e-01 CZ
# 19  0.15000000     0.8764706  1.809718e-01 CZ
# 20  0.05263158     0.9868421 -3.058748e-01 CZ
# 21  0.05000000     0.9583286  1.963671e-01 CZ
# 22  0.10526316     0.9736842 -4.897432e-01 CZ
# 23  0.00000000     1.0000000  0.000000e+00 CZ
# 24  0.15000000     0.9625000 -6.024847e-01 CZ
# 25  0.00000000     0.9750000  4.750271e-01 CZ
# 26  0.10000000     0.9589912 -1.691523e-01 CZ
# 27  0.15000000     0.9625000 -5.975862e-01 CZ
# 28  0.05000000     0.9736842  5.551115e-16 CZ
# 29  0.11111111     0.9566977 -2.121066e-01 CZ
# 30  0.10000000     0.9750000 -4.799256e-01 CZ
# ⋮   ⋮              ⋮         ⋮             ⋮
# 178 0.05000000     0.9721448  2.581740e-02 LPPC
# 179 0.05000000     0.9729551  1.249868e-02 LPPC
# 180 0.10000000     0.9750000 -4.799256e-01 LPPC
# 181 0.15789474     0.9605263 -6.142289e-01 LPPC
# 182 0.00000000     1.0000000 -6.661338e-16 LPPC
# 183 0.05000000     0.9736842  5.551115e-16 LPPC
# 184 0.10000000     0.9597953 -1.816510e-01 LPPC
# 185 0.10000000     0.9444444  0.000000e+00 LPPC
# 186 0.10000000     0.9444444  0.000000e+00 LPPC
# 187 0.05263158     0.9575163  1.838684e-01 LPPC
# 188 0.10000000     0.9750000 -4.799256e-01 LPPC
# 189 0.10526316     0.9736842 -4.847000e-01 LPPC
# 190 0.31578947     0.8733032 -3.863069e-01 LPPC
# 191 0.22222222     0.9254490 -4.400720e-01 LPPC
# 192 0.00000000     1.0000000 -6.661338e-16 LPPC
# 193 0.10000000     0.9428191  1.471602e-02 LPPC
# 194 0.15789474     0.9605263 -6.142289e-01 LPPC
# 195 0.05263158     0.9427083  3.083541e-01 LPPC
# 196 0.00000000     1.0000000 -8.881784e-16 LPPC
# 197 0.00000000     0.9875000  2.933761e-01 LPPC
# 198 0.05263158     0.9449368  2.917114e-01 LPPC
# 199 0.05000000     0.9175439  4.851819e-01 LPPC
# 200 0.20000000     0.9500000 -6.949923e-01 LPPC
# 201 0.00000000     0.9750000  4.750271e-01 LPPC
# 202 0.10000000     0.9750000 -4.799256e-01 LPPC
# 203 0.05000000     0.9875000 -2.982746e-01 LPPC
# 204 0.00000000     0.9750000  4.799256e-01 LPPC
# 205 0.00000000     0.9875000  2.982746e-01 LPPC
# 206 0.00000000     0.8947368  1.016202e+00 LPPC
# 207 0.05000000     0.9597953  1.816510e-01 LPPC

# %%
CF_bias %>%
  group_by(Cong, Alig, group) %>%
  get_summary_stats(bias, type = "mean_sd")
# Out:
#    Cong        Alig          group variable n  mean   sd
# 1  Congruent   Alignment     CZ    bias     16 -0.169 0.326
# 2  Congruent   Alignment     LPPC  bias     18 -0.176 0.282
# 3  Congruent   Alignment     RPPC  bias     18 -0.240 0.317
# 4  Congruent   MissAlignment CZ    bias     17  0.047 0.405
# 5  Congruent   MissAlignment LPPC  bias     16  0.014 0.368
# 6  Congruent   MissAlignment RPPC  bias     17 -0.023 0.365
# 7  InCongruent Alignment     CZ    bias     18 -0.166 0.353
# 8  InCongruent Alignment     LPPC  bias     18 -0.053 0.454
# 9  InCongruent Alignment     RPPC  bias     17 -0.117 0.303
# 10 InCongruent MissAlignment CZ    bias     17  0.037 0.407
# 11 InCongruent MissAlignment LPPC  bias     18 -0.031 0.368
# 12 InCongruent MissAlignment RPPC  bias     17  0.025 0.338

# %%
ggdensity(CF_bias, x = "bias",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = c("Alig","group"))
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_bias, x = "Alig", y = "bias",
  color = "Cong", palette = "jco", outlier.shape = NA, 
  facet.by = "group", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
CF_bias %>% group_by(Cong, Alig, group) %>% shapiro_test(bias)
# Out:
#    Cong        Alig          group variable statistic p
# 1  Congruent   Alignment     CZ    bias     0.9163879 0.14752718
# 2  Congruent   Alignment     LPPC  bias     0.9105892 0.08811629
# 3  Congruent   Alignment     RPPC  bias     0.8937442 0.04475968
# 4  Congruent   MissAlignment CZ    bias     0.9400489 0.31876610
# 5  Congruent   MissAlignment LPPC  bias     0.9162202 0.14661152
# 6  Congruent   MissAlignment RPPC  bias     0.9567507 0.57143560
# 7  InCongruent Alignment     CZ    bias     0.9592691 0.58758081
# 8  InCongruent Alignment     LPPC  bias     0.9730643 0.85292481
# 9  InCongruent Alignment     RPPC  bias     0.9049238 0.08215043
# 10 InCongruent MissAlignment CZ    bias     0.9517683 0.48508208
# 11 InCongruent MissAlignment LPPC  bias     0.9429157 0.32480636
# 12 InCongruent MissAlignment RPPC  bias     0.9799925 0.95703494

# %%
ggqqplot(CF_bias, "bias", ggtheme = theme_bw()) +
  facet_grid(Cong + group ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
CF_bias %>%
  group_by(Cong, Alig, group) %>%
  identify_outliers(bias)
# Out:
#   Cong        Alig      group subj Acc MRT      SDT NumbersOf HitRate
# 1 InCongruent Alignment RPPC  19   1   0.955752 Hit 20        1
#   FalseAlarmRate dPrime    bias       is.outlier is.extreme
# 1 0.2631579      0.9342105 -0.7989829 TRUE       FALSE

# %%
res.aov <- anova_test(
  data = CF_bias, dv = bias, wid = subj,
  within = c(Cong, Alig,group)
)
get_anova_table(res.aov)
# Out:
#   Effect          DFn DFd F     p     p<.05 ges
# 1 Cong            1   12  0.246 0.629       8.91e-04
# 2 Alig            1   12  3.662 0.080       3.50e-02
# 3 group           2   24  0.002 0.998       1.77e-05
# 4 Cong:Alig       1   12  1.210 0.293       7.00e-03
# 5 Cong:group      2   24  0.014 0.986       1.52e-04
# 6 Alig:group      2   24  1.361 0.276       1.60e-02
# 7 Cong:Alig:group 2   24  1.118 0.343       1.10e-02

# %%
# # comparisons for Alig variable
# CF_bias %>%
#   group_by(group) %>%
#   pairwise_t_test(
#     bias ~ Alig, paired = TRUE, 
#     p.adjust.method = "bonferroni"
#     )

# %%
# # comparisons for Cong variable
# CF_bias %>%
# group_by(group) %>%
#   pairwise_t_test(
#     bias ~ Cong, paired = TRUE, 
#     p.adjust.method = "bonferroni"
#     )

# %% [markdown]
# # RT

# %%
load("CF_CZ_female_RT2.Rda")
load("CF_RPPC_female_RT3.Rda")
load("CF_LPPC_female_RT.Rda")

# %%
CF_CZ_female_RT2$group <- "CZ"
CF_RPPC_female_RT3$group <- "RPPC"
CF_LPPC_female_RT$group <- "LPPC"

# %%
CF_RT <- rbind(CF_CZ_female_RT2,CF_RPPC_female_RT3, CF_LPPC_female_RT)
CF_RT
# Out:
#     subj Cong        Alig          MRT       group
# 1   19   Congruent   Alignment     0.8071602 CZ
# 2   19   Congruent   MissAlignment 0.8535971 CZ
# 3   19   InCongruent MissAlignment 0.8849255 CZ
# 4   20   Congruent   Alignment     0.5870369 CZ
# 5   20   Congruent   MissAlignment 0.6208664 CZ
# 6   20   InCongruent Alignment     0.6285295 CZ
# 7   20   InCongruent MissAlignment 0.6870855 CZ
# 8   21   Congruent   Alignment     0.4425843 CZ
# 9   21   Congruent   MissAlignment 0.4810498 CZ
# 10  21   InCongruent Alignment     0.4753736 CZ
# 11  22   Congruent   Alignment     0.7205798 CZ
# 12  22   Congruent   MissAlignment 0.7243872 CZ
# 13  22   InCongruent Alignment     0.7401765 CZ
# 14  22   InCongruent MissAlignment 0.7834314 CZ
# 15  23   Congruent   Alignment     0.8732740 CZ
# 16  25   Congruent   Alignment     0.6787551 CZ
# 17  25   Congruent   MissAlignment 0.7253464 CZ
# 18  25   InCongruent Alignment     0.7209442 CZ
# 19  25   InCongruent MissAlignment 0.7097993 CZ
# 20  26   Congruent   MissAlignment 0.8955386 CZ
# 21  27   Congruent   Alignment     0.6384801 CZ
# 22  27   Congruent   MissAlignment 0.6705273 CZ
# 23  27   InCongruent Alignment     0.6502597 CZ
# 24  27   InCongruent MissAlignment 0.7208232 CZ
# 25  28   Congruent   Alignment     0.5150256 CZ
# 26  28   Congruent   MissAlignment 0.5690689 CZ
# 27  28   InCongruent Alignment     0.5168714 CZ
# 28  28   InCongruent MissAlignment 0.5462794 CZ
# 29  29   Congruent   Alignment     0.6032559 CZ
# 30  29   Congruent   MissAlignment 0.6226492 CZ
# ⋮   ⋮    ⋮           ⋮             ⋮         ⋮
# 441 29   InCongruent Alignment     0.7520956 LPPC
# 451 29   InCongruent MissAlignment 0.7268950 LPPC
# 461 30   Congruent   Alignment     0.5428416 LPPC
# 471 30   Congruent   MissAlignment 0.5696142 LPPC
# 481 30   InCongruent Alignment     0.5735008 LPPC
# 491 30   InCongruent MissAlignment 0.5808841 LPPC
# 501 31   Congruent   Alignment     0.5191899 LPPC
# 511 31   Congruent   MissAlignment 0.5033304 LPPC
# 521 31   InCongruent Alignment     0.5612575 LPPC
# 531 31   InCongruent MissAlignment 0.5475297 LPPC
# 541 32   Congruent   Alignment     0.7059329 LPPC
# 551 32   Congruent   MissAlignment 0.8549598 LPPC
# 561 32   InCongruent Alignment     0.7311522 LPPC
# 571 32   InCongruent MissAlignment 0.8883852 LPPC
# 581 33   Congruent   Alignment     0.6616211 LPPC
# 591 33   Congruent   MissAlignment 0.6743753 LPPC
# 601 33   InCongruent Alignment     0.7067111 LPPC
# 611 33   InCongruent MissAlignment 0.6401532 LPPC
# 621 34   Congruent   Alignment     0.6462971 LPPC
# 631 34   Congruent   MissAlignment 0.6999851 LPPC
# 641 34   InCongruent Alignment     0.7344471 LPPC
# 651 34   InCongruent MissAlignment 0.7225611 LPPC
# 661 35   Congruent   Alignment     0.5640686 LPPC
# 671 35   Congruent   MissAlignment 0.6305435 LPPC
# 681 35   InCongruent Alignment     0.5576123 LPPC
# 691 35   InCongruent MissAlignment 0.6098177 LPPC
# 701 36   Congruent   Alignment     0.6114360 LPPC
# 711 36   Congruent   MissAlignment 0.6265933 LPPC
# 721 36   InCongruent Alignment     0.6223810 LPPC
# 731 36   InCongruent MissAlignment 0.6986064 LPPC

# %%
CF_RT %>%
  group_by(Cong, Alig, group) %>%
  get_summary_stats(MRT, type = "mean_sd")
# Out:
#    Cong        Alig          group variable n  mean  sd
# 1  Congruent   Alignment     CZ    MRT      16 0.641 0.108
# 2  Congruent   Alignment     LPPC  MRT      18 0.670 0.126
# 3  Congruent   Alignment     RPPC  MRT      14 0.619 0.061
# 4  Congruent   MissAlignment CZ    MRT      16 0.687 0.104
# 5  Congruent   MissAlignment LPPC  MRT      18 0.716 0.134
# 6  Congruent   MissAlignment RPPC  MRT      14 0.648 0.081
# 7  InCongruent Alignment     CZ    MRT      14 0.645 0.085
# 8  InCongruent Alignment     LPPC  MRT      18 0.710 0.137
# 9  InCongruent Alignment     RPPC  MRT      14 0.645 0.080
# 10 InCongruent MissAlignment CZ    MRT      14 0.697 0.083
# 11 InCongruent MissAlignment LPPC  MRT      18 0.733 0.153
# 12 InCongruent MissAlignment RPPC  MRT      15 0.682 0.107

# %%
ggdensity(CF_RT, x = "MRT",
   add = "mean", rug = TRUE,
   color = "Cong", fill = "Cong",
   palette = c("#00AFBB", "#E7B800"), facet.by = c("Alig","group"))
# Out:
# plot without title

# %%
CF_RT %>%
  group_by(Cong, Alig, group) %>%
  identify_outliers(MRT)
# Out:
#   Cong        Alig          group subj MRT       is.outlier is.extreme
# 1 Congruent   Alignment     CZ    21   0.4425843 TRUE       FALSE
# 2 Congruent   Alignment     CZ    23   0.8732740 TRUE       FALSE
# 3 Congruent   Alignment     LPPC  26   0.9620213 TRUE       FALSE
# 4 Congruent   MissAlignment CZ    26   0.8955386 TRUE       FALSE
# 5 InCongruent MissAlignment CZ    19   0.8849255 TRUE        TRUE
# 6 InCongruent MissAlignment CZ    28   0.5462794 TRUE       FALSE
# 7 InCongruent MissAlignment CZ    30   0.5706609 TRUE       FALSE
# 8 InCongruent MissAlignment RPPC  26   0.9397418 TRUE       FALSE

# %%
CF_RT %>% group_by(Cong, Alig, group) %>% shapiro_test(MRT)
# Out:
#    Cong        Alig          group variable statistic p
# 1  Congruent   Alignment     CZ    MRT      0.9678056 0.80193138
# 2  Congruent   Alignment     LPPC  MRT      0.9496966 0.42027743
# 3  Congruent   Alignment     RPPC  MRT      0.8514433 0.02323681
# 4  Congruent   MissAlignment CZ    MRT      0.9656188 0.76362535
# 5  Congruent   MissAlignment LPPC  MRT      0.9187491 0.12284293
# 6  Congruent   MissAlignment RPPC  MRT      0.9332784 0.33898663
# 7  InCongruent Alignment     CZ    MRT      0.9127119 0.17253523
# 8  InCongruent Alignment     LPPC  MRT      0.9605313 0.61192226
# 9  InCongruent Alignment     RPPC  MRT      0.9511113 0.57808906
# 10 InCongruent MissAlignment CZ    MRT      0.9284195 0.28992029
# 11 InCongruent MissAlignment LPPC  MRT      0.9761711 0.90223006
# 12 InCongruent MissAlignment RPPC  MRT      0.9486721 0.50378509

# %%
ggqqplot(CF_RT, "MRT", ggtheme = theme_bw()) +
  facet_grid(Cong + group ~ Alig, labeller = "label_both")
# Out:
# plot without title

# %%
bxp <- ggboxplot(
  CF_RT, x = "Alig", y = "MRT",
  color = "Cong", palette = "jco",
  facet.by = "group", short.panel.labs = FALSE
) 
bxp
# Out:
# plot without title

# %%
# dd <- CF_RT %>%
#   group_by(Cong, Alig, group) %>%
#   identify_outliers(MRT)

# dd <- dd[which(dd$is.extreme == TRUE),]

# #qnorm(0.65) - qnorm(0.85)

# CF_RT2<- CF_RT %>% 
#   anti_join(dd, by = "MRT") 

# CF_RT2 %>%
#   group_by(Cong, Alig, group) %>%
#   identify_outliers(MRT)

# bxp <- ggboxplot(
#   CF_RT2, x = "Alig", y = "MRT",
#   color = "Cong", palette = "jco", 
#   facet.by = "group", short.panel.labs = FALSE
# ) 
# bxp

# %%
# bxp <- ggboxplot(
#   CF_RT2, x = "Alig", y = "MRT",
#   color = "Cong", palette = "jco", 
#   facet.by = "group", short.panel.labs = FALSE
# ) 
# bxp

# %%
# dd <- CF_RPPC_sum_RT2 %>%
#   group_by(Cong, Alig) %>%
#   identify_outliers(MRT)

# dd <- dd[which(dd$is.extreme == TRUE),]

# #qnorm(0.65) - qnorm(0.85)

# CF_RPPC_sum_RT3<- CF_RPPC_sum_RT2 %>% 
#   anti_join(dd, by = "MRT") 

# CF_RPPC_sum_RT3 %>%
#   group_by(Cong, Alig) %>%
#   identify_outliers(MRT)

# bxp <- ggboxplot(
#   CF_RPPC_sum_RT3, x = "Alig", y = "MRT",
#   color = "Cong", palette = "jco", 
#  # facet.by = "Alig", short.panel.labs = FALSE
# ) 
# bxp

# %%
# CF_RPPC_sum_RT3 %>% group_by(Cong, Alig) %>% shapiro_test(MRT)

# %%
# #install.packages("ARTool")
# library(car)
# library(ARTool)

# %%
# CF_RT$Cong <- factor(CF_RT$Cong)
# CF_RT$Alig <- factor(CF_RT$Alig)
# CF_RT$subj <- factor(CF_RT$subj)
# CF_RT$group <- factor(CF_RT$group)

# %%
# m <- art(MRT ~ Cong*group+ Error(subj), data=CF_RT)
# summary(m)

# %%
# anova(m)

# %%
# m <- art(MRT ~ Alig + Error(subj), data=CF_RPPC_sum_RT)
# summary(m)

# %%
# anova(m)

# %%
# #t2way(dPrime ~ Cong*Alig, data = CF_CZ_sum_dprime)
# bwtrim(MRT ~ Cong*Alig, id = subj, data = CF_RPPC_sum_RT)
# #sppbb(MRT ~ Cong*Alig, subj, data = CF_CZ_sum_RT)

# %%
#res.Co <- CF_CZ_sum_RT %>% group_by(Alig) %>% friedman_test(MRT ~ Cong |subj)
#res.Co

# %%
#length(CF_CZ_sum_RT$MRT)
#length(CF_CZ_sum_RT$Cong)
#CF_CZ_sum_RT

# %%
#pwc <- CF_CZ_sum_RT %>%
 #   group_by(Alig) %>%
 # wilcox_test(MRT ~ Cong, paired = TRUE, p.adjust.method = "bonferroni")
#pwc

# %%
#res.Alig <- CF_CZ_sum_RT %>% group_by(Cong) %>% friedman_test(MRT ~ Alig |subj)
#res.Alig

# %%
res.aov <- anova_test(
  data = CF_RT, dv = MRT, wid = subj,
  within = c(Cong, Alig, group)
)
get_anova_table(res.aov)
# Out:
#   Effect          DFn DFd F      p        p<.05 ges
# 1 Cong            1   12  27.108 0.000220 *     1.90e-02
# 2 Alig            1   12  32.279 0.000102 *     4.40e-02
# 3 group           2   24   0.421 0.661000       1.00e-02
# 4 Cong:Alig       1   12   3.827 0.074000       4.00e-03
# 5 Cong:group      2   24   0.016 0.984000       1.75e-05
# 6 Alig:group      2   24   0.299 0.744000       8.18e-04
# 7 Cong:Alig:group 2   24   0.692 0.510000       6.89e-04
